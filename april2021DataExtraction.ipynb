# %% [markdown]
# <a href="https://colab.research.google.com/github/kennyxu256/investigatingCryptoPumpAndDumps/blob/main/april2021DataExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Senior Year/busi 496/dataAnalysis
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Senior Year/IRP/IRPAnalysis

# %%
# !pip install ccxt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ccxt
#   Downloading ccxt-3.0.54-py2.py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 45.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.9/dist-packages (from ccxt) (2022.12.7)
# Collecting aiodns>=1.1.1
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting aiohttp>=3.8
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.9/dist-packages (from ccxt) (67.6.1)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/dist-packages (from ccxt) (2.27.1)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.9/dist-packages (from ccxt) (40.0.1)
# Collecting yarl>=1.7.2
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 23.8 MB/s eta 0:00:00
# Collecting pycares>=4.0.0
#   Downloading pycares-4.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 KB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp>=3.8->ccxt) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.1 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 15.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp>=3.8->ccxt) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=2.6.1->ccxt) (1.15.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->ccxt) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.18.4->ccxt) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.21)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, pycares, aiosignal, aiohttp, aiodns, ccxt
# Successfully installed aiodns-3.0.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 ccxt-3.0.54 frozenlist-1.3.3 multidict-6.0.4 pycares-4.3.0 yarl-1.8.2

# %%
import ccxt
import pandas as pd
import time
import os

# %%
def create_ohlcv_df(data):
    header = ['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume']
    df = pd.DataFrame(data, columns=header)
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='ms', origin='unix')  # convert timestamp to datetime
    return df

# %%
# Pulls the raw data from exchanges. Returns list of fetched symbols.
# -- EXAMPLE INPUT --
# exchange = 'binance'
# from_date = '2019-11-20 00:00:00'
# number_candles = 240 - number of candles
# candle_size = '12h' - candlesticks
# f_path = '../data' - CSV OHLCV file path for output
def pull_data(exchange, from_date, n_candles, c_size, f_path, skip=False):
    count = 1
    millisec = 1000
    hold = 1

    missing_symbols = []

    # -- create a folder --
    newpath = f_path + '/' + exchange + '/'
    if not os.path.exists(newpath):
        os.makedirs(newpath)

    # -- load exchange --
    exc_instance = getattr(ccxt, exchange)()
    exc_instance.load_markets()
    from_timestamp = exc_instance.parse8601(from_date)

    # -- pull ohlcv --
    for symbol in exc_instance.symbols:
        for attempt in range(2):  # 3 attempts max
            try:
                print('Pulling:', exchange, ':', symbol, '[{}/{}]'.format(count, len(exc_instance.symbols)))
                data = exc_instance.fetch_ohlcv(symbol, c_size, from_timestamp, n_candles)

                # if < n_candles returned, skip this pair
                if len(data) < n_candles and skip is True:
                    continue

                # -- create DF --
                df = create_ohlcv_df(data)

                # -- save CSV --
                symbol = symbol.replace("/", "-")
                filename = newpath + '{}_{}_[{}]-TO-[{}].csv'.format(exchange, symbol, df['Timestamp'].iloc[0],
                                                                     df['Timestamp'].iloc[-1])
                filename = filename.replace(":", ".")
                df.to_csv(filename)

            except (ccxt.ExchangeError, ccxt.AuthenticationError, ccxt.ExchangeNotAvailable, ccxt.RequestTimeout,
                    IndexError) as error:
                print('Got an error', type(error).__name__, error.args, ', retrying in', hold, 'seconds...')
                time.sleep(hold)
            else:  # if no error, proceed to next iteration
                break
        else:  # we failed all attempts
            print('All attempts failed, skipping:', symbol)
            missing_symbols.append(symbol)
            continue

        count += 1
        # -- wait for rate limit --
        time.sleep((exc_instance.rateLimit / millisec) + 5)  # rate limit +5 seconds to just to be safe

    # print out any symbols we could not obtain
    if len(missing_symbols) > 0:
        print('Unable to obtain:', missing_symbols)

    return missing_symbols

# Specify the exchanges and from date and other parameters here.
# exchanges = 'binance'
# from_date = '2019-04-20 00:00:00'
# number_candles = 240 - number of candles
# candle_size = '1h' - candlesticks
# f_path = '../data' - CSV OHLCV file path for output

# %%
from_date = '2021-04-01 00:00:00'
localFolder = 'freqPumps'
numberCandles = 480

# %%
pull_data('bittrex', from_date, numberCandles, '1h', localFolder)
# Out:
# Pulling: bittrex : 1ECO/BTC [1/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : 1ECO-BTC [1/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 1ECO-BTC
# Pulling: bittrex : 1ECO/USDT [1/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : 1ECO-USDT [1/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 1ECO-USDT
# Pulling: bittrex : 1INCH/BTC [1/941]
# Pulling: bittrex : 1INCH/ETH [2/941]
# Pulling: bittrex : 1INCH/USD [3/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : 1INCH-USD [3/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 1INCH-USD
# Pulling: bittrex : 1INCH/USDT [3/941]
# Pulling: bittrex : 1PECO/BTC [4/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : 1PECO-BTC [4/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 1PECO-BTC
# Pulling: bittrex : 1PECO/USDT [4/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : 1PECO-USDT [4/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 1PECO-USDT
# Pulling: bittrex : 4ART/BTC [4/941]
# Pulling: bittrex : 4ART/USDT [5/941]
# Pulling: bittrex : AAVE/BTC [6/941]
# Pulling: bittrex : AAVE/ETH [7/941]
# Pulling: bittrex : AAVE/EUR [8/941]
# Pulling: bittrex : AAVE/USD [9/941]
# Pulling: bittrex : AAVE/USDT [10/941]
# Pulling: bittrex : ABBC/BTC [11/941]
# Pulling: bittrex : ABYSS/BTC [12/941]
# Pulling: bittrex : ACH/USD [13/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ACH-USD [13/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACH-USD
# Pulling: bittrex : ACXT/USDT [13/941]
# Pulling: bittrex : ADA/BTC [14/941]
# Pulling: bittrex : ADA/ETH [15/941]
# Pulling: bittrex : ADA/EUR [16/941]
# Pulling: bittrex : ADA/USD [17/941]
# Pulling: bittrex : ADA/USDC [18/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ADA-USDC [18/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ADA-USDC
# Pulling: bittrex : ADA/USDT [18/941]
# Pulling: bittrex : ADK/BTC [19/941]
# Pulling: bittrex : ADX/BTC [20/941]
# Pulling: bittrex : AGRS/BTC [21/941]
# Pulling: bittrex : AGRS/USDT [22/941]
# Pulling: bittrex : AGV/USDT [23/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AGV-USDT [23/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGV-USDT
# Pulling: bittrex : AIN/USDT [23/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AIN-USDT [23/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AIN-USDT
# Pulling: bittrex : AKN/USDT [23/941]
# Pulling: bittrex : AKRO/BTC [24/941]
# Pulling: bittrex : AKT/BTC [25/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AKT-BTC [25/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AKT-BTC
# Pulling: bittrex : AKT/USDT [25/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AKT-USDT [25/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AKT-USDT
# Pulling: bittrex : AKTIO/USDT [25/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AKTIO-USDT [25/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AKTIO-USDT
# Pulling: bittrex : ALGO/BTC [25/941]
# Pulling: bittrex : ALGO/USD [26/941]
# Pulling: bittrex : ALGO/USDT [27/941]
# Pulling: bittrex : ALTA/USDT [28/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ALTA-USDT [28/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALTA-USDT
# Pulling: bittrex : AMP/BTC [28/941]
# Pulling: bittrex : AMP/ETH [29/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AMP-ETH [29/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AMP-ETH
# Pulling: bittrex : AMP/USD [29/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AMP-USD [29/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AMP-USD
# Pulling: bittrex : AMP/USDT [29/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AMP-USDT [29/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AMP-USDT
# Pulling: bittrex : ANKR/BTC [29/941]
# Pulling: bittrex : ANKR/ETH [30/941]
# Pulling: bittrex : ANKR/USD [31/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ANKR-USD [31/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ANKR-USD
# Pulling: bittrex : ANT/BTC [31/941]
# Pulling: bittrex : ANT/ETH [32/941]
# Pulling: bittrex : ANT/USD [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ANT-USD [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ANT-USD
# Pulling: bittrex : ANTE/USDT [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ANTE-USDT [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ANTE-USDT
# Pulling: bittrex : APE/USD [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : APE-USD [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APE-USD
# Pulling: bittrex : APE/USDT [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : APE-USDT [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APE-USDT
# Pulling: bittrex : API3/USDT [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : API3-USDT [33/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: API3-USDT
# Pulling: bittrex : APM/BTC [33/941]
# Pulling: bittrex : APXP/USDT [34/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : APXP-USDT [34/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APXP-USDT
# Pulling: bittrex : AR/BTC [34/941]
# Pulling: bittrex : AR/USD [35/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AR-USD [35/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AR-USD
# Pulling: bittrex : ARDR/BTC [35/941]
# Pulling: bittrex : ARDX/BTC [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARDX-BTC [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARDX-BTC
# Pulling: bittrex : ARDX/ETH [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARDX-ETH [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARDX-ETH
# Pulling: bittrex : ARDX/USDT [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARDX-USDT [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARDX-USDT
# Pulling: bittrex : ARIA20/BTC [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARIA20-BTC [36/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARIA20-BTC
# Pulling: bittrex : ARK/BTC [36/941]
# Pulling: bittrex : ARTIC/USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARTIC-USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARTIC-USDT
# Pulling: bittrex : ARTII/BTC [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARTII-BTC [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARTII-BTC
# Pulling: bittrex : ARV/USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARV-USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARV-USDT
# Pulling: bittrex : ARW/USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ARW-USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARW-USDT
# Pulling: bittrex : ASM/USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ASM-USDT [37/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ASM-USDT
# Pulling: bittrex : ATOM/BTC [37/941]
# Pulling: bittrex : ATOM/ETH [38/941]
# Pulling: bittrex : ATOM/USD [39/941]
# Pulling: bittrex : ATOM/USDT [40/941]
# Pulling: bittrex : ATRI/USDT [41/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ATRI-USDT [41/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATRI-USDT
# Pulling: bittrex : ATTR/USDT [41/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ATTR-USDT [41/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATTR-USDT
# Pulling: bittrex : AUDT/USDT [41/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AUDT-USDT [41/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AUDT-USDT
# Pulling: bittrex : AVAX/BTC [41/941]
# Pulling: bittrex : AVAX/ETH [42/941]
# Pulling: bittrex : AVAX/USD [43/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AVAX-USD [43/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AVAX-USD
# Pulling: bittrex : AVAX/USDT [43/941]
# Pulling: bittrex : AVT/ETH [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AVT-ETH [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AVT-ETH
# Pulling: bittrex : AVT/USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AVT-USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AVT-USDT
# Pulling: bittrex : AXS/USD [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AXS-USD [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AXS-USD
# Pulling: bittrex : AXS/USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : AXS-USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AXS-USDT
# Pulling: bittrex : B2M/USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : B2M-USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: B2M-USDT
# Pulling: bittrex : BAAS/USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BAAS-USDT [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAAS-USDT
# Pulling: bittrex : BADGER/USD [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BADGER-USD [44/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BADGER-USD
# Pulling: bittrex : BAL/BTC [44/941]
# Pulling: bittrex : BAL/ETH [45/941]
# Pulling: bittrex : BAL/EUR [46/941]
# Pulling: bittrex : BAL/USD [47/941]
# Pulling: bittrex : BAL/USDT [48/941]
# Pulling: bittrex : BAND/BTC [49/941]
# Pulling: bittrex : BAND/ETH [50/941]
# Pulling: bittrex : BAND/USDT [51/941]
# Pulling: bittrex : BAT/BTC [52/941]
# Pulling: bittrex : BAT/ETH [53/941]
# Pulling: bittrex : BAT/USD [54/941]
# Pulling: bittrex : BAT/USDT [55/941]
# Pulling: bittrex : BAX/USDT [56/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BAX-USDT [56/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAX-USDT
# Pulling: bittrex : BBF/USDT [56/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BBF-USDT [56/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BBF-USDT
# Pulling: bittrex : BCH/BTC [56/941]
# Pulling: bittrex : BCH/ETH [57/941]
# Pulling: bittrex : BCH/EUR [58/941]
# Pulling: bittrex : BCH/USD [59/941]
# Pulling: bittrex : BCH/USDT [60/941]
# Pulling: bittrex : BEE/USDT [61/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BEE-USDT [61/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BEE-USDT
# Pulling: bittrex : BERRY/USDT [61/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BERRY-USDT [61/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BERRY-USDT
# Pulling: bittrex : BEST/USDT [61/941]
# Pulling: bittrex : BFC/BTC [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BFC-BTC [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BFC-BTC
# Pulling: bittrex : BIOT/USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BIOT-USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BIOT-USDT
# Pulling: bittrex : BIST/USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BIST-USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BIST-USDT
# Pulling: bittrex : BITCI/USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BITCI-USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BITCI-USDT
# Pulling: bittrex : BKR/USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BKR-USDT [62/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BKR-USDT
# Pulling: bittrex : BLK/BTC [62/941]
# Pulling: bittrex : BLOCK/BTC [63/941]
# Pulling: bittrex : BLOCK/USDT [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BLOCK-USDT [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BLOCK-USDT
# Pulling: bittrex : BMP/BTC [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BMP-BTC [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BMP-BTC
# Pulling: bittrex : BMP/USDT [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BMP-USDT [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BMP-USDT
# Pulling: bittrex : BNA/USDT [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BNA-USDT [64/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BNA-USDT
# Pulling: bittrex : BNT/BTC [64/941]
# Pulling: bittrex : BNT/ETH [65/941]
# Pulling: bittrex : BNT/USD [66/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BNT-USD [66/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BNT-USD
# Pulling: bittrex : BOA/BTC [66/941]
# Pulling: bittrex : BOA/USDT [67/941]
# Pulling: bittrex : BOND/ETH [68/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BOND-ETH [68/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BOND-ETH
# Pulling: bittrex : BOND/USDT [68/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BOND-USDT [68/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BOND-USDT
# Pulling: bittrex : BONDLY/USDT [68/941]
# Pulling: bittrex : BOSON/BTC [69/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BOSON-BTC [69/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BOSON-BTC
# Pulling: bittrex : BOSON/USDT [69/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BOSON-USDT [69/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BOSON-USDT
# Pulling: bittrex : BRZ/USDT [69/941]
# Pulling: bittrex : BST/USDT [70/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BST-USDT [70/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BST-USDT
# Pulling: bittrex : BSV/BTC [70/941]
# Pulling: bittrex : BSV/ETH [71/941]
# Pulling: bittrex : BSV/EUR [72/941]
# Pulling: bittrex : BSV/USD [73/941]
# Pulling: bittrex : BSV/USDT [74/941]
# Pulling: bittrex : BTBS/USDT [75/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BTBS-USDT [75/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTBS-USDT
# Pulling: bittrex : BTC/EUR [75/941]
# Pulling: bittrex : BTC/USD [76/941]
# Pulling: bittrex : BTC/USDC [77/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BTC-USDC [77/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTC-USDC
# Pulling: bittrex : BTC/USDT [77/941]
# Pulling: bittrex : BTCV/BTC [78/941]
# Pulling: bittrex : BTCV/USDT [79/941]
# Pulling: bittrex : BTD/USDT [80/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BTD-USDT [80/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTD-USDT
# Pulling: bittrex : BTRIPS/BTC [80/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BTRIPS-BTC [80/941]
# Got an error BadSymbol ('bittrex does not have market symbol BTRIPS-BTC',) , retrying in 1 seconds...
# All attempts failed, skipping: BTRIPS-BTC
# Pulling: bittrex : BTRST/USD [80/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : BTRST-USD [80/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTRST-USD
# Pulling: bittrex : BTS/BTC [80/941]
# Pulling: bittrex : BTU/BTC [81/941]
# Pulling: bittrex : CADX/BTC [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CADX-BTC [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CADX-BTC
# Pulling: bittrex : CAIZ/USDT [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CAIZ-USDT [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CAIZ-USDT
# Pulling: bittrex : CAST/USDT [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CAST-USDT [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CAST-USDT
# Pulling: bittrex : CBANK/USDT [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CBANK-USDT [82/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CBANK-USDT
# Pulling: bittrex : CBC/BTC [82/941]
# Pulling: bittrex : CDEX/USDT [83/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CDEX-USDT [83/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CDEX-USDT
# Pulling: bittrex : CEDS/USDT [83/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CEDS-USDT [83/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CEDS-USDT
# Pulling: bittrex : CEL/BTC [83/941]
# Pulling: bittrex : CEL/ETH [84/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CEL-ETH [84/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CEL-ETH
# Pulling: bittrex : CEL/USD [84/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CEL-USD [84/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CEL-USD
# Pulling: bittrex : CEL/USDT [84/941]
# Pulling: bittrex : CELO/BTC [85/941]
# Pulling: bittrex : CELO/ETH [86/941]
# Pulling: bittrex : CELO/EUR [87/941]
# Pulling: bittrex : CELO/USD [88/941]
# Pulling: bittrex : CELO/USDT [89/941]
# Pulling: bittrex : CHNG/USDT [90/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CHNG-USDT [90/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CHNG-USDT
# Pulling: bittrex : CIND/USDT [90/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CIND-USDT [90/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CIND-USDT
# Pulling: bittrex : CIV/USDT [90/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CIV-USDT [90/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CIV-USDT
# Pulling: bittrex : CKB/BTC [90/941]
# Pulling: bittrex : CKB/USD [91/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CKB-USD [91/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CKB-USD
# Pulling: bittrex : CKB/USDT [91/941]
# Pulling: bittrex : CLI/USDT [92/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CLI-USDT [92/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CLI-USDT
# Pulling: bittrex : CLT/BTC [92/941]
# Pulling: bittrex : CLT/USDT [93/941]
# Pulling: bittrex : CLXY/USDT [94/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CLXY-USDT [94/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CLXY-USDT
# Pulling: bittrex : CMCX/USDT [94/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CMCX-USDT [94/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CMCX-USDT
# Pulling: bittrex : CND/BTC [94/941]
# Pulling: bittrex : CNTM/USDT [95/941]
# Pulling: bittrex : COMP/BTC [96/941]
# Pulling: bittrex : COMP/ETH [97/941]
# Pulling: bittrex : COMP/USD [98/941]
# Pulling: bittrex : COMP/USDT [99/941]
# Pulling: bittrex : COT/BTC [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : COT-BTC [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: COT-BTC
# Pulling: bittrex : COT/ETH [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : COT-ETH [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: COT-ETH
# Pulling: bittrex : COT/USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : COT-USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: COT-USDT
# Pulling: bittrex : COVN/BTC [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : COVN-BTC [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: COVN-BTC
# Pulling: bittrex : COVN/USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : COVN-USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: COVN-USDT
# Pulling: bittrex : CRFI/USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CRFI-USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CRFI-USDT
# Pulling: bittrex : CRMC/USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CRMC-USDT [100/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CRMC-USDT
# Pulling: bittrex : CRO/BTC [100/941]
# Pulling: bittrex : CRO/ETH [101/941]
# Pulling: bittrex : CRO/EUR [102/941]
# Pulling: bittrex : CRO/USD [103/941]
# Pulling: bittrex : CRO/USDT [104/941]
# Pulling: bittrex : CRTS/USDT [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CRTS-USDT [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CRTS-USDT
# Pulling: bittrex : CRV/BTC [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CRV-BTC [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CRV-BTC
# Pulling: bittrex : CRV/ETH [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CRV-ETH [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CRV-ETH
# Pulling: bittrex : CRV/USDT [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CRV-USDT [105/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CRV-USDT
# Pulling: bittrex : CRW/BTC [105/941]
# Pulling: bittrex : CSC/USDT [106/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CSC-USDT [106/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CSC-USDT
# Pulling: bittrex : CTC/BTC [106/941]
# Pulling: bittrex : CTPL/USDT [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CTPL-USDT [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CTPL-USDT
# Pulling: bittrex : CUDOS/BTC [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CUDOS-BTC [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CUDOS-BTC
# Pulling: bittrex : CUDOS/USDT [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CUDOS-USDT [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CUDOS-USDT
# Pulling: bittrex : CURIO/USDT [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CURIO-USDT [107/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CURIO-USDT
# Pulling: bittrex : CUSD/BTC [107/941]
# Pulling: bittrex : CUSD/ETH [108/941]
# Pulling: bittrex : CUSD/USDT [109/941]
# Pulling: bittrex : CUT/BTC [110/941]
# Pulling: bittrex : CUT/USDT [111/941]
# Pulling: bittrex : CWC/BTC [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CWC-BTC [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CWC-BTC
# Pulling: bittrex : CWD/USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CWD-USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CWD-USDT
# Pulling: bittrex : CWEB/USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CWEB-USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CWEB-USDT
# Pulling: bittrex : CYCLUB/USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : CYCLUB-USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: CYCLUB-USDT
# Pulling: bittrex : DAF/USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DAF-USDT [112/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DAF-USDT
# Pulling: bittrex : DAI/BTC [112/941]
# Pulling: bittrex : DAI/ETH [113/941]
# Pulling: bittrex : DAI/USD [114/941]
# Pulling: bittrex : DAI/USDT [115/941]
# Pulling: bittrex : DASH/BTC [116/941]
# Pulling: bittrex : DASH/ETH [117/941]
# Pulling: bittrex : DASH/USD [118/941]
# Pulling: bittrex : DASH/USDT [119/941]
# Pulling: bittrex : DAWN/BTC [120/941]
# Pulling: bittrex : DCR/BTC [121/941]
# Pulling: bittrex : DCR/USD [122/941]
# Pulling: bittrex : DCR/USDT [123/941]
# Pulling: bittrex : DECE/USDT [124/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DECE-USDT [124/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DECE-USDT
# Pulling: bittrex : DEP/BTC [124/941]
# Pulling: bittrex : DEP/USDT [125/941]
# Pulling: bittrex : DEXA/USDT [126/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DEXA-USDT [126/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DEXA-USDT
# Pulling: bittrex : DFCH/BTC [126/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DFCH-BTC [126/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DFCH-BTC
# Pulling: bittrex : DFCH/USDT [126/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DFCH-USDT [126/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DFCH-USDT
# Pulling: bittrex : DFI/BTC [126/941]
# Pulling: bittrex : DFI/ETH [127/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DFI-ETH [127/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DFI-ETH
# Pulling: bittrex : DFI/EUR [127/941]
# Pulling: bittrex : DFI/USDT [128/941]
# Pulling: bittrex : DGB/BTC [129/941]
# Pulling: bittrex : DGB/ETH [130/941]
# Pulling: bittrex : DGB/EUR [131/941]
# Pulling: bittrex : DGB/USD [132/941]
# Pulling: bittrex : DGB/USDT [133/941]
# Pulling: bittrex : DMR/USDT [134/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DMR-USDT [134/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DMR-USDT
# Pulling: bittrex : DMT/BTC [134/941]
# Pulling: bittrex : DMTR/USDT [135/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DMTR-USDT [135/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DMTR-USDT
# Pulling: bittrex : DNT/BTC [135/941]
# Pulling: bittrex : DOGA/USDT [136/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DOGA-USDT [136/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DOGA-USDT
# Pulling: bittrex : DOGE/BTC [136/941]
# Pulling: bittrex : DOGE/ETH [137/941]
# Pulling: bittrex : DOGE/EUR [138/941]
# Pulling: bittrex : DOGE/USD [139/941]
# Pulling: bittrex : DOGE/USDC [140/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DOGE-USDC [140/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DOGE-USDC
# Pulling: bittrex : DOGE/USDT [140/941]
# Pulling: bittrex : DOT/BTC [141/941]
# Pulling: bittrex : DOT/ETH [142/941]
# Pulling: bittrex : DOT/EUR [143/941]
# Pulling: bittrex : DOT/USD [144/941]
# Pulling: bittrex : DOT/USDT [145/941]
# Pulling: bittrex : DRCM/USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DRCM-USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DRCM-USDT
# Pulling: bittrex : DRE/USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DRE-USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DRE-USDT
# Pulling: bittrex : DST/USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DST-USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DST-USDT
# Pulling: bittrex : DTX/ETH [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DTX-ETH [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DTX-ETH
# Pulling: bittrex : DTX/USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DTX-USDT [146/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DTX-USDT
# Pulling: bittrex : DUSK/BTC [146/941]
# Pulling: bittrex : DUSK/USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DUSK-USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DUSK-USDT
# Pulling: bittrex : DVI/USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DVI-USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DVI-USDT
# Pulling: bittrex : DVK/USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : DVK-USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: DVK-USDT
# Pulling: bittrex : EAC/USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : EAC-USDT [147/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: EAC-USDT
# Pulling: bittrex : ECELL/USDT [147/941]
# Pulling: bittrex : EDR/USDT [148/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : EDR-USDT [148/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: EDR-USDT
# Pulling: bittrex : ELA/BTC [148/941]
# Pulling: bittrex : ELA/USDT [149/941]
# Pulling: bittrex : ELT/USDT [150/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ELT-USDT [150/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ELT-USDT
# Pulling: bittrex : EMC2/BTC [150/941]
# Pulling: bittrex : ENG/BTC [151/941]
# Pulling: bittrex : ENJ/BTC [152/941]
# Pulling: bittrex : ENJ/ETH [153/941]
# Pulling: bittrex : ENJ/USD [154/941]
# Pulling: bittrex : ENJ/USDT [155/941]
# Pulling: bittrex : ENS/USDT [156/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ENS-USDT [156/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ENS-USDT
# Pulling: bittrex : EOS/BTC [156/941]
# Pulling: bittrex : EOS/ETH [157/941]
# Pulling: bittrex : EOS/USD [158/941]
# Pulling: bittrex : EOS/USDT [159/941]
# Pulling: bittrex : EPTT/USDT [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : EPTT-USDT [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: EPTT-USDT
# Pulling: bittrex : EQX/BTC [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : EQX-BTC [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: EQX-BTC
# Pulling: bittrex : EQX/ETH [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : EQX-ETH [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: EQX-ETH
# Pulling: bittrex : EQX/USDT [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : EQX-USDT [160/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: EQX-USDT
# Pulling: bittrex : ETC/BTC [160/941]
# Pulling: bittrex : ETC/ETH [161/941]
# Pulling: bittrex : ETC/USD [162/941]
# Pulling: bittrex : ETC/USDT [163/941]
# Pulling: bittrex : ETH/BTC [164/941]
# Pulling: bittrex : ETH/EUR [165/941]
# Pulling: bittrex : ETH/USD [166/941]
# Pulling: bittrex : ETH/USDC [167/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ETH-USDC [167/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ETH-USDC
# Pulling: bittrex : ETH/USDT [167/941]
# Pulling: bittrex : ETHA/USDT [168/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ETHA-USDT [168/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ETHA-USDT
# Pulling: bittrex : ETHW/USD [168/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ETHW-USD [168/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ETHW-USD
# Pulling: bittrex : ETHW/USDT [168/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ETHW-USDT [168/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ETHW-USDT
# Pulling: bittrex : ETM/USDT [168/941]
# ...
# Pulling: bittrex : XGOLD-USDT [506/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: XGOLD-USDT
# Pulling: bittrex : XLM/BTC [506/941]
# Pulling: bittrex : XLM/ETH [507/941]
# Pulling: bittrex : XLM/EUR [508/941]
# Pulling: bittrex : XLM/USD [509/941]
# Pulling: bittrex : XLM/USDT [510/941]
# Pulling: bittrex : XMY/USDT [511/941]
# Pulling: bittrex : XRP/BTC [512/941]
# Pulling: bittrex : XRP/ETH [513/941]
# Pulling: bittrex : XRP/EUR [514/941]
# Pulling: bittrex : XRP/USD [515/941]
# Pulling: bittrex : XRP/USDC [516/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : XRP-USDC [516/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: XRP-USDC
# Pulling: bittrex : XRP/USDT [516/941]
# Pulling: bittrex : XSILV/USDT [517/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : XSILV-USDT [517/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: XSILV-USDT
# Pulling: bittrex : XTP/BTC [517/941]
# Pulling: bittrex : XTP/USDT [518/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : XTP-USDT [518/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: XTP-USDT
# Pulling: bittrex : XTZ/BTC [518/941]
# Pulling: bittrex : XTZ/ETH [519/941]
# Pulling: bittrex : XTZ/USD [520/941]
# Pulling: bittrex : XTZ/USDT [521/941]
# Pulling: bittrex : XVG/BTC [522/941]
# Pulling: bittrex : XVG/ETH [523/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : XVG-ETH [523/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: XVG-ETH
# Pulling: bittrex : XVG/USDT [523/941]
# Pulling: bittrex : XWC/BTC [524/941]
# Pulling: bittrex : XWC/USDT [525/941]
# Pulling: bittrex : XYM/BTC [526/941]
# Pulling: bittrex : XYM/ETH [527/941]
# Pulling: bittrex : XYM/USDT [528/941]
# Pulling: bittrex : YEFI/USDT [529/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : YEFI-USDT [529/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: YEFI-USDT
# Pulling: bittrex : YFI/USD [529/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : YFI-USD [529/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: YFI-USD
# Pulling: bittrex : YFL/ETH [529/941]
# Pulling: bittrex : YFL/USDT [530/941]
# Pulling: bittrex : YLD/BTC [531/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : YLD-BTC [531/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: YLD-BTC
# Pulling: bittrex : YLD/USDT [531/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : YLD-USDT [531/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: YLD-USDT
# Pulling: bittrex : YOU/USDT [531/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : YOU-USDT [531/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: YOU-USDT
# Pulling: bittrex : ZEC/BTC [531/941]
# Pulling: bittrex : ZEC/ETH [532/941]
# Pulling: bittrex : ZEC/USD [533/941]
# Pulling: bittrex : ZEC/USDT [534/941]
# Pulling: bittrex : ZEN/BTC [535/941]
# Pulling: bittrex : ZEN/USD [536/941]
# Pulling: bittrex : ZEN/USDT [537/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZEN-USDT [537/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZEN-USDT
# Pulling: bittrex : ZIL/BTC [537/941]
# Pulling: bittrex : ZIL/USD [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZIL-USD [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZIL-USD
# Pulling: bittrex : ZILD/USDT [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZILD-USDT [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZILD-USDT
# Pulling: bittrex : ZK/USDT [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZK-USDT [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZK-USDT
# Pulling: bittrex : ZKP/ETH [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZKP-ETH [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZKP-ETH
# Pulling: bittrex : ZKP/USDT [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZKP-USDT [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZKP-USDT
# Pulling: bittrex : ZPTC/USDC [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: bittrex : ZPTC-USDC [538/941]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ZPTC-USDC
# Pulling: bittrex : ZRX/BTC [538/941]
# Pulling: bittrex : ZRX/ETH [539/941]
# Pulling: bittrex : ZRX/USD [540/941]
# Pulling: bittrex : ZRX/USDT [541/941]
# Pulling: bittrex : ZUSD/USDT [542/941]
# Unable to obtain: ['1ECO-BTC', '1ECO-USDT', '1INCH-USD', '1PECO-BTC', '1PECO-USDT', 'ACH-USD', 'ADA-USDC', 'AGV-USDT', 'AIN-USDT', 'AKT-BTC', 'AKT-USDT', 'AKTIO-USDT', 'ALTA-USDT', 'AMP-ETH', 'AMP-USD', 'AMP-USDT', 'ANKR-USD', 'ANT-USD', 'ANTE-USDT', 'APE-USD', 'APE-USDT', 'API3-USDT', 'APXP-USDT', 'AR-USD', 'ARDX-BTC', 'ARDX-ETH', 'ARDX-USDT', 'ARIA20-BTC', 'ARTIC-USDT', 'ARTII-BTC', 'ARV-USDT', 'ARW-USDT', 'ASM-USDT', 'ATRI-USDT', 'ATTR-USDT', 'AUDT-USDT', 'AVAX-USD', 'AVT-ETH', 'AVT-USDT', 'AXS-USD', 'AXS-USDT', 'B2M-USDT', 'BAAS-USDT', 'BADGER-USD', 'BAX-USDT', 'BBF-USDT', 'BEE-USDT', 'BERRY-USDT', 'BFC-BTC', 'BIOT-USDT', 'BIST-USDT', 'BITCI-USDT', 'BKR-USDT', 'BLOCK-USDT', 'BMP-BTC', 'BMP-USDT', 'BNA-USDT', 'BNT-USD', 'BOND-ETH', 'BOND-USDT', 'BOSON-BTC', 'BOSON-USDT', 'BST-USDT', 'BTBS-USDT', 'BTC-USDC', 'BTD-USDT', 'BTRIPS-BTC', 'BTRST-USD', 'CADX-BTC', 'CAIZ-USDT', 'CAST-USDT', 'CBANK-USDT', 'CDEX-USDT', 'CEDS-USDT', 'CEL-ETH', 'CEL-USD', 'CHNG-USDT', 'CIND-USDT', 'CIV-USDT', 'CKB-USD', 'CLI-USDT', 'CLXY-USDT', 'CMCX-USDT', 'COT-BTC', 'COT-ETH', 'COT-USDT', 'COVN-BTC', 'COVN-USDT', 'CRFI-USDT', 'CRMC-USDT', 'CRTS-USDT', 'CRV-BTC', 'CRV-ETH', 'CRV-USDT', 'CSC-USDT', 'CTPL-USDT', 'CUDOS-BTC', 'CUDOS-USDT', 'CURIO-USDT', 'CWC-BTC', 'CWD-USDT', 'CWEB-USDT', 'CYCLUB-USDT', 'DAF-USDT', 'DECE-USDT', 'DEXA-USDT', 'DFCH-BTC', 'DFCH-USDT', 'DFI-ETH', 'DMR-USDT', 'DMTR-USDT', 'DOGA-USDT', 'DOGE-USDC', 'DRCM-USDT', 'DRE-USDT', 'DST-USDT', 'DTX-ETH', 'DTX-USDT', 'DUSK-USDT', 'DVI-USDT', 'DVK-USDT', 'EAC-USDT', 'EDR-USDT', 'ELT-USDT', 'ENS-USDT', 'EPTT-USDT', 'EQX-BTC', 'EQX-ETH', 'EQX-USDT', 'ETH-USDC', 'ETHA-USDT', 'ETHW-USD', 'ETHW-USDT', 'ETM-USDT', 'EUROC-EUR', 'EUROC-USDC', 'EWC-USDT', 'EWT-USDT', 'FDM-USDT', 'FEVR-USDT', 'FIRO-USDT', 'FLIXX-USDT', 'FLR-USDT', 'FLUX-USDT', 'FNX-USDT', 'FTC-USDT', 'FTM-USD', 'FTM-USDT', 'FUSE-USDT', 'FXS-USDT', 'GALA-USD', 'GALA-USDT', 'GAZE-ETH', 'GAZE-USDT', 'GBIT-USDT', 'GBPT-BTC', 'GBPT-ETH', 'GBPT-USDC', 'GDT-USDT', 'GIGX-USDT', 'GMT Token-USDT', 'GPX-USDT', 'GPYX-BTC', 'GRNC-USDT', 'GTC-USD', 'HLM-USDT', 'HOTCROSS-USDT', 'HRTS-USD', 'HRTS-USDT', 'HTML-USDT', 'HYVE-USDT', 'ICA-USDT', 'INV-ETH', 'IOTX-USD', 'IOTX-USDT', 'IQ-USDT', 'IQO-USDT', 'JAM-USDT', 'JASMY-ETH', 'JASMY-USDT', 'JGN-USDT', 'KBH-USDT', 'KDA-USD', 'KIN-USDT', 'KLEVA-USDT', 'KSM-USD', 'KSP-USDT', 'KUSD-USDC', 'KUSD-USDT', 'LAND-USDT', 'LBL-USDT', 'LGCY-USDT', 'LPNT-USDT', 'LPT-USDT', 'LRC-USD', 'LWC-ETH', 'LWC-USDT', 'MARS4-ETH', 'MARS4-USDT', 'MATIC-ETH', 'MCCX-USDT', 'MDC-BTC', 'MF-USDT', 'MF1-USDT', 'MIM-USDT', 'MIMO-BTC', 'MINE-USDT', 'MINT-ETH', 'MINT-USDT', 'MNFT-ETH', 'MNFT-USDT', 'MODEX-ETH', 'MODEX-USDT', 'MOGX-USDT', 'MOR-USDT', 'MOV-USDT', 'MPC-USDT', 'MPLC-USDT', 'MPT-USDT', 'MQL-USDT', 'MSB-USDT', 'MTRA-USDT', 'MTS-USDT', 'MTSP-USDT', 'MVC-USDT', 'MYCE-BTC', 'MYCE-USDT', 'MYID-USDT', 'NFTX-BTC', 'NFTX-ETH', 'NFTX-USDT', 'NIFT-USDT', 'NKCLC-USDT', 'NKN-USDT', 'NPT-USDT', 'O3-ETH', 'O3-USDT', 'ONSTON-USDT', 'PAR-BTC', 'PAR-USDT', 'PAXG-USD', 'PAXG-USDT', 'PGX-USDT', 'PINK-USDT', 'PIST-USDT', 'PKR-USDT', 'PKT-BTC', 'PKT-USDT', 'PLA-BTC', 'PLA-EUR', 'PLA-USD', 'PLA-USDT', 'PLEX-USDT', 'POLC-ETH', 'POLC-USDT', 'POLL-USDT', 'POPK-USDT', 'PPAY-BTC', 'PPAY-USD', 'PPAY-USDT', 'PRMX-USDT', 'PRO-USD', 'PRO-USDC', 'PRO-USDT', 'PROM-USDT', 'PRT-USDT', 'PTOY-USDT', 'PUNDIX-BTC', 'PUNDIX-ETH', 'PUNDIX-USDT', 'PXP-USDT', 'PYR-BTC', 'PYR-USDT', 'QNT-ETH', 'QNT-USD', 'R1-USDT', 'RAD-USD', 'RAMP-BTC', 'RAMP-ETH', 'RAMP-USDT', 'REAL-BTC', 'REAL-USDT', 'RED-USDT', 'RLC-USD', 'RLY-USD', 'RNB-BTC', 'RNDR-USDT', 'ROC-USDT', 'ROOK-BTC', 'ROOK-ETH', 'ROOK-USDT', 'RTH-USDT', 'RVN-ETH', 'SAND-BTC', 'SAND-USD', 'SHIB-USD', 'SHX-BTC', 'SHX-USDT', 'SIGNA-USDT', 'SIRS-BTC', 'SIRS-USDT', 'SKL-USD', 'SKL-USDT', 'SMG-USDT', 'SML-USDT', 'SNX-USD', 'SOL-BTC', 'SOL-EUR', 'SOL-USD', 'SOL-USDT', 'SPC-USDT', 'SPWN-ETH', 'SPWN-USDT', 'SSX-BTC', 'SSX-USDT', 'STCCOIN-BTC', 'STCCOIN-USDT', 'STMX-EUR', 'STMX-USD', 'STORJ-USD', 'STRK-USD', 'STSW-USDT', 'SUS ...
# ['1ECO-BTC',
#  '1ECO-USDT',
#  '1INCH-USD',
#  '1PECO-BTC',
#  '1PECO-USDT',
#  'ACH-USD',
#  'ADA-USDC',
#  'AGV-USDT',
#  'AIN-USDT',
#  'AKT-BTC',
#  'AKT-USDT',
#  'AKTIO-USDT',
#  'ALTA-USDT',
#  'AMP-ETH',
#  'AMP-USD',
#  'AMP-USDT',
#  'ANKR-USD',
#  'ANT-USD',
#  'ANTE-USDT',
#  'APE-USD',
#  'APE-USDT',
#  'API3-USDT',
#  'APXP-USDT',
#  'AR-USD',
#  'ARDX-BTC',
#  'ARDX-ETH',
#  'ARDX-USDT',
#  'ARIA20-BTC',
#  'ARTIC-USDT',
#  'ARTII-BTC',
#  'ARV-USDT',
#  'ARW-USDT',
#  'ASM-USDT',
#  'ATRI-USDT',
#  'ATTR-USDT',
#  'AUDT-USDT',
#  'AVAX-USD',
#  'AVT-ETH',
#  'AVT-USDT',
#  'AXS-USD',
#  'AXS-USDT',
#  'B2M-USDT',
#  'BAAS-USDT',
#  'BADGER-USD',
#  'BAX-USDT',
#  'BBF-USDT',
#  'BEE-USDT',
#  'BERRY-USDT',
#  'BFC-BTC',
#  'BIOT-USDT',
#  'BIST-USDT',
#  'BITCI-USDT',
#  'BKR-USDT',
#  'BLOCK-USDT',
#  'BMP-BTC',
#  'BMP-USDT',
#  'BNA-USDT',
#  'BNT-USD',
#  'BOND-ETH',
#  'BOND-USDT',
#  'BOSON-BTC',
#  'BOSON-USDT',
#  'BST-USDT',
#  'BTBS-USDT',
#  'BTC-USDC',
#  'BTD-USDT',
#  'BTRIPS-BTC',
#  'BTRST-USD',
#  'CADX-BTC',
#  'CAIZ-USDT',
#  'CAST-USDT',
#  'CBANK-USDT',
#  'CDEX-USDT',
#  'CEDS-USDT',
#  'CEL-ETH',
#  'CEL-USD',
#  'CHNG-USDT',
#  'CIND-USDT',
#  'CIV-USDT',
#  'CKB-USD',
#  'CLI-USDT',
#  'CLXY-USDT',
#  'CMCX-USDT',
#  'COT-BTC',
#  'COT-ETH',
#  'COT-USDT',
#  'COVN-BTC',
#  'COVN-USDT',
#  'CRFI-USDT',
#  'CRMC-USDT',
#  'CRTS-USDT',
#  'CRV-BTC',
#  'CRV-ETH',
#  'CRV-USDT',
#  'CSC-USDT',
#  'CTPL-USDT',
#  'CUDOS-BTC',
#  'CUDOS-USDT',
#  'CURIO-USDT',
#  'CWC-BTC',
#  'CWD-USDT',
#  'CWEB-USDT',
#  'CYCLUB-USDT',
#  'DAF-USDT',
#  'DECE-USDT',
#  'DEXA-USDT',
#  'DFCH-BTC',
#  'DFCH-USDT',
#  'DFI-ETH',
#  'DMR-USDT',
#  'DMTR-USDT',
#  'DOGA-USDT',
#  'DOGE-USDC',
#  'DRCM-USDT',
#  'DRE-USDT',
#  'DST-USDT',
#  'DTX-ETH',
#  'DTX-USDT',
#  'DUSK-USDT',
#  'DVI-USDT',
#  'DVK-USDT',
#  'EAC-USDT',
#  'EDR-USDT',
#  'ELT-USDT',
#  'ENS-USDT',
#  'EPTT-USDT',
#  'EQX-BTC',
#  'EQX-ETH',
#  'EQX-USDT',
#  'ETH-USDC',
#  'ETHA-USDT',
#  'ETHW-USD',
#  'ETHW-USDT',
#  'ETM-USDT',
#  'EUROC-EUR',
#  'EUROC-USDC',
#  'EWC-USDT',
#  'EWT-USDT',
#  'FDM-USDT',
#  'FEVR-USDT',
#  'FIRO-USDT',
#  'FLIXX-USDT',
#  'FLR-USDT',
#  'FLUX-USDT',
#  'FNX-USDT',
#  'FTC-USDT',
#  'FTM-USD',
#  'FTM-USDT',
#  'FUSE-USDT',
#  'FXS-USDT',
#  'GALA-USD',
#  'GALA-USDT',
#  'GAZE-ETH',
#  'GAZE-USDT',
#  'GBIT-USDT',
#  'GBPT-BTC',
#  'GBPT-ETH',
#  'GBPT-USDC',
#  'GDT-USDT',
#  'GIGX-USDT',
#  'GMT Token-USDT',
#  'GPX-USDT',
#  'GPYX-BTC',
#  'GRNC-USDT',
#  'GTC-USD',
#  'HLM-USDT',
#  'HOTCROSS-USDT',
#  'HRTS-USD',
#  'HRTS-USDT',
#  'HTML-USDT',
#  'HYVE-USDT',
#  'ICA-USDT',
#  'INV-ETH',
#  'IOTX-USD',
#  'IOTX-USDT',
#  'IQ-USDT',
#  'IQO-USDT',
#  'JAM-USDT',
#  'JASMY-ETH',
#  'JASMY-USDT',
#  'JGN-USDT',
#  'KBH-USDT',
#  'KDA-USD',
#  'KIN-USDT',
#  'KLEVA-USDT',
#  'KSM-USD',
#  'KSP-USDT',
#  'KUSD-USDC',
#  'KUSD-USDT',
#  'LAND-USDT',
#  'LBL-USDT',
#  'LGCY-USDT',
#  'LPNT-USDT',
#  'LPT-USDT',
#  'LRC-USD',
#  'LWC-ETH',
#  'LWC-USDT',
#  'MARS4-ETH',
#  'MARS4-USDT',
#  'MATIC-ETH',
#  'MCCX-USDT',
#  'MDC-BTC',
#  'MF-USDT',
#  'MF1-USDT',
#  'MIM-USDT',
#  'MIMO-BTC',
#  'MINE-USDT',
#  'MINT-ETH',
#  'MINT-USDT',
#  'MNFT-ETH',
#  'MNFT-USDT',
#  'MODEX-ETH',
#  'MODEX-USDT',
#  'MOGX-USDT',
#  'MOR-USDT',
#  'MOV-USDT',
#  'MPC-USDT',
#  'MPLC-USDT',
#  'MPT-USDT',
#  'MQL-USDT',
#  'MSB-USDT',
#  'MTRA-USDT',
#  'MTS-USDT',
#  'MTSP-USDT',
#  'MVC-USDT',
#  'MYCE-BTC',
#  'MYCE-USDT',
#  'MYID-USDT',
#  'NFTX-BTC',
#  'NFTX-ETH',
#  'NFTX-USDT',
#  'NIFT-USDT',
#  'NKCLC-USDT',
#  'NKN-USDT',
#  'NPT-USDT',
#  'O3-ETH',
#  'O3-USDT',
#  'ONSTON-USDT',
#  'PAR-BTC',
#  'PAR-USDT',
#  'PAXG-USD',
#  'PAXG-USDT',
#  'PGX-USDT',
#  'PINK-USDT',
#  'PIST-USDT',
#  'PKR-USDT',
#  'PKT-BTC',
#  'PKT-USDT',
#  'PLA-BTC',
#  'PLA-EUR',
#  'PLA-USD',
#  'PLA-USDT',
#  'PLEX-USDT',
#  'POLC-ETH',
#  'POLC-USDT',
#  'POLL-USDT',
#  'POPK-USDT',
#  'PPAY-BTC',
#  'PPAY-USD',
#  'PPAY-USDT',
#  'PRMX-USDT',
#  'PRO-USD',
#  'PRO-USDC',
#  'PRO-USDT',
#  'PROM-USDT',
#  'PRT-USDT',
#  'PTOY-USDT',
#  'PUNDIX-BTC',
#  'PUNDIX-ETH',
#  'PUNDIX-USDT',
#  'PXP-USDT',
#  'PYR-BTC',
#  'PYR-USDT',
#  'QNT-ETH',
#  'QNT-USD',
#  'R1-USDT',
#  'RAD-USD',
#  'RAMP-BTC',
#  'RAMP-ETH',
#  'RAMP-USDT',
#  'REAL-BTC',
#  'REAL-USDT',
#  'RED-USDT',
#  'RLC-USD',
#  'RLY-USD',
#  'RNB-BTC',
#  'RNDR-USDT',
#  'ROC-USDT',
#  'ROOK-BTC',
#  'ROOK-ETH',
#  'ROOK-USDT',
#  'RTH-USDT',
#  'RVN-ETH',
#  'SAND-BTC',
#  'SAND-USD',
#  'SHIB-USD',
#  'SHX-BTC',
#  'SHX-USDT',
#  'SIGNA-USDT',
#  'SIRS-BTC',
#  'SIRS-USDT',
#  'SKL-USD',
#  'SKL-USDT',
#  'SMG-USDT',
#  'SML-USDT',
#  'SNX-USD',
#  'SOL-BTC',
#  'SOL-EUR',
#  'SOL-USD',
#  'SOL-USDT',
#  'SPC-USDT',
#  'SPWN-ETH',
#  'SPWN-USDT',
#  'SSX-BTC',
#  'SSX-USDT',
#  'STCCOIN-BTC',
#  'STCCOIN-USDT',
#  'STMX-EUR',
#  'STMX-USD',
#  'STORJ-USD',
#  'STRK-USD',
#  'STSW-USDT',
#  'SUSHI-BTC',
#  'SUSHI-ETH',
#  'SUSHI-EUR',
#  'SUSHI-USD',
#  'SUSHI-USDT',
#  'SYS-USDT',
#  'TCR-USDT',
#  'TEDDY-USDT',
#  'TFBX-USDT',
#  'TLM-USDT',
#  'TOKKI-USDT',
#  'TOM-USDT',
#  'TRIX-USDT',
#  'TRZ-USDT',
#  'TXA-USDT',
#  'TYB-USDT',
#  'TYC-BTC',
#  'TYC-USDT',
#  'TZBTC-BTC',
#  'TZBTC-USDT',
#  'Tokamak Network-USD',
#  'UNIX-BTC',
#  'UNIX-ETH',
#  'UNIX-USDT',
#  'USDC-EUR',
#  'USDT-USDC',
#  'UZRS-USDT',
#  'VALOR-BTC',
#  'VALOR-USDT',
#  'VCK-USDT',
#  'VEMP-USDT',
#  'VET-ETH',
#  'VET-USD',
#  'VOLTINU-USDT',
#  'VRA-ETH',
#  'VSP-ETH',
#  'VSP-USDT',
#  'VVT-USDT',
#  'WACME-ETH',
#  'WACME-USDT',
#  'WAXE-USDT',
#  'WEC-USDT',
#  'WEMIX-USDT',
#  'WSB-USDT',
#  'WSTRM-USDT',
#  'XAI-USDT',
#  'XBN-USDT',
#  'XCAD-USDT',
#  'XCF-BTC',
#  'XCF-USDT',
#  'XCN-BTC',
#  'XCN-ETH',
#  'XCN-EUR',
#  'XCN-USD',
#  'XCN-USDT',
#  'XDC-BTC',
#  'XDC-EUR',
#  'XDC-USDT',
#  'XDN-USDT',
#  'XEP-USDT',
#  'XGOLD-USDT',
#  'XRP-USDC',
#  'XSILV-USDT',
#  'XTP-USDT',
#  'XVG-ETH',
#  'YEFI-USDT',
#  'YFI-USD',
#  'YLD-BTC',
#  'YLD-USDT',
#  'YOU-USDT',
#  'ZEN-USDT',
#  'ZIL-USD',
#  'ZILD-USDT',
#  'ZK-USDT',
#  'ZKP-ETH',
#  'ZKP-USDT',
#  'ZPTC-USDC']

# %%
pull_data('kraken', from_date, numberCandles, '1h', localFolder)
# Out:
# Pulling: kraken : 1INCH/EUR [1/645]
# Pulling: kraken : 1INCH/USD [2/645]
# Pulling: kraken : AAVE/BTC [3/645]
# Pulling: kraken : AAVE/ETH [4/645]
# Pulling: kraken : AAVE/EUR [5/645]
# Pulling: kraken : AAVE/GBP [6/645]
# Pulling: kraken : AAVE/USD [7/645]
# Pulling: kraken : ACA/EUR [8/645]
# Pulling: kraken : ACA/USD [9/645]
# Pulling: kraken : ACH/EUR [10/645]
# Pulling: kraken : ACH/USD [11/645]
# Pulling: kraken : ADA/AUD [12/645]
# Pulling: kraken : ADA/BTC [13/645]
# Pulling: kraken : ADA/ETH [14/645]
# Pulling: kraken : ADA/EUR [15/645]
# Pulling: kraken : ADA/GBP [16/645]
# Pulling: kraken : ADA/USD [17/645]
# Pulling: kraken : ADA/USDT [18/645]
# Pulling: kraken : ADX/EUR [19/645]
# Pulling: kraken : ADX/USD [20/645]
# Pulling: kraken : AGLD/EUR [21/645]
# Pulling: kraken : AGLD/USD [22/645]
# Pulling: kraken : AIR/EUR [23/645]
# Pulling: kraken : AIR/USD [24/645]
# Pulling: kraken : AKT/EUR [25/645]
# Pulling: kraken : AKT/USD [26/645]
# Pulling: kraken : ALCX/EUR [27/645]
# Pulling: kraken : ALCX/USD [28/645]
# Pulling: kraken : ALGO/BTC [29/645]
# Pulling: kraken : ALGO/ETH [30/645]
# Pulling: kraken : ALGO/EUR [31/645]
# Pulling: kraken : ALGO/GBP [32/645]
# Pulling: kraken : ALGO/USD [33/645]
# Pulling: kraken : ALGO/USDT [34/645]
# Pulling: kraken : ALICE/EUR [35/645]
# Pulling: kraken : ALICE/USD [36/645]
# Pulling: kraken : ALPHA/EUR [37/645]
# Pulling: kraken : ALPHA/USD [38/645]
# Pulling: kraken : ANKR/BTC [39/645]
# Pulling: kraken : ANKR/EUR [40/645]
# Pulling: kraken : ANKR/USD [41/645]
# Pulling: kraken : ANT/BTC [42/645]
# Pulling: kraken : ANT/ETH [43/645]
# Pulling: kraken : ANT/EUR [44/645]
# Pulling: kraken : ANT/USD [45/645]
# Pulling: kraken : APE/EUR [46/645]
# Pulling: kraken : APE/USD [47/645]
# Pulling: kraken : APE/USDT [48/645]
# Pulling: kraken : API3/EUR [49/645]
# Pulling: kraken : API3/USD [50/645]
# Pulling: kraken : APT/EUR [51/645]
# Pulling: kraken : APT/USD [52/645]
# Pulling: kraken : ARB/EUR [53/645]
# Pulling: kraken : ARB/USD [54/645]
# Pulling: kraken : ARPA/EUR [55/645]
# Pulling: kraken : ARPA/USD [56/645]
# Pulling: kraken : ASTR/EUR [57/645]
# Pulling: kraken : ASTR/USD [58/645]
# Pulling: kraken : ATLAS/EUR [59/645]
# Pulling: kraken : ATLAS/USD [60/645]
# Pulling: kraken : ATOM/BTC [61/645]
# Pulling: kraken : ATOM/ETH [62/645]
# Pulling: kraken : ATOM/EUR [63/645]
# Pulling: kraken : ATOM/GBP [64/645]
# Pulling: kraken : ATOM/USD [65/645]
# Pulling: kraken : ATOM/USDT [66/645]
# Pulling: kraken : AUD/JPY [67/645]
# Pulling: kraken : AUD/USD [68/645]
# Pulling: kraken : AUDIO/EUR [69/645]
# Pulling: kraken : AUDIO/USD [70/645]
# Pulling: kraken : AVAX/EUR [71/645]
# Pulling: kraken : AVAX/USD [72/645]
# Pulling: kraken : AVAX/USDT [73/645]
# Pulling: kraken : AXS/EUR [74/645]
# Pulling: kraken : AXS/USD [75/645]
# Pulling: kraken : BADGER/EUR [76/645]
# Pulling: kraken : BADGER/USD [77/645]
# Pulling: kraken : BAL/BTC [78/645]
# Pulling: kraken : BAL/EUR [79/645]
# Pulling: kraken : BAL/USD [80/645]
# Pulling: kraken : BAND/EUR [81/645]
# Pulling: kraken : BAND/USD [82/645]
# Pulling: kraken : BAT/BTC [83/645]
# Pulling: kraken : BAT/ETH [84/645]
# Pulling: kraken : BAT/EUR [85/645]
# Pulling: kraken : BAT/JPY [86/645]
# Pulling: kraken : BAT/USD [87/645]
# Pulling: kraken : BCH/AUD [88/645]
# Pulling: kraken : BCH/BTC [89/645]
# Pulling: kraken : BCH/ETH [90/645]
# Pulling: kraken : BCH/EUR [91/645]
# Pulling: kraken : BCH/GBP [92/645]
# Pulling: kraken : BCH/JPY [93/645]
# Pulling: kraken : BCH/USD [94/645]
# Pulling: kraken : BCH/USDT [95/645]
# Pulling: kraken : BICO/EUR [96/645]
# Pulling: kraken : BICO/USD [97/645]
# Pulling: kraken : BIT/EUR [98/645]
# Pulling: kraken : BIT/USD [99/645]
# Pulling: kraken : BLUR/EUR [100/645]
# Pulling: kraken : BLUR/USD [101/645]
# Pulling: kraken : BLZ/EUR [102/645]
# Pulling: kraken : BLZ/USD [103/645]
# Pulling: kraken : BNC/EUR [104/645]
# Pulling: kraken : BNC/USD [105/645]
# Pulling: kraken : BNT/BTC [106/645]
# Pulling: kraken : BNT/EUR [107/645]
# Pulling: kraken : BNT/USD [108/645]
# Pulling: kraken : BOBA/EUR [109/645]
# Pulling: kraken : BOBA/USD [110/645]
# Pulling: kraken : BOND/EUR [111/645]
# Pulling: kraken : BOND/USD [112/645]
# Pulling: kraken : BSX/EUR [113/645]
# Pulling: kraken : BSX/USD [114/645]
# Pulling: kraken : BTC/AED [115/645]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kraken : BTC-AED [115/645]
# Got an error BadSymbol ('kraken does not have market symbol BTC-AED',) , retrying in 1 seconds...
# All attempts failed, skipping: BTC-AED
# Pulling: kraken : BTC/AUD [115/645]
# Pulling: kraken : BTC/CAD [116/645]
# Pulling: kraken : BTC/CHF [117/645]
# Pulling: kraken : BTC/DAI [118/645]
# Pulling: kraken : BTC/EUR [119/645]
# Pulling: kraken : BTC/GBP [120/645]
# Pulling: kraken : BTC/JPY [121/645]
# Pulling: kraken : BTC/USD [122/645]
# Pulling: kraken : BTC/USDC [123/645]
# Pulling: kraken : BTC/USDT [124/645]
# Pulling: kraken : BTT/EUR [125/645]
# Pulling: kraken : BTT/USD [126/645]
# Pulling: kraken : C98/EUR [127/645]
# Pulling: kraken : C98/USD [128/645]
# Pulling: kraken : CELR/EUR [129/645]
# Pulling: kraken : CELR/USD [130/645]
# Pulling: kraken : CFG/EUR [131/645]
# Pulling: kraken : CFG/USD [132/645]
# Pulling: kraken : CHR/EUR [133/645]
# Pulling: kraken : CHR/USD [134/645]
# Pulling: kraken : CHZ/EUR [135/645]
# Pulling: kraken : CHZ/USD [136/645]
# Pulling: kraken : COMP/BTC [137/645]
# Pulling: kraken : COMP/EUR [138/645]
# Pulling: kraken : COMP/USD [139/645]
# Pulling: kraken : COTI/EUR [140/645]
# Pulling: kraken : COTI/USD [141/645]
# Pulling: kraken : CQT/EUR [142/645]
# Pulling: kraken : CQT/USD [143/645]
# Pulling: kraken : CRV/BTC [144/645]
# Pulling: kraken : CRV/ETH [145/645]
# Pulling: kraken : CRV/EUR [146/645]
# Pulling: kraken : CRV/USD [147/645]
# Pulling: kraken : CSM/EUR [148/645]
# Pulling: kraken : CSM/USD [149/645]
# Pulling: kraken : CTSI/EUR [150/645]
# Pulling: kraken : CTSI/USD [151/645]
# Pulling: kraken : CVC/EUR [152/645]
# Pulling: kraken : CVC/USD [153/645]
# Pulling: kraken : CVX/EUR [154/645]
# Pulling: kraken : CVX/USD [155/645]
# Pulling: kraken : DAI/EUR [156/645]
# Pulling: kraken : DAI/USD [157/645]
# Pulling: kraken : DAI/USDT [158/645]
# Pulling: kraken : DASH/BTC [159/645]
# Pulling: kraken : DASH/EUR [160/645]
# Pulling: kraken : DASH/USD [161/645]
# Pulling: kraken : DENT/EUR [162/645]
# Pulling: kraken : DENT/USD [163/645]
# Pulling: kraken : DOGE/BTC [164/645]
# Pulling: kraken : DOGE/EUR [165/645]
# Pulling: kraken : DOGE/USD [166/645]
# Pulling: kraken : DOGE/USDT [167/645]
# Pulling: kraken : DOT/BTC [168/645]
# Pulling: kraken : DOT/ETH [169/645]
# Pulling: kraken : DOT/EUR [170/645]
# Pulling: kraken : DOT/GBP [171/645]
# Pulling: kraken : DOT/JPY [172/645]
# Pulling: kraken : DOT/USD [173/645]
# Pulling: kraken : DOT/USDT [174/645]
# Pulling: kraken : DYDX/EUR [175/645]
# Pulling: kraken : DYDX/USD [176/645]
# Pulling: kraken : EGLD/EUR [177/645]
# Pulling: kraken : EGLD/USD [178/645]
# Pulling: kraken : ENJ/BTC [179/645]
# Pulling: kraken : ENJ/EUR [180/645]
# Pulling: kraken : ENJ/GBP [181/645]
# Pulling: kraken : ENJ/JPY [182/645]
# Pulling: kraken : ENJ/USD [183/645]
# Pulling: kraken : ENS/EUR [184/645]
# Pulling: kraken : ENS/USD [185/645]
# Pulling: kraken : EOS/BTC [186/645]
# Pulling: kraken : EOS/ETH [187/645]
# Pulling: kraken : EOS/EUR [188/645]
# Pulling: kraken : EOS/USD [189/645]
# Pulling: kraken : EOS/USDT [190/645]
# Pulling: kraken : ETC/BTC [191/645]
# Pulling: kraken : ETC/ETH [192/645]
# Pulling: kraken : ETC/EUR [193/645]
# Pulling: kraken : ETC/USD [194/645]
# Pulling: kraken : ETH/AED [195/645]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kraken : ETH-AED [195/645]
# Got an error BadSymbol ('kraken does not have market symbol ETH-AED',) , retrying in 1 seconds...
# All attempts failed, skipping: ETH-AED
# Pulling: kraken : ETH/AUD [195/645]
# Pulling: kraken : ETH/BTC [196/645]
# Pulling: kraken : ETH/CAD [197/645]
# Pulling: kraken : ETH/CHF [198/645]
# Pulling: kraken : ETH/DAI [199/645]
# Pulling: kraken : ETH/EUR [200/645]
# Pulling: kraken : ETH/GBP [201/645]
# Pulling: kraken : ETH/JPY [202/645]
# Pulling: kraken : ETH/USD [203/645]
# Pulling: kraken : ETH/USDC [204/645]
# Pulling: kraken : ETH/USDT [205/645]
# Pulling: kraken : ETH2.S/ETH [206/645]
# Pulling: kraken : ETHW/ETH [207/645]
# Pulling: kraken : ETHW/EUR [208/645]
# Pulling: kraken : ETHW/USD [209/645]
# Pulling: kraken : EUL/EUR [210/645]
# Pulling: kraken : EUL/USD [211/645]
# Pulling: kraken : EUR/AUD [212/645]
# Pulling: kraken : EUR/CAD [213/645]
# Pulling: kraken : EUR/CHF [214/645]
# Pulling: kraken : EUR/GBP [215/645]
# Pulling: kraken : EUR/JPY [216/645]
# Pulling: kraken : EUR/USD [217/645]
# Pulling: kraken : EWT/BTC [218/645]
# Pulling: kraken : EWT/EUR [219/645]
# Pulling: kraken : EWT/GBP [220/645]
# Pulling: kraken : EWT/USD [221/645]
# Pulling: kraken : FARM/EUR [222/645]
# Pulling: kraken : FARM/USD [223/645]
# Pulling: kraken : FET/EUR [224/645]
# Pulling: kraken : FET/USD [225/645]
# Pulling: kraken : FIDA/EUR [226/645]
# Pulling: kraken : FIDA/USD [227/645]
# Pulling: kraken : FIL/BTC [228/645]
# Pulling: kraken : FIL/ETH [229/645]
# Pulling: kraken : FIL/EUR [230/645]
# Pulling: kraken : FIL/GBP [231/645]
# Pulling: kraken : FIL/USD [232/645]
# Pulling: kraken : FIS/EUR [233/645]
# Pulling: kraken : FIS/USD [234/645]
# Pulling: kraken : FLOW/BTC [235/645]
# Pulling: kraken : FLOW/ETH [236/645]
# Pulling: kraken : FLOW/EUR [237/645]
# Pulling: kraken : FLOW/GBP [238/645]
# Pulling: kraken : FLOW/USD [239/645]
# Pulling: kraken : FLR/EUR [240/645]
# Pulling: kraken : FLR/USD [241/645]
# Pulling: kraken : FORTH/EUR [242/645]
# Pulling: kraken : FORTH/USD [243/645]
# Pulling: kraken : FTM/EUR [244/645]
# Pulling: kraken : FTM/USD [245/645]
# Pulling: kraken : FXS/EUR [246/645]
# Pulling: kraken : FXS/USD [247/645]
# Pulling: kraken : GAL/EUR [248/645]
# Pulling: kraken : GAL/USD [249/645]
# Pulling: kraken : GALA/EUR [250/645]
# Pulling: kraken : GALA/USD [251/645]
# Pulling: kraken : GARI/EUR [252/645]
# Pulling: kraken : GARI/USD [253/645]
# Pulling: kraken : GBP/USD [254/645]
# Pulling: kraken : GHST/BTC [255/645]
# Pulling: kraken : GHST/EUR [256/645]
# Pulling: kraken : GHST/USD [257/645]
# Pulling: kraken : GLMR/EUR [258/645]
# Pulling: kraken : GLMR/USD [259/645]
# Pulling: kraken : GMT/EUR [260/645]
# Pulling: kraken : GMT/USD [261/645]
# Pulling: kraken : GMX/EUR [262/645]
# Pulling: kraken : GMX/USD [263/645]
# Pulling: kraken : GNO/BTC [264/645]
# Pulling: kraken : GNO/EUR [265/645]
# Pulling: kraken : GNO/USD [266/645]
# Pulling: kraken : GRT/BTC [267/645]
# Pulling: kraken : GRT/EUR [268/645]
# Pulling: kraken : GRT/GBP [269/645]
# Pulling: kraken : GRT/USD [270/645]
# Pulling: kraken : GST/EUR [271/645]
# Pulling: kraken : GST/USD [272/645]
# Pulling: kraken : GTC/EUR [273/645]
# Pulling: kraken : GTC/USD [274/645]
# Pulling: kraken : HDX/EUR [275/645]
# Pulling: kraken : HDX/USD [276/645]
# Pulling: kraken : HFT/EUR [277/645]
# Pulling: kraken : HFT/USD [278/645]
# Pulling: kraken : ICP/EUR [279/645]
# Pulling: kraken : ICP/USD [280/645]
# Pulling: kraken : ICX/BTC [281/645]
# Pulling: kraken : ICX/ETH [282/645]
# Pulling: kraken : ICX/EUR [283/645]
# Pulling: kraken : ICX/USD [284/645]
# Pulling: kraken : IDEX/EUR [285/645]
# Pulling: kraken : IDEX/USD [286/645]
# Pulling: kraken : IMX/EUR [287/645]
# Pulling: kraken : IMX/USD [288/645]
# Pulling: kraken : INJ/EUR [289/645]
# Pulling: kraken : INJ/USD [290/645]
# Pulling: kraken : INTR/EUR [291/645]
# Pulling: kraken : INTR/USD [292/645]
# Pulling: kraken : JASMY/EUR [293/645]
# Pulling: kraken : JASMY/USD [294/645]
# Pulling: kraken : JUNO/EUR [295/645]
# Pulling: kraken : JUNO/USD [296/645]
# Pulling: kraken : KAR/EUR [297/645]
# Pulling: kraken : KAR/USD [298/645]
# Pulling: kraken : KAVA/BTC [299/645]
# Pulling: kraken : KAVA/ETH [300/645]
# Pulling: kraken : KAVA/EUR [301/645]
# Pulling: kraken : KAVA/USD [302/645]
# Pulling: kraken : KEEP/BTC [303/645]
# Pulling: kraken : KEEP/EUR [304/645]
# Pulling: kraken : KEEP/USD [305/645]
# Pulling: kraken : KEY/EUR [306/645]
# Pulling: kraken : KEY/USD [307/645]
# Pulling: kraken : KILT/EUR [308/645]
# Pulling: kraken : KILT/USD [309/645]
# Pulling: kraken : KIN/EUR [310/645]
# Pulling: kraken : KIN/USD [311/645]
# Pulling: kraken : KINT/EUR [312/645]
# Pulling: kraken : KINT/USD [313/645]
# Pulling: kraken : KNC/BTC [314/645]
# Pulling: kraken : KNC/ETH [315/645]
# Pulling: kraken : KNC/EUR [316/645]
# Pulling: kraken : KNC/USD [317/645]
# Pulling: kraken : KP3R/EUR [318/645]
# Pulling: kraken : KP3R/USD [319/645]
# Pulling: kraken : KSM/BTC [320/645]
# Pulling: kraken : KSM/DOT [321/645]
# Pulling: kraken : KSM/ETH [322/645]
# Pulling: kraken : KSM/EUR [323/645]
# Pulling: kraken : KSM/GBP [324/645]
# Pulling: kraken : KSM/USD [325/645]
# Pulling: kraken : LCX/EUR [326/645]
# Pulling: kraken : LCX/USD [327/645]
# Pulling: kraken : LDO/EUR [328/645]
# Pulling: kraken : LDO/USD [329/645]
# Pulling: kraken : LINK/AUD [330/645]
# Pulling: kraken : LINK/BTC [331/645]
# Pulling: kraken : LINK/ETH [332/645]
# Pulling: kraken : LINK/EUR [333/645]
# Pulling: kraken : LINK/GBP [334/645]
# Pulling: kraken : LINK/JPY [335/645]
# Pulling: kraken : LINK/USD [336/645]
# Pulling: kraken : LINK/USDT [337/645]
# Pulling: kraken : LPT/BTC [338/645]
# Pulling: kraken : LPT/EUR [339/645]
# Pulling: kraken : LPT/GBP [340/645]
# Pulling: kraken : LPT/USD [341/645]
# Pulling: kraken : LRC/EUR [342/645]
# Pulling: kraken : LRC/USD [343/645]
# Pulling: kraken : LSK/BTC [344/645]
# Pulling: kraken : LSK/ETH [345/645]
# Pulling: kraken : LSK/EUR [346/645]
# Pulling: kraken : LSK/USD [347/645]
# Pulling: kraken : LTC/AUD [348/645]
# Pulling: kraken : LTC/BTC [349/645]
# Pulling: kraken : LTC/ETH [350/645]
# Pulling: kraken : LTC/EUR [351/645]
# Pulling: kraken : LTC/GBP [352/645]
# Pulling: kraken : LTC/JPY [353/645]
# Pulling: kraken : LTC/USD [354/645]
# Pulling: kraken : LTC/USDT [355/645]
# Pulling: kraken : LUNA/EUR [356/645]
# Pulling: kraken : LUNA/USD [357/645]
# Pulling: kraken : LUNC/EUR [358/645]
# Pulling: kraken : LUNC/USD [359/645]
# Pulling: kraken : MANA/BTC [360/645]
# Pulling: kraken : MANA/ETH [361/645]
# Pulling: kraken : MANA/EUR [362/645]
# Pulling: kraken : MANA/USD [363/645]
# Pulling: kraken : MANA/USDT [364/645]
# Pulling: kraken : MASK/EUR [365/645]
# Pulling: kraken : MASK/USD [366/645]
# Pulling: kraken : MATIC/BTC [367/645]
# Pulling: kraken : MATIC/EUR [368/645]
# Pulling: kraken : MATIC/GBP [369/645]
# Pulling: kraken : MATIC/USD [370/645]
# Pulling: kraken : MATIC/USDT [371/645]
# Pulling: kraken : MC/EUR [372/645]
# Pulling: kraken : MC/USD [373/645]
# Pulling: kraken : MINA/BTC [374/645]
# Pulling: kraken : MINA/EUR [375/645]
# Pulling: kraken : MINA/GBP [376/645]
# Pulling: kraken : MINA/USD [377/645]
# Pulling: kraken : MIR/EUR [378/645]
# Pulling: kraken : MIR/USD [379/645]
# Pulling: kraken : MKR/BTC [380/645]
# Pulling: kraken : MKR/EUR [381/645]
# Pulling: kraken : MKR/USD [382/645]
# Pulling: kraken : MLN/BTC [383/645]
# Pulling: kraken : MLN/ETH [384/645]
# Pulling: kraken : MLN/EUR [385/645]
# Pulling: kraken : MLN/USD [386/645]
# Pulling: kraken : MNGO/EUR [387/645]
# Pulling: kraken : MNGO/USD [388/645]
# Pulling: kraken : MOVR/EUR [389/645]
# Pulling: kraken : MOVR/USD [390/645]
# Pulling: kraken : MSOL/EUR [391/645]
# Pulling: kraken : MSOL/USD [392/645]
# Pulling: kraken : MULTI/EUR [393/645]
# Pulling: kraken : MULTI/USD [394/645]
# Pulling: kraken : MV/EUR [395/645]
# Pulling: kraken : MV/USD [396/645]
# Pulling: kraken : MXC/EUR [397/645]
# Pulling: kraken : MXC/USD [398/645]
# Pulling: kraken : NANO/BTC [399/645]
# Pulling: kraken : NANO/ETH [400/645]
# Pulling: kraken : NANO/EUR [401/645]
# Pulling: kraken : NANO/USD [402/645]
# Pulling: kraken : NEAR/EUR [403/645]
# Pulling: kraken : NEAR/USD [404/645]
# Pulling: kraken : NMR/EUR [405/645]
# Pulling: kraken : NMR/USD [406/645]
# Pulling: kraken : NODL/EUR [407/645]
# Pulling: kraken : NODL/USD [408/645]
# Pulling: kraken : NYM/BTC [409/645]
# Pulling: kraken : NYM/EUR [410/645]
# Pulling: kraken : NYM/USD [411/645]
# Pulling: kraken : OCEAN/BTC [412/645]
# Pulling: kraken : OCEAN/EUR [413/645]
# Pulling: kraken : OCEAN/GBP [414/645]
# Pulling: kraken : OCEAN/USD [415/645]
# Pulling: kraken : OGN/EUR [416/645]
# Pulling: kraken : OGN/USD [417/645]
# Pulling: kraken : OMG/BTC [418/645]
# Pulling: kraken : OMG/ETH [419/645]
# Pulling: kraken : OMG/EUR [420/645]
# Pulling: kraken : OMG/JPY [421/645]
# Pulling: kraken : OMG/USD [422/645]
# Pulling: kraken : ORCA/EUR [423/645]
# Pulling: kraken : ORCA/USD [424/645]
# Pulling: kraken : OXT/BTC [425/645]
# Pulling: kraken : OXT/EUR [426/645]
# Pulling: kraken : OXT/USD [427/645]
# Pulling: kraken : OXY/EUR [428/645]
# Pulling: kraken : OXY/USD [429/645]
# Pulling: kraken : PARA/EUR [430/645]
# Pulling: kraken : PARA/USD [431/645]
# Pulling: kraken : PAXG/BTC [432/645]
# Pulling: kraken : PAXG/ETH [433/645]
# Pulling: kraken : PAXG/EUR [434/645]
# Pulling: kraken : PAXG/USD [435/645]
# Pulling: kraken : PERP/EUR [436/645]
# Pulling: kraken : PERP/USD [437/645]
# Pulling: kraken : PHA/EUR [438/645]
# Pulling: kraken : PHA/USD [439/645]
# Pulling: kraken : PLA/EUR [440/645]
# Pulling: kraken : PLA/USD [441/645]
# Pulling: kraken : POLIS/EUR [442/645]
# Pulling: kraken : POLIS/USD [443/645]
# Pulling: kraken : POLS/EUR [444/645]
# Pulling: kraken : POLS/USD [445/645]
# Pulling: kraken : POND/EUR [446/645]
# Pulling: kraken : POND/USD [447/645]
# Pulling: kraken : POWR/EUR [448/645]
# Pulling: kraken : POWR/USD [449/645]
# Pulling: kraken : PSTAKE/EUR [450/645]
# Pulling: kraken : PSTAKE/USD [451/645]
# Pulling: kraken : QNT/EUR [452/645]
# Pulling: kraken : QNT/USD [453/645]
# Pulling: kraken : QTUM/BTC [454/645]
# Pulling: kraken : QTUM/ETH [455/645]
# Pulling: kraken : QTUM/EUR [456/645]
# Pulling: kraken : QTUM/USD [457/645]
# Pulling: kraken : RAD/EUR [458/645]
# Pulling: kraken : RAD/USD [459/645]
# Pulling: kraken : RARE/EUR [460/645]
# Pulling: kraken : RARE/USD [461/645]
# Pulling: kraken : RARI/BTC [462/645]
# Pulling: kraken : RARI/EUR [463/645]
# Pulling: kraken : RARI/USD [464/645]
# Pulling: kraken : RAY/EUR [465/645]
# Pulling: kraken : RAY/USD [466/645]
# Pulling: kraken : RBC/EUR [467/645]
# Pulling: kraken : RBC/USD [468/645]
# Pulling: kraken : REN/BTC [469/645]
# Pulling: kraken : REN/EUR [470/645]
# Pulling: kraken : REN/USD [471/645]
# Pulling: kraken : REP/BTC [472/645]
# Pulling: kraken : REP/ETH [473/645]
# Pulling: kraken : REP/EUR [474/645]
# Pulling: kraken : REP/USD [475/645]
# Pulling: kraken : REPV1/BTC [476/645]
# Pulling: kraken : REPV1/EUR [477/645]
# Pulling: kraken : REPV1/USD [478/645]
# Pulling: kraken : REQ/EUR [479/645]
# Pulling: kraken : REQ/USD [480/645]
# Pulling: kraken : RLC/EUR [481/645]
# Pulling: kraken : RLC/USD [482/645]
# Pulling: kraken : RNDR/EUR [483/645]
# Pulling: kraken : RNDR/USD [484/645]
# Pulling: kraken : ROOK/EUR [485/645]
# Pulling: kraken : ROOK/USD [486/645]
# Pulling: kraken : RPL/EUR [487/645]
# Pulling: kraken : RPL/USD [488/645]
# Pulling: kraken : RUNE/EUR [489/645]
# Pulling: kraken : RUNE/USD [490/645]
# Pulling: kraken : SAMO/EUR [491/645]
# Pulling: kraken : SAMO/USD [492/645]
# Pulling: kraken : SAND/BTC [493/645]
# Pulling: kraken : SAND/EUR [494/645]
# Pulling: kraken : SAND/GBP [495/645]
# Pulling: kraken : SAND/USD [496/645]
# Pulling: kraken : SBR/EUR [497/645]
# Pulling: kraken : SBR/USD [498/645]
# Pulling: kraken : SC/BTC [499/645]
# Pulling: kraken : SC/ETH [500/645]
# Pulling: kraken : SC/EUR [501/645]
# Pulling: kraken : SC/USD [502/645]
# Pulling: kraken : SCRT/EUR [503/645]
# Pulling: kraken : SCRT/USD [504/645]
# Pulling: kraken : SDN/EUR [505/645]
# Pulling: kraken : SDN/USD [506/645]
# Pulling: kraken : SGB/EUR [507/645]
# Pulling: kraken : SGB/USD [508/645]
# Pulling: kraken : SHIB/EUR [509/645]
# Pulling: kraken : SHIB/USD [510/645]
# Pulling: kraken : SHIB/USDT [511/645]
# Pulling: kraken : SNX/BTC [512/645]
# Pulling: kraken : SNX/ETH [513/645]
# Pulling: kraken : SNX/EUR [514/645]
# Pulling: kraken : SNX/USD [515/645]
# Pulling: kraken : SOL/BTC [516/645]
# Pulling: kraken : SOL/EUR [517/645]
# Pulling: kraken : SOL/GBP [518/645]
# Pulling: kraken : SOL/USD [519/645]
# Pulling: kraken : SOL/USDT [520/645]
# Pulling: kraken : SPELL/EUR [521/645]
# Pulling: kraken : SPELL/USD [522/645]
# Pulling: kraken : SRM/BTC [523/645]
# Pulling: kraken : SRM/EUR [524/645]
# Pulling: kraken : SRM/USD [525/645]
# Pulling: kraken : STEP/EUR [526/645]
# Pulling: kraken : STEP/USD [527/645]
# Pulling: kraken : STG/EUR [528/645]
# Pulling: kraken : STG/USD [529/645]
# Pulling: kraken : STORJ/BTC [530/645]
# Pulling: kraken : STORJ/EUR [531/645]
# Pulling: kraken : STORJ/USD [532/645]
# Pulling: kraken : STX/EUR [533/645]
# Pulling: kraken : STX/USD [534/645]
# Pulling: kraken : SUPER/EUR [535/645]
# Pulling: kraken : SUPER/USD [536/645]
# Pulling: kraken : SUSHI/BTC [537/645]
# Pulling: kraken : SUSHI/EUR [538/645]
# Pulling: kraken : SUSHI/GBP [539/645]
# Pulling: kraken : SUSHI/USD [540/645]
# Pulling: kraken : SYN/EUR [541/645]
# Pulling: kraken : SYN/USD [542/645]
# Pulling: kraken : T/EUR [543/645]
# Pulling: kraken : T/USD [544/645]
# Pulling: kraken : TBTC/BTC [545/645]
# Pulling: kraken : TBTC/EUR [546/645]
# Pulling: kraken : TBTC/USD [547/645]
# Pulling: kraken : TEER/EUR [548/645]
# Pulling: kraken : TEER/USD [549/645]
# Pulling: kraken : TLM/EUR [550/645]
# Pulling: kraken : TLM/USD [551/645]
# Pulling: kraken : TOKE/EUR [552/645]
# Pulling: kraken : TOKE/USD [553/645]
# Pulling: kraken : TRIBE/EUR [554/645]
# Pulling: kraken : TRIBE/USD [555/645]
# Pulling: kraken : TRU/EUR [556/645]
# Pulling: kraken : TRU/USD [557/645]
# Pulling: kraken : TRX/BTC [558/645]
# Pulling: kraken : TRX/ETH [559/645]
# Pulling: kraken : TRX/EUR [560/645]
# Pulling: kraken : TRX/USD [561/645]
# Pulling: kraken : TVK/EUR [562/645]
# Pulling: kraken : TVK/USD [563/645]
# Pulling: kraken : UMA/EUR [564/645]
# Pulling: kraken : UMA/USD [565/645]
# Pulling: kraken : UNFI/EUR [566/645]
# Pulling: kraken : UNFI/USD [567/645]
# Pulling: kraken : UNI/BTC [568/645]
# Pulling: kraken : UNI/ETH [569/645]
# Pulling: kraken : UNI/EUR [570/645]
# Pulling: kraken : UNI/USD [571/645]
# Pulling: kraken : USD/AED [572/645]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kraken : USD-AED [572/645]
# Got an error BadSymbol ('kraken does not have market symbol USD-AED',) , retrying in 1 seconds...
# All attempts failed, skipping: USD-AED
# Pulling: kraken : USD/CAD [572/645]
# Pulling: kraken : USD/CHF [573/645]
# Pulling: kraken : USD/JPY [574/645]
# Pulling: kraken : USDC/AUD [575/645]
# Pulling: kraken : USDC/CAD [576/645]
# Pulling: kraken : USDC/CHF [577/645]
# Pulling: kraken : USDC/EUR [578/645]
# Pulling: kraken : USDC/GBP [579/645]
# Pulling: kraken : USDC/USD [580/645]
# Pulling: kraken : USDC/USDT [581/645]
# Pulling: kraken : USDT/AUD [582/645]
# Pulling: kraken : USDT/CAD [583/645]
# Pulling: kraken : USDT/CHF [584/645]
# Pulling: kraken : USDT/EUR [585/645]
# Pulling: kraken : USDT/GBP [586/645]
# Pulling: kraken : USDT/JPY [587/645]
# Pulling: kraken : USDT/USD [588/645]
# Pulling: kraken : USTC/EUR [589/645]
# Pulling: kraken : USTC/USD [590/645]
# Pulling: kraken : USTC/USDC [591/645]
# Pulling: kraken : USTC/USDT [592/645]
# Pulling: kraken : WAVES/BTC [593/645]
# Pulling: kraken : WAVES/ETH [594/645]
# Pulling: kraken : WAVES/EUR [595/645]
# Pulling: kraken : WAVES/USD [596/645]
# Pulling: kraken : WAXL/EUR [597/645]
# Pulling: kraken : WAXL/USD [598/645]
# Pulling: kraken : WBTC/BTC [599/645]
# Pulling: kraken : WBTC/EUR [600/645]
# Pulling: kraken : WBTC/USD [601/645]
# Pulling: kraken : WOO/EUR [602/645]
# Pulling: kraken : WOO/USD [603/645]
# Pulling: kraken : XCN/EUR [604/645]
# Pulling: kraken : XCN/USD [605/645]
# Pulling: kraken : XLM/BTC [606/645]
# Pulling: kraken : XLM/EUR [607/645]
# Pulling: kraken : XLM/GBP [608/645]
# Pulling: kraken : XLM/USD [609/645]
# Pulling: kraken : XMR/BTC [610/645]
# Pulling: kraken : XMR/EUR [611/645]
# Pulling: kraken : XMR/USD [612/645]
# Pulling: kraken : XMR/USDT [613/645]
# Pulling: kraken : XRP/AUD [614/645]
# Pulling: kraken : XRP/BTC [615/645]
# Pulling: kraken : XRP/CAD [616/645]
# Pulling: kraken : XRP/ETH [617/645]
# Pulling: kraken : XRP/EUR [618/645]
# Pulling: kraken : XRP/GBP [619/645]
# Pulling: kraken : XRP/JPY [620/645]
# Pulling: kraken : XRP/USD [621/645]
# Pulling: kraken : XRP/USDT [622/645]
# Pulling: kraken : XRT/EUR [623/645]
# Pulling: kraken : XRT/USD [624/645]
# Pulling: kraken : XTZ/AUD [625/645]
# Pulling: kraken : XTZ/BTC [626/645]
# Pulling: kraken : XTZ/ETH [627/645]
# Pulling: kraken : XTZ/EUR [628/645]
# Pulling: kraken : XTZ/GBP [629/645]
# Pulling: kraken : XTZ/USD [630/645]
# Pulling: kraken : XTZ/USDT [631/645]
# Pulling: kraken : YFI/BTC [632/645]
# Pulling: kraken : YFI/EUR [633/645]
# Pulling: kraken : YFI/USD [634/645]
# Pulling: kraken : YGG/EUR [635/645]
# Pulling: kraken : YGG/USD [636/645]
# Pulling: kraken : ZEC/BTC [637/645]
# Pulling: kraken : ZEC/EUR [638/645]
# Pulling: kraken : ZEC/USD [639/645]
# Pulling: kraken : ZRX/BTC [640/645]
# Pulling: kraken : ZRX/EUR [641/645]
# Pulling: kraken : ZRX/USD [642/645]
# Unable to obtain: ['BTC-AED', 'ETH-AED', 'USD-AED']
# ['BTC-AED', 'ETH-AED', 'USD-AED']

# %%
pull_data('kucoin', from_date, numberCandles, '1h', localFolder)
# Out:
# Pulling: kucoin : 1EARTH/USDT [1/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : 1EARTH-USDT [1/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 1EARTH-USDT
# Pulling: kucoin : 1INCH/USDT [1/1297]
# Pulling: kucoin : 2CRZ/USDT [2/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : 2CRZ-USDT [2/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: 2CRZ-USDT
# Pulling: kucoin : AAVE/BTC [2/1297]
# Pulling: kucoin : AAVE/KCS [3/1297]
# Pulling: kucoin : AAVE/USDT [4/1297]
# Pulling: kucoin : AAVE3L/USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AAVE3L-USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AAVE3L-USDT
# Pulling: kucoin : AAVE3S/USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AAVE3S-USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AAVE3S-USDT
# Pulling: kucoin : ABBC/BTC [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ABBC-BTC [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ABBC-BTC
# Pulling: kucoin : ABBC/USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ABBC-USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ABBC-USDT
# Pulling: kucoin : ACA/BTC [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACA-BTC [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACA-BTC
# Pulling: kucoin : ACA/USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACA-USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACA-USDT
# Pulling: kucoin : ACE/USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACE-USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACE-USDT
# Pulling: kucoin : ACH/USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACH-USDT [5/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACH-USDT
# Pulling: kucoin : ACOIN/USDT [5/1297]
# Pulling: kucoin : ACQ/USDC [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACQ-USDC [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACQ-USDC
# Pulling: kucoin : ACQ/USDT [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACQ-USDT [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACQ-USDT
# Pulling: kucoin : ACS/USDT [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACS-USDT [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACS-USDT
# Pulling: kucoin : ACT/USDT [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ACT-USDT [6/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ACT-USDT
# Pulling: kucoin : ADA/BTC [6/1297]
# Pulling: kucoin : ADA/KCS [7/1297]
# Pulling: kucoin : ADA/USDC [8/1297]
# Pulling: kucoin : ADA/USDT [9/1297]
# Pulling: kucoin : ADA3L/USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ADA3L-USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ADA3L-USDT
# Pulling: kucoin : ADA3S/USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ADA3S-USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ADA3S-USDT
# Pulling: kucoin : ADS/BTC [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ADS-BTC [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ADS-BTC
# Pulling: kucoin : ADS/USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ADS-USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ADS-USDT
# Pulling: kucoin : ADX/USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ADX-USDT [10/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ADX-USDT
# Pulling: kucoin : AERGO/BTC [10/1297]
# Pulling: kucoin : AERGO/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AERGO-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AERGO-USDT
# Pulling: kucoin : AFK/USDC [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AFK-USDC [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AFK-USDC
# Pulling: kucoin : AFK/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AFK-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AFK-USDT
# Pulling: kucoin : AGIX/BTC [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AGIX-BTC [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGIX-BTC
# Pulling: kucoin : AGIX/ETH [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AGIX-ETH [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGIX-ETH
# Pulling: kucoin : AGIX/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AGIX-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGIX-USDT
# Pulling: kucoin : AGIX2L/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AGIX2L-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGIX2L-USDT
# Pulling: kucoin : AGIX2S/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AGIX2S-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGIX2S-USDT
# Pulling: kucoin : AGLD/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AGLD-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AGLD-USDT
# Pulling: kucoin : AI/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AI-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AI-USDT
# Pulling: kucoin : AIOZ/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AIOZ-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AIOZ-USDT
# Pulling: kucoin : AIPAD/USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AIPAD-USDT [11/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AIPAD-USDT
# Pulling: kucoin : AKRO/BTC [11/1297]
# Pulling: kucoin : AKRO/USDT [12/1297]
# Pulling: kucoin : AKT/USDT [13/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AKT-USDT [13/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AKT-USDT
# Pulling: kucoin : ALEPH/USDT [13/1297]
# Pulling: kucoin : ALGO/BTC [14/1297]
# Pulling: kucoin : ALGO/ETH [15/1297]
# Pulling: kucoin : ALGO/KCS [16/1297]
# Pulling: kucoin : ALGO/USDC [17/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALGO-USDC [17/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALGO-USDC
# Pulling: kucoin : ALGO/USDT [17/1297]
# Pulling: kucoin : ALICE/BTC [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALICE-BTC [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALICE-BTC
# Pulling: kucoin : ALICE/ETH [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALICE-ETH [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALICE-ETH
# Pulling: kucoin : ALICE/USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALICE-USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALICE-USDT
# Pulling: kucoin : ALPHA/BTC [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALPHA-BTC [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALPHA-BTC
# Pulling: kucoin : ALPHA/USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALPHA-USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALPHA-USDT
# Pulling: kucoin : ALPINE/USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALPINE-USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALPINE-USDT
# Pulling: kucoin : ALT/USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ALT-USDT [18/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ALT-USDT
# Pulling: kucoin : AMB/BTC [18/1297]
# Pulling: kucoin : AMB/ETH [19/1297]
# Pulling: kucoin : AMB/USDT [20/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AMB-USDT [20/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AMB-USDT
# Pulling: kucoin : AMP/USDT [20/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AMP-USDT [20/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AMP-USDT
# Pulling: kucoin : AMPL/BTC [20/1297]
# Pulling: kucoin : AMPL/ETH [21/1297]
# Pulling: kucoin : AMPL/USDT [22/1297]
# Pulling: kucoin : ANC/USDT [23/1297]
# Pulling: kucoin : ANKR/BTC [24/1297]
# Pulling: kucoin : ANKR/USDT [25/1297]
# Pulling: kucoin : ANT/BTC [26/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ANT-BTC [26/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ANT-BTC
# Pulling: kucoin : ANT/USDT [26/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ANT-USDT [26/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ANT-USDT
# Pulling: kucoin : AOA/BTC [26/1297]
# Pulling: kucoin : AOA/USDT [27/1297]
# Pulling: kucoin : AOG/USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AOG-USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AOG-USDT
# Pulling: kucoin : APE/USDC [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APE-USDC [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APE-USDC
# Pulling: kucoin : APE/USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APE-USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APE-USDT
# Pulling: kucoin : APE3L/USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APE3L-USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APE3L-USDT
# Pulling: kucoin : APE3S/USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APE3S-USDT [28/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APE3S-USDT
# Pulling: kucoin : API3/USDT [28/1297]
# Pulling: kucoin : APL/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APL-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APL-USDT
# Pulling: kucoin : APT/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APT-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APT-USDT
# Pulling: kucoin : APT2L/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APT2L-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APT2L-USDT
# Pulling: kucoin : APT2S/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : APT2S-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: APT2S-USDT
# Pulling: kucoin : AR/BTC [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AR-BTC [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AR-BTC
# Pulling: kucoin : AR/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AR-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AR-USDT
# Pulling: kucoin : ARB/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARB-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARB-USDT
# Pulling: kucoin : ARB3L/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARB3L-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARB3L-USDT
# Pulling: kucoin : ARB3S/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARB3S-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARB3S-USDT
# Pulling: kucoin : ARKER/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARKER-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARKER-USDT
# Pulling: kucoin : ARNM/USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARNM-USDT [29/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARNM-USDT
# Pulling: kucoin : ARPA/USDT [29/1297]
# Pulling: kucoin : ARRR/BTC [30/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARRR-BTC [30/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARRR-BTC
# Pulling: kucoin : ARRR/USDT [30/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ARRR-USDT [30/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ARRR-USDT
# Pulling: kucoin : ARX/USDT [30/1297]
# Pulling: kucoin : ASD/USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ASD-USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ASD-USDT
# Pulling: kucoin : ASTR/BTC [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ASTR-BTC [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ASTR-BTC
# Pulling: kucoin : ASTR/USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ASTR-USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ASTR-USDT
# Pulling: kucoin : ASTRA/USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ASTRA-USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ASTRA-USDT
# Pulling: kucoin : ATA/BTC [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ATA-BTC [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATA-BTC
# Pulling: kucoin : ATA/USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ATA-USDT [31/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATA-USDT
# Pulling: kucoin : ATOM/BTC [31/1297]
# Pulling: kucoin : ATOM/ETH [32/1297]
# Pulling: kucoin : ATOM/KCS [33/1297]
# Pulling: kucoin : ATOM/USDC [34/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ATOM-USDC [34/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATOM-USDC
# Pulling: kucoin : ATOM/USDT [34/1297]
# Pulling: kucoin : ATOM3L/USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ATOM3L-USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATOM3L-USDT
# Pulling: kucoin : ATOM3S/USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : ATOM3S-USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: ATOM3S-USDT
# Pulling: kucoin : AUDIO/BTC [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AUDIO-BTC [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AUDIO-BTC
# Pulling: kucoin : AUDIO/USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AUDIO-USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AUDIO-USDT
# Pulling: kucoin : AURORA/USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AURORA-USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AURORA-USDT
# Pulling: kucoin : AURY/USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AURY-USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AURY-USDT
# Pulling: kucoin : AUSD/USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AUSD-USDT [35/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AUSD-USDT
# Pulling: kucoin : AVA/BTC [35/1297]
# Pulling: kucoin : AVA/ETH [36/1297]
# Pulling: kucoin : AVA/USDT [37/1297]
# Pulling: kucoin : AVAX/BTC [38/1297]
# Pulling: kucoin : AVAX/USDC [39/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AVAX-USDC [39/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AVAX-USDC
# Pulling: kucoin : AVAX/USDT [39/1297]
# Pulling: kucoin : AVAX3L/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AVAX3L-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AVAX3L-USDT
# Pulling: kucoin : AVAX3S/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AVAX3S-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AVAX3S-USDT
# Pulling: kucoin : AXS/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AXS-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AXS-USDT
# Pulling: kucoin : AXS3L/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AXS3L-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AXS3L-USDT
# Pulling: kucoin : AXS3S/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AXS3S-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AXS3S-USDT
# Pulling: kucoin : AZERO/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : AZERO-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: AZERO-USDT
# Pulling: kucoin : BAL/BTC [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BAL-BTC [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAL-BTC
# Pulling: kucoin : BAL/ETH [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BAL-ETH [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAL-ETH
# Pulling: kucoin : BAL/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BAL-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAL-USDT
# Pulling: kucoin : BAND/BTC [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BAND-BTC [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAND-BTC
# Pulling: kucoin : BAND/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BAND-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BAND-USDT
# Pulling: kucoin : BASIC/USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BASIC-USDT [40/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BASIC-USDT
# Pulling: kucoin : BAT/USDT [40/1297]
# Pulling: kucoin : BAX/BTC [41/1297]
# Pulling: kucoin : BAX/ETH [42/1297]
# Pulling: kucoin : BAX/USDT [43/1297]
# Pulling: kucoin : BBC/USDT [44/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BBC-USDT [44/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BBC-USDT
# Pulling: kucoin : BCH/BTC [44/1297]
# Pulling: kucoin : BCH/KCS [45/1297]
# Pulling: kucoin : BCH/USDC [46/1297]
# Pulling: kucoin : BCH/USDT [47/1297]
# Pulling: kucoin : BCH3L/USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BCH3L-USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BCH3L-USDT
# Pulling: kucoin : BCH3S/USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BCH3S-USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BCH3S-USDT
# Pulling: kucoin : BDX/BTC [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BDX-BTC [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BDX-BTC
# Pulling: kucoin : BDX/USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BDX-USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BDX-USDT
# Pulling: kucoin : BEAT/USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BEAT-USDT [48/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BEAT-USDT
# Pulling: kucoin : BEPRO/BTC [48/1297]
# Pulling: kucoin : BEPRO/USDT [49/1297]
# Pulling: kucoin : BFC/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BFC-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BFC-USDT
# Pulling: kucoin : BICO/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BICO-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BICO-USDT
# Pulling: kucoin : BIFIF/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BIFIF-USDT [50/1297]
# Got an error BadSymbol ('kucoin does not have market symbol BIFIF-USDT',) , retrying in 1 seconds...
# All attempts failed, skipping: BIFIF-USDT
# Pulling: kucoin : BLOK/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BLOK-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BLOK-USDT
# Pulling: kucoin : BLUR/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BLUR-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BLUR-USDT
# Pulling: kucoin : BLUR2L/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BLUR2L-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BLUR2L-USDT
# Pulling: kucoin : BLUR2S/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BLUR2S-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BLUR2S-USDT
# Pulling: kucoin : BLZ/USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BLZ-USDT [50/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BLZ-USDT
# Pulling: kucoin : BNB/BTC [50/1297]
# Pulling: kucoin : BNB/KCS [51/1297]
# Pulling: kucoin : BNB/USDC [52/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BNB-USDC [52/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BNB-USDC
# Pulling: kucoin : BNB/USDT [52/1297]
# Pulling: kucoin : BNB3L/USDT [53/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BNB3L-USDT [53/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BNB3L-USDT
# Pulling: kucoin : BNB3S/USDT [53/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BNB3S-USDT [53/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BNB3S-USDT
# Pulling: kucoin : BNC/USDT [53/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BNC-USDT [53/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BNC-USDT
# Pulling: kucoin : BNS/BTC [53/1297]
# Pulling: kucoin : BNS/USDT [54/1297]
# Pulling: kucoin : BOA/USDT [55/1297]
# Pulling: kucoin : BOBA/USDT [56/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BOBA-USDT [56/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BOBA-USDT
# Pulling: kucoin : BOLT/BTC [56/1297]
# Pulling: kucoin : BOLT/USDT [57/1297]
# Pulling: kucoin : BOND/USDT [58/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BOND-USDT [58/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BOND-USDT
# Pulling: kucoin : BONDLY/ETH [58/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BONDLY-ETH [58/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BONDLY-ETH
# Pulling: kucoin : BONDLY/USDT [58/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BONDLY-USDT [58/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BONDLY-USDT
# Pulling: kucoin : BOSON/ETH [58/1297]
# Pulling: kucoin : BOSON/USDT [59/1297]
# Pulling: kucoin : BRISE/USDT [60/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BRISE-USDT [60/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BRISE-USDT
# Pulling: kucoin : BRWL/USDT [60/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BRWL-USDT [60/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BRWL-USDT
# Pulling: kucoin : BSV/BTC [60/1297]
# Pulling: kucoin : BSV/ETH [61/1297]
# Pulling: kucoin : BSV/KCS [62/1297]
# Pulling: kucoin : BSV/USDC [63/1297]
# Pulling: kucoin : BSV/USDT [64/1297]
# Pulling: kucoin : BSW/USDT [65/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BSW-USDT [65/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BSW-USDT
# Pulling: kucoin : BTC/BRL [65/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BTC-BRL [65/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTC-BRL
# Pulling: kucoin : BTC/DAI [65/1297]
# Pulling: kucoin : BTC/EUR [66/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BTC-EUR [66/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTC-EUR
# Pulling: kucoin : BTC/GBP [66/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BTC-GBP [66/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTC-GBP
# Pulling: kucoin : BTC/TUSD [66/1297]
# Pulling: kucoin : BTC/USDC [67/1297]
# Pulling: kucoin : BTC/USDT [68/1297]
# Pulling: kucoin : BTC3L/USDT [69/1297]
# Pulling: kucoin : BTC3S/USDT [70/1297]
# Pulling: kucoin : BTCDOWN/USDT [71/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BTCDOWN-USDT [71/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTCDOWN-USDT
# Pulling: kucoin : BTCUP/USDT [71/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BTCUP-USDT [71/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BTCUP-USDT
# Pulling: kucoin : BTT/USDT [71/1297]
# Pulling: kucoin : BULL/USDT [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BULL-USDT [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BULL-USDT
# Pulling: kucoin : BURGER/BTC [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BURGER-BTC [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BURGER-BTC
# Pulling: kucoin : BURGER/USDT [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BURGER-USDT [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BURGER-USDT
# Pulling: kucoin : BUSD/USDC [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# Pulling: kucoin : BUSD-USDC [72/1297]
# Got an error IndexError ('single positional indexer is out-of-bounds',) , retrying in 1 seconds...
# All attempts failed, skipping: BUSD-USDC
# Pulling: kucoin : BUSD/USDT [72/1297]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     626             self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 627             response.raise_for_status()
#     628
#
# /usr/local/lib/python3.9/dist-packages/requests/models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.kucoin.com/api/v1/market/candles?symbol=BUSD-USDT&type=1hour&startAt=1617235200&endAt=1618963200
#
# During handling of the above exception, another exception occurred:
#
# RateLimitExceeded                         Traceback (most recent call last)
# <ipython-input-7-3ae6f43af2ab> in <cell line: 1>()
# ----> 1 pull_data('kucoin', from_date, numberCandles, '1h', localFolder)
#
# <ipython-input-5-89b5e3d92398> in pull_data(exchange, from_date, n_candles, c_size, f_path, skip)
#      28             try:
#      29                 print('Pulling:', exchange, ':', symbol, '[{}/{}]'.format(count, len(exc_instance.symbols)))
# ---> 30                 data = exc_instance.fetch_ohlcv(symbol, c_size, from_timestamp, n_candles)
#      31
#      32                 # if < n_candles returned, skip this pair
#
# /usr/local/lib/python3.9/dist-packages/ccxt/kucoin.py in fetch_ohlcv(self, symbol, timeframe, since, limit, params)
#    1151             request['startAt'] = self.parse_to_int(int(math.floor(since / 1000)))
#    1152         request['endAt'] = self.parse_to_int(int(math.floor(endAt / 1000)))
# -> 1153         response = self.publicGetMarketCandles(self.extend(request, params))
#    1154         #
#    1155         #     {
#
# /usr/local/lib/python3.9/dist-packages/ccxt/base/exchange.py in inner(_self, params, context)
#     505                 if context is not None:
#     506                     inner_kwargs['context'] = params
# --> 507                 return entry(_self, **inner_kwargs)
#     508             return inner
#     509         to_bind = partialer()
#
# /usr/local/lib/python3.9/dist-packages/ccxt/base/exchange.py in request(self, path, api, method, params, headers, body, config, context)
#    2885
#    2886     def request(self, path, api: Any = 'public', method='GET', params={}, headers: Optional[Any] = None, body: Optional[Any] = None, config={}, context={}):
# -> 2887         return self.fetch2(path, api, method, params, headers, body, config, context)
#    2888
#    2889     def load_accounts(self, reload=False, params={}):
#
# /usr/local/lib/python3.9/dist-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body, config, context)
#    2882         self.lastRestRequestTimestamp = self.milliseconds()
#    2883         request = self.sign(path, api, method, params, headers, body)
# -> 2884         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#    2885
#    2886     def request(self, path, api: Any = 'public', method='GET', params={}, headers: Optional[Any] = None, body: Optional[Any] = None, config={}, context={}):
#
# /usr/local/lib/python3.9/dist-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     643             skip_further_error_handling = self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     644             if not skip_further_error_handling:
# --> 645                 self.handle_http_status_code(http_status_code, http_status_text, url, method, http_response)
#     646             raise ExchangeError(details) from e
#     647
#
# /usr/local/lib/python3.9/dist-packages/ccxt/base/exchange.py in handle_http_status_code(self, code, reason, url, method, body)
#    1693         if codeAsString in self.httpExceptions:
#    1694             ErrorClass = self.httpExceptions[codeAsString]
# -> 1695             raise ErrorClass(self.id + ' ' + method + ' ' + url + ' ' + codeAsString + ' ' + reason + ' ' + body)
#    1696
#    1697     @staticmethod
#
# RateLimitExceeded: kucoin GET https://api.kucoin.com/api/v1/market/candles?symbol=BUSD-USDT&type=1hour&startAt=1617235200&endAt=1618963200 429 Too Many Requests {"code":"429000","msg":"Too Many Requests"}

# %%
pull_data('lbank', from_date, numberCandles, '1h', localFolder)
# Out:
# Pulling: lbank : 1INCH/USDT [1/957]
# Pulling: lbank : 1INCH3L/USDT [2/957]
# Pulling: lbank : 1INCH3S/USDT [3/957]
# Pulling: lbank : 1INCH5L/USDT [4/957]
# Pulling: lbank : 1INCH5S/USDT [5/957]
# Pulling: lbank : 3ULL/USDT [6/957]
# Pulling: lbank : 4JNET/USDT [7/957]
# Pulling: lbank : 7PXS/USDT [8/957]
# Pulling: lbank : A1A/USDT [9/957]
# Pulling: lbank : AAVE/USDT [10/957]
# Pulling: lbank : AAVE3L/USDT [11/957]
# Pulling: lbank : AAVE3S/USDT [12/957]
# Pulling: lbank : ABEY/USDT [13/957]
# Pulling: lbank : ACA/USDT [14/957]
# Pulling: lbank : ACS/USDT [15/957]
# Pulling: lbank : ADA/USDT [16/957]
# Pulling: lbank : ADA3L/USDT [17/957]
# Pulling: lbank : ADA3S/USDT [18/957]
# Pulling: lbank : AGIX/USDT [19/957]
# Pulling: lbank : AGIX3L/USDT [20/957]
# Pulling: lbank : AGIX3S/USDT [21/957]
# Pulling: lbank : AGLD/USDT [22/957]
# Pulling: lbank : AGLD3L/USDT [23/957]
# Pulling: lbank : AGLD3S/USDT [24/957]
# Pulling: lbank : ALGO/USDT [25/957]
# Pulling: lbank : ALGO3L/USDT [26/957]
# Pulling: lbank : ALGO3S/USDT [27/957]
# Pulling: lbank : ALICE/USDT [28/957]
# Pulling: lbank : ALICE3L/USDT [29/957]
# Pulling: lbank : ALICE3S/USDT [30/957]
# Pulling: lbank : ALPACA/USDT [31/957]
# Pulling: lbank : ALPHA3L/USDT [32/957]
# Pulling: lbank : ALPHA3S/USDT [33/957]
# Pulling: lbank : AMP/USDT [34/957]
# Pulling: lbank : ANJI/USDT [35/957]
# Pulling: lbank : ANKR/USDT [36/957]
# Pulling: lbank : ANKR3L/USDT [37/957]
# Pulling: lbank : ANKR3S/USDT [38/957]
# Pulling: lbank : ANT/USDT [39/957]
# Pulling: lbank : ANT3L/USDT [40/957]
# Pulling: lbank : ANT3S/USDT [41/957]
# Pulling: lbank : APE/USDT [42/957]
# Pulling: lbank : APE3L/USDT [43/957]
# Pulling: lbank : APE3S/USDT [44/957]
# Pulling: lbank : API33L/USDT [45/957]
# Pulling: lbank : API33S/USDT [46/957]
# Pulling: lbank : APRIL/USDT [47/957]
# Pulling: lbank : APT/USDT [48/957]
# Pulling: lbank : APT3L/USDT [49/957]
# Pulling: lbank : APT3S/USDT [50/957]
# Pulling: lbank : APX/USDT [51/957]
# Pulling: lbank : AR3L/USDT [52/957]
# Pulling: lbank : AR3S/USDT [53/957]
# Pulling: lbank : ARB/USDT [54/957]
# Pulling: lbank : ARC/USDT [55/957]
# Pulling: lbank : ARI10/USDT [56/957]
# Pulling: lbank : ARIA/USDT [57/957]
# Pulling: lbank : ARIX/USDT [58/957]
# Pulling: lbank : ARPA/USDT [59/957]
# Pulling: lbank : ARPA3L/USDT [60/957]
# Pulling: lbank : ARPA3S/USDT [61/957]
# Pulling: lbank : ARTR/USDT [62/957]
# Pulling: lbank : ARV/USDT [63/957]
# Pulling: lbank : ASC/USDT [64/957]
# Pulling: lbank : ASY/USDT [65/957]
# Pulling: lbank : ATA3L/USDT [66/957]
# Pulling: lbank : ATA3S/USDT [67/957]
# Pulling: lbank : ATOM/USDT [68/957]
# Pulling: lbank : ATOM3L/USDT [69/957]
# Pulling: lbank : ATOM3S/USDT [70/957]
# Pulling: lbank : ATOZ/USDT [71/957]
# Pulling: lbank : AUC/USDT [72/957]
# Pulling: lbank : AUDIO/USDT [73/957]
# Pulling: lbank : AUDIO3L/USDT [74/957]
# Pulling: lbank : AUDIO3S/USDT [75/957]
# Pulling: lbank : AUTO/USDT [76/957]
# Pulling: lbank : AVAX/USDC [77/957]
# Pulling: lbank : AVAX/USDT [78/957]
# Pulling: lbank : AVAX3L/USDT [79/957]
# Pulling: lbank : AVAX3S/USDT [80/957]
# Pulling: lbank : AXS/USDT [81/957]
# Pulling: lbank : AXS3L/USDT [82/957]
# Pulling: lbank : AXS3S/USDT [83/957]
# Pulling: lbank : AXS5L/USDT [84/957]
# Pulling: lbank : AXS5S/USDT [85/957]
# Pulling: lbank : BABYDOGE/USDT [86/957]
# Pulling: lbank : BADGER/USDT [87/957]
# Pulling: lbank : BADGER3L/USDT [88/957]
# Pulling: lbank : BADGER3S/USDT [89/957]
# Pulling: lbank : BAKE3L/USDT [90/957]
# Pulling: lbank : BAKE3S/USDT [91/957]
# Pulling: lbank : BAL/USDT [92/957]
# Pulling: lbank : BAL3L/USDT [93/957]
# Pulling: lbank : BAL3S/USDT [94/957]
# Pulling: lbank : BAND3L/USDT [95/957]
# Pulling: lbank : BAND3S/USDT [96/957]
# Pulling: lbank : BANK/USDT [97/957]
# Pulling: lbank : BAT3L/USDT [98/957]
# Pulling: lbank : BAT3S/USDT [99/957]
# Pulling: lbank : BB/USDT [100/957]
# Pulling: lbank : BCH/USDC [101/957]
# Pulling: lbank : BCH/USDT [102/957]
# Pulling: lbank : BCH3L/USDT [103/957]
# Pulling: lbank : BCH3S/USDT [104/957]
# Pulling: lbank : BCH5L/USDT [105/957]
# Pulling: lbank : BCH5S/USDT [106/957]
# Pulling: lbank : BCL/USDT [107/957]
# Pulling: lbank : BDCC/USDT [108/957]
# Pulling: lbank : BEAR/USDT [109/957]
# Pulling: lbank : BEL1/USDT [110/957]
# Pulling: lbank : BEL3L/USDT [111/957]
# Pulling: lbank : BEL3S/USDT [112/957]
# Pulling: lbank : BERRY/USDT [113/957]
# Pulling: lbank : BFIC/USDT [114/957]
# Pulling: lbank : BFLOKIC/USDT [115/957]
# Pulling: lbank : BIBL/USDT [116/957]
# Pulling: lbank : BICO/USDT [117/957]
# Pulling: lbank : BIO/USDT [118/957]
# Pulling: lbank : BIT3L/USDT [119/957]
# Pulling: lbank : BIT3S/USDT [120/957]
# Pulling: lbank : BLID/USDT [121/957]
# Pulling: lbank : BLOVELY/USDT [122/957]
# Pulling: lbank : BLUESPARROW/USDT [123/957]
# Pulling: lbank : BLUR/USDT [124/957]
# Pulling: lbank : BLZ/USDT [125/957]
# Pulling: lbank : BLZ3L/USDT [126/957]
# Pulling: lbank : BLZ3S/USDT [127/957]
# Pulling: lbank : BNB/BUSD [128/957]
# Pulling: lbank : BNB/ETH [129/957]
# Pulling: lbank : BNB/USDT [130/957]
# Pulling: lbank : BNB3L/USDT [131/957]
# Pulling: lbank : BNB3S/USDT [132/957]
# Pulling: lbank : BNT/USDT [133/957]
# Pulling: lbank : BNX/USDT [134/957]
# Pulling: lbank : BONE/USDT [135/957]
# Pulling: lbank : BONK/USDT [136/957]
# Pulling: lbank : BOTTO/USDT [137/957]
# Pulling: lbank : BP/USDT [138/957]
# Pulling: lbank : BRG/USDT [139/957]
# Pulling: lbank : BRISE/USDT [140/957]
# Pulling: lbank : BSV3L/USDT [141/957]
# Pulling: lbank : BSV3S/USDT [142/957]
# Pulling: lbank : BSV5L/USDT [143/957]
# Pulling: lbank : BSV5S/USDT [144/957]
# Pulling: lbank : BSW/USDT [145/957]
# Pulling: lbank : BTC/BUSD [146/957]
# Pulling: lbank : BTC/USDC [147/957]
# Pulling: lbank : BTC/USDT [148/957]
# Pulling: lbank : BTC3L/USDT [149/957]
# Pulling: lbank : BTC3S/USDT [150/957]
# Pulling: lbank : BTC5L/USDT [151/957]
# Pulling: lbank : BTC5S/USDT [152/957]
# Pulling: lbank : BTT/USDT [153/957]
# Pulling: lbank : BURN/USDT [154/957]
# Pulling: lbank : BUSD/USDT [155/957]
# Pulling: lbank : C98/USDT [156/957]
# Pulling: lbank : C983L/USDT [157/957]
# Pulling: lbank : C983S/USDT [158/957]
# Pulling: lbank : CAKE/USDT [159/957]
# Pulling: lbank : CAKE3L/USDT [160/957]
# Pulling: lbank : CAKE3S/USDT [161/957]
# Pulling: lbank : CARE/USDT [162/957]
# Pulling: lbank : CART/USDT [163/957]
# Pulling: lbank : CAST/USDT [164/957]
# Pulling: lbank : CATGIRL/USDT [165/957]
# Pulling: lbank : CATS/USDT [166/957]
# Pulling: lbank : CBK/USDT [167/957]
# Pulling: lbank : CCASH/USDT [168/957]
# Pulling: lbank : CCP/USDT [169/957]
# Pulling: lbank : CCV2/USDT [170/957]
# Pulling: lbank : CCX/USDT [171/957]
# Pulling: lbank : CEEK/USDT [172/957]
# Pulling: lbank : CELO/USDT [173/957]
# Pulling: lbank : CELO3L/USDT [174/957]
# Pulling: lbank : CELO3S/USDT [175/957]
# Pulling: lbank : CELR/USDT [176/957]
# Pulling: lbank : CELR3L/USDT [177/957]
# Pulling: lbank : CELR3S/USDT [178/957]
# Pulling: lbank : CFC/USDT [179/957]
# Pulling: lbank : CFX/USDT [180/957]
# Pulling: lbank : CFX3L/USDT [181/957]
# Pulling: lbank : CFX3S/USDT [182/957]
# Pulling: lbank : CFXT/USDT [183/957]
# Pulling: lbank : CGO/USDT [184/957]
# Pulling: lbank : CGU/USDT [185/957]
# Pulling: lbank : CHAMP/USDT [186/957]
# Pulling: lbank : CHEQ/USDT [187/957]
# Pulling: lbank : CHESS/USDT [188/957]
# Pulling: lbank : CHICA/USDT [189/957]
# Pulling: lbank : CHO/USDT [190/957]
# Pulling: lbank : CHR3L/USDT [191/957]
# Pulling: lbank : CHR3S/USDT [192/957]
# Pulling: lbank : CHZ/USDT [193/957]
# Pulling: lbank : CHZ3L/USDT [194/957]
# Pulling: lbank : CHZ3S/USDT [195/957]
# Pulling: lbank : CIC/USDT [196/957]
# Pulling: lbank : CKB/USDT [197/957]
# Pulling: lbank : CMCX/USDT [198/957]
# Pulling: lbank : CNX/USDT [199/957]
# Pulling: lbank : COINSCOPE/USDT [200/957]
# Pulling: lbank : COMP/USDT [201/957]
# Pulling: lbank : COMP3L/USDT [202/957]
# Pulling: lbank : COMP3S/USDT [203/957]
# Pulling: lbank : CORE/USDT [204/957]
# Pulling: lbank : COT/USDT [205/957]
# Pulling: lbank : COTI3L/USDT [206/957]
# Pulling: lbank : COTI3S/USDT [207/957]
# Pulling: lbank : CPC/USDT [208/957]
# Pulling: lbank : CPS/USDT [209/957]
# Pulling: lbank : CRA/USDT [210/957]
# Pulling: lbank : CRE/USDT [211/957]
# Pulling: lbank : CREAM3L/USDT [212/957]
# Pulling: lbank : CREAM3S/USDT [213/957]
# Pulling: lbank : CREMOA/USDT [214/957]
# Pulling: lbank : CRETA/USDT [215/957]
# Pulling: lbank : CRMC/USDT [216/957]
# Pulling: lbank : CRO/USDT [217/957]
# Pulling: lbank : CRO3L/USDT [218/957]
# Pulling: lbank : CRO3S/USDT [219/957]
# Pulling: lbank : CROWN/USDT [220/957]
# Pulling: lbank : CRP/USDT [221/957]
# Pulling: lbank : CRV/USDC [222/957]
# Pulling: lbank : CRV/USDT [223/957]
# Pulling: lbank : CRV3L/USDT [224/957]
# Pulling: lbank : CRV3S/USDT [225/957]
# Pulling: lbank : CRV5L/USDT [226/957]
# Pulling: lbank : CRV5S/USDT [227/957]
# Pulling: lbank : CRYS/USDT [228/957]
# Pulling: lbank : CTK3L/USDT [229/957]
# Pulling: lbank : CTK3S/USDT [230/957]
# Pulling: lbank : CTP/USDT [231/957]
# Pulling: lbank : CTSI3L/USDT [232/957]
# Pulling: lbank : CTSI3S/USDT [233/957]
# Pulling: lbank : CTY/USDT [234/957]
# Pulling: lbank : CULT/USDT [235/957]
# Pulling: lbank : CVC3L/USDT [236/957]
# Pulling: lbank : CVC3S/USDT [237/957]
# Pulling: lbank : CVX/USDT [238/957]
# Pulling: lbank : CXS/USDT [239/957]
# Pulling: lbank : D2T/USDT [240/957]
# Pulling: lbank : DAI/USDT [241/957]
# Pulling: lbank : DAR/USDT [242/957]
# Pulling: lbank : DAR3L/USDT [243/957]
# Pulling: lbank : DAR3S/USDT [244/957]
# Pulling: lbank : DASH/USDT [245/957]
# Pulling: lbank : DASH3L/USDT [246/957]
# Pulling: lbank : DASH3S/USDT [247/957]
# Pulling: lbank : DBX/USDT [248/957]
# Pulling: lbank : DC/USDT [249/957]
# Pulling: lbank : DDC/USDT [250/957]
# Pulling: lbank : DEBT/USDT [251/957]
# Pulling: lbank : DENT3L/USDT [252/957]
# Pulling: lbank : DENT3S/USDT [253/957]
# Pulling: lbank : DEXO/USDT [254/957]
# Pulling: lbank : DGB/USDT [255/957]
# Pulling: lbank : DGB3L/USDT [256/957]
# Pulling: lbank : DGB3S/USDT [257/957]
# Pulling: lbank : DHABICOIN/USDT [258/957]
# Pulling: lbank : DIE/USDT [259/957]
# Pulling: lbank : DINGO/USDT [260/957]
# Pulling: lbank : DMCC/USDT [261/957]
# Pulling: lbank : DOCT/USDT [262/957]
# Pulling: lbank : DODO3L/USDT [263/957]
# Pulling: lbank : DODO3S/USDT [264/957]
# Pulling: lbank : DOGE/USDC [265/957]
# Pulling: lbank : DOGE/USDT [266/957]
# Pulling: lbank : DOGE3L/USDT [267/957]
# Pulling: lbank : DOGE3S/USDT [268/957]
# Pulling: lbank : DOGE5L/USDT [269/957]
# Pulling: lbank : DOGECOIN/USDT [270/957]
# Pulling: lbank : DOGECOLA/USDT [271/957]
# Pulling: lbank : DOT/USDC [272/957]
# Pulling: lbank : DOT/USDT [273/957]
# Pulling: lbank : DOT3L/USDT [274/957]
# Pulling: lbank : DOT3S/USDT [275/957]
# Pulling: lbank : DOT5L/USDT [276/957]
# Pulling: lbank : DOT5S/USDT [277/957]
# Pulling: lbank : DRIVECRYPTO/USDT [278/957]
# Pulling: lbank : DSP/USDT [279/957]
# Pulling: lbank : DST/USDT [280/957]
# Pulling: lbank : DTH/USDT [281/957]
# Pulling: lbank : DTR/USDT [282/957]
# Pulling: lbank : DVTC/USDT [283/957]
# Pulling: lbank : DYDX/USDT [284/957]
# Pulling: lbank : DYDX3L/USDT [285/957]
# Pulling: lbank : DYDX3S/USDT [286/957]
# Pulling: lbank : DZOO/USDT [287/957]
# Pulling: lbank : EBSO/USDT [288/957]
# Pulling: lbank : EDAT/USDT [289/957]
# Pulling: lbank : EFK/USDT [290/957]
# Pulling: lbank : EGLD/USDT [291/957]
# Pulling: lbank : EGLD3L/USDT [292/957]
# Pulling: lbank : EGLD3S/USDT [293/957]
# Pulling: lbank : ELC/USDT [294/957]
# Pulling: lbank : ELYSIAN/USDT [295/957]
# Pulling: lbank : ENJ3L/USDT [296/957]
# Pulling: lbank : ENJ3S/USDT [297/957]
# Pulling: lbank : ENJ5L/USDT [298/957]
# Pulling: lbank : ENJ5S/USDT [299/957]
# Pulling: lbank : ENS/USDC [300/957]
# Pulling: lbank : ENS/USDT [301/957]
# Pulling: lbank : ENS3L/USDT [302/957]
# Pulling: lbank : ENS3S/USDT [303/957]
# Pulling: lbank : ENT/USDT [304/957]
# Pulling: lbank : EOS/USDC [305/957]
# Pulling: lbank : EOS/USDT [306/957]
# Pulling: lbank : EOS3L/USDT [307/957]
# Pulling: lbank : EOS3S/USDT [308/957]
# Pulling: lbank : EOS5L/USDT [309/957]
# Pulling: lbank : EOS5S/USDT [310/957]
# Pulling: lbank : EPIX/USDT [311/957]
# Pulling: lbank : EPX/USDT [312/957]
# Pulling: lbank : ERN/USDT [313/957]
# Pulling: lbank : ERR/USDT [314/957]
# Pulling: lbank : ESG/USDT [315/957]
# Pulling: lbank : EST/USDT [316/957]
# Pulling: lbank : ETC/ETH [317/957]
# Pulling: lbank : ETC/USDT [318/957]
# Pulling: lbank : ETC3L/USDT [319/957]
# Pulling: lbank : ETC3S/USDT [320/957]
# Pulling: lbank : ETH/BTC [321/957]
# Pulling: lbank : ETH/BUSD [322/957]
# Pulling: lbank : ETH/USDC [323/957]
# Pulling: lbank : ETH/USDT [324/957]
# Pulling: lbank : ETH3L/USDT [325/957]
# Pulling: lbank : ETH3S/USDT [326/957]
# Pulling: lbank : ETH5L/USDT [327/957]
# Pulling: lbank : ETH5S/USDT [328/957]
# Pulling: lbank : ETHW/USDT [329/957]
# Pulling: lbank : EUL/USDT [330/957]
# Pulling: lbank : EWC/USDT [331/957]
# Pulling: lbank : EXN/USDT [332/957]
# Pulling: lbank : EYE/USDT [333/957]
# Pulling: lbank : FAMEG/USDT [334/957]
# Pulling: lbank : FAST/USDT [335/957]
# Pulling: lbank : FCF/USDT [336/957]
# Pulling: lbank : FEI/USDT [337/957]
# Pulling: lbank : FET/USDT [338/957]
# Pulling: lbank : FGHT/USDT [339/957]
# Pulling: lbank : FIDA/USDT [340/957]
# Pulling: lbank : FIEF/USDT [341/957]
# Pulling: lbank : FIL/USDT [342/957]
# Pulling: lbank : FIL3S/USDT [343/957]
# Pulling: lbank : FIL5L/USDT [344/957]
# Pulling: lbank : FIL5S/USDT [345/957]
# Pulling: lbank : FIS/USDT [346/957]
# Pulling: lbank : FITFI/USDT [347/957]
# Pulling: lbank : FIWA/USDT [348/957]
# Pulling: lbank : FJT/USDT [349/957]
# Pulling: lbank : FLAG/USDT [350/957]
# Pulling: lbank : FLEX/USDT [351/957]
# Pulling: lbank : FLM3L/USDT [352/957]
# Pulling: lbank : FLM3S/USDT [353/957]
# Pulling: lbank : FLOKI/USDT [354/957]
# Pulling: lbank : FLOKICEO/USDT [355/957]
# Pulling: lbank : FLOW/USDT [356/957]
# Pulling: lbank : FLOW3L/USDT [357/957]
# Pulling: lbank : FLOW3S/USDT [358/957]
# Pulling: lbank : FLR/USDT [359/957]
# Pulling: lbank : FND/USDT [360/957]
# Pulling: lbank : FOF/USDT [361/957]
# Pulling: lbank : FOGNET/USDT [362/957]
# Pulling: lbank : FRA/USDT [363/957]
# Pulling: lbank : FREE/USDT [364/957]
# Pulling: lbank : FRTS/USDT [365/957]
# Pulling: lbank : FRWR/USDT [366/957]
# Pulling: lbank : FSC/USDT [367/957]
# Pulling: lbank : FTM/USDC [368/957]
# Pulling: lbank : FTM/USDT [369/957]
# Pulling: lbank : FTM3L/USDT [370/957]
# Pulling: lbank : FTM3S/USDT [371/957]
# Pulling: lbank : FTT3L/USDT [372/957]
# Pulling: lbank : FTT3S/USDT [373/957]
# Pulling: lbank : FWC/USDT [374/957]
# Pulling: lbank : FXS/USDT [375/957]
# Pulling: lbank : G/USDT [376/957]
# Pulling: lbank : GAL/USDT [377/957]
# Pulling: lbank : GALA/USDT [378/957]
# Pulling: lbank : GALA3L/USDT [379/957]
# Pulling: lbank : GALA3S/USDT [380/957]
# Pulling: lbank : GALA5L/USDT [381/957]
# Pulling: lbank : GALA5S/USDT [382/957]
# Pulling: lbank : GART/USDT [383/957]
# Pulling: lbank : GATHER/USDT [384/957]
# Pulling: lbank : GBEX/USDT [385/957]
# Pulling: lbank : GDCC/USDT [386/957]
# Pulling: lbank : GDOGE/USDT [387/957]
# Pulling: lbank : GEP/USDT [388/957]
# Pulling: lbank : GFT/USDT [389/957]
# Pulling: lbank : GHUB/USDT [390/957]
# Pulling: lbank : GLEEC/USDT [391/957]
# Pulling: lbank : GLMR/USDT [392/957]
# Pulling: lbank : GLR/USDT [393/957]
# Pulling: lbank : GMCOIN/USDT [394/957]
# Pulling: lbank : GMT Token/USDT [395/957]
# Pulling: lbank : GMT1/USDT [396/957]
# Pulling: lbank : GMT3L/USDT [397/957]
# Pulling: lbank : GMT3S/USDT [398/957]
# Pulling: lbank : GMX/USDT [399/957]
# Pulling: lbank : GNS/USDT [400/957]
# Pulling: lbank : GOLC/USDT [401/957]
# Pulling: lbank : GPT/USDT [402/957]
# Pulling: lbank : GRT/USDT [403/957]
# Pulling: lbank : GRT3L/USDT [404/957]
# Pulling: lbank : GRT3S/USDT [405/957]
# Pulling: lbank : GRV/USDT [406/957]
# Pulling: lbank : GSL/USDT [407/957]
# Pulling: lbank : GT/USDT [408/957]
# Pulling: lbank : GTC/USDT [409/957]
# Pulling: lbank : GTC3L/USDT [410/957]
# Pulling: lbank : GTC3S/USDT [411/957]
# Pulling: lbank : GTG/USDT [412/957]
# Pulling: lbank : GTN/USDT [413/957]
# Pulling: lbank : GTX/USDT [414/957]
# Pulling: lbank : GULF/BUSD [415/957]
# Pulling: lbank : GULF/USDT [416/957]
# Pulling: lbank : GXA/USDT [417/957]
# Pulling: lbank : GXBC/USDT [418/957]
# Pulling: lbank : GYMNET/USDT [419/957]
# Pulling: lbank : HALO/USDT [420/957]
# Pulling: lbank : HAM/USDT [421/957]
# Pulling: lbank : HAN/USDT [422/957]
# Pulling: lbank : HBAR3L/USDT [423/957]
# Pulling: lbank : HBAR3S/USDT [424/957]
# Pulling: lbank : HERO/USDT [425/957]
# Pulling: lbank : HFT/USDT [426/957]
# Pulling: lbank : HIGH/USDT [427/957]
# Pulling: lbank : HIGH3L/USDT [428/957]
# Pulling: lbank : HIGH3S/USDT [429/957]
# Pulling: lbank : HLN/USDT [430/957]
# Pulling: lbank : HMT/USDT [431/957]
# Pulling: lbank : HNB/USDT [432/957]
# Pulling: lbank : HNT/USDT [433/957]
# Pulling: lbank : HODL/USDT [434/957]
# Pulling: lbank : HOOK/USDT [435/957]
# Pulling: lbank : HOOK3L/USDT [436/957]
# Pulling: lbank : HOOK3S/USDT [437/957]
# Pulling: lbank : HOT/USDT [438/957]
# Pulling: lbank : HT/USDT [439/957]
# Pulling: lbank : HT3L/USDT [440/957]
# Pulling: lbank : HT3S/USDT [441/957]
# Pulling: lbank : HUB/USDT [442/957]
# Pulling: lbank : IBAT/USDT [443/957]
# Pulling: lbank : ICP/USDT [444/957]
# Pulling: lbank : ICP3L/USDT [445/957]
# Pulling: lbank : ICP3S/USDT [446/957]
# Pulling: lbank : ICX3L/USDT [447/957]
# Pulling: lbank : ICX3S/USDT [448/957]
# Pulling: lbank : ID/USDT [449/957]
# Pulling: lbank : IFC/USDT [450/957]
# Pulling: lbank : IHC/USDT [451/957]
# Pulling: lbank : ILV/USDT [452/957]
# Pulling: lbank : IMGNAI/USDT [453/957]
# Pulling: lbank : IMPACTXP/USDT [454/957]
# Pulling: lbank : IMPT/USDT [455/957]
# Pulling: lbank : IMX/USDT [456/957]
# Pulling: lbank : IMX3L/USDT [457/957]
# Pulling: lbank : IMX3S/USDT [458/957]
# Pulling: lbank : INJ/USDT [459/957]
# Pulling: lbank : INJ3L/USDT [460/957]
# Pulling: lbank : INJ3S/USDT [461/957]
# Pulling: lbank : INTL/USDT [462/957]
# Pulling: lbank : IOST3L/USDT [463/957]
# Pulling: lbank : IOST3S/USDT [464/957]
# Pulling: lbank : IOTA3L/USDT [465/957]
# Pulling: lbank : IOTA3S/USDT [466/957]
# Pulling: lbank : IOTX/USDT [467/957]
# Pulling: lbank : IOTX3L/USDT [468/957]
# Pulling: lbank : IOTX3S/USDT [469/957]
# Pulling: lbank : IPVN/USDT [470/957]
# Pulling: lbank : IRT/USDT [471/957]
# Pulling: lbank : ISIKC/USDT [472/957]
# Pulling: lbank : ISLAMI/USDT [473/957]
# Pulling: lbank : ITLR/USDT [474/957]
# Pulling: lbank : IXT/USDT [475/957]
# Pulling: lbank : JASMY/USDT [476/957]
# Pulling: lbank : JASMY3L/USDT [477/957]
# Pulling: lbank : JASMY3S/USDT [478/957]
# Pulling: lbank : JEN/USDT [479/957]
# Pulling: lbank : JOE/USDT [480/957]
# Pulling: lbank : KA/USDT [481/957]
# Pulling: lbank : KABOSU/USDT [482/957]
# Pulling: lbank : KAVA/USDT [483/957]
# Pulling: lbank : KAVA3L/USDT [484/957]
# Pulling: lbank : KAVA3S/USDT [485/957]
# Pulling: lbank : KAWA/USDT [486/957]
# Pulling: lbank : KEG/USDT [487/957]
# Pulling: lbank : KINGSHIB/USDT [488/957]
# Pulling: lbank : KISHIMOTO/USDT [489/957]
# Pulling: lbank : KISHU/USDT [490/957]
# Pulling: lbank : KLAY/USDT [491/957]
# Pulling: lbank : KLAY3L/USDT [492/957]
# Pulling: lbank : KLAY3S/USDT [493/957]
# Pulling: lbank : KLEE/USDT [494/957]
# Pulling: lbank : KNC3L/USDT [495/957]
# Pulling: lbank : KNC3S/USDT [496/957]
# Pulling: lbank : KP3R/USDT [497/957]
# Pulling: lbank : KSM/USDT [498/957]
# Pulling: lbank : KSM3L/USDT [499/957]
# Pulling: lbank : KSM3S/USDT [500/957]
# Pulling: lbank : KUNCI/USDT [501/957]
# Pulling: lbank : KUSUNOKI/USDT [502/957]
# Pulling: lbank : LAPA/USDT [503/957]
# Pulling: lbank : LAT/USDT [504/957]
# Pulling: lbank : LAZIO/USDT [505/957]
# Pulling: lbank : LBK/USDT [506/957]
# Pulling: lbank : LDO/USDT [507/957]
# Pulling: lbank : LEO/USDT [508/957]
# Pulling: lbank : LGC/USDT [509/957]
# Pulling: lbank : LILFLOKI/USDT [510/957]
# Pulling: lbank : LINA3L/USDT [511/957]
# Pulling: lbank : LINA3S/USDT [512/957]
# Pulling: lbank : LINK/ETH [513/957]
# Pulling: lbank : LINK/USDT [514/957]
# Pulling: lbank : LINK3L/USDT [515/957]
# Pulling: lbank : LINK3S/USDT [516/957]
# Pulling: lbank : LINK5L/USDT [517/957]
# Pulling: lbank : LINK5S/USDT [518/957]
# Pulling: lbank : LIT/USDT [519/957]
# Pulling: lbank : LIT3L/USDT [520/957]
# Pulling: lbank : LIT3S/USDT [521/957]
# Pulling: lbank : LKC/USDT [522/957]
# Pulling: lbank : LKD/USDT [523/957]
# Pulling: lbank : LM/USDT [524/957]
# Pulling: lbank : LNR/USDT [525/957]
# Pulling: lbank : LOOKS/USDT [526/957]
# Pulling: lbank : LOOKS3L/USDT [527/957]
# Pulling: lbank : LOOKS3S/USDT [528/957]
# Pulling: lbank : LOOKS5L/USDT [529/957]
# Pulling: lbank : LOOKS5S/USDT [530/957]
# Pulling: lbank : LOOT/USDT [531/957]
# Pulling: lbank : LPT3L/USDT [532/957]
# Pulling: lbank : LPT3S/USDT [533/957]
# Pulling: lbank : LQTY/USDT [534/957]
# Pulling: lbank : LR/USDT [535/957]
# Pulling: lbank : LRC/USDT [536/957]
# Pulling: lbank : LRC3L/USDT [537/957]
# Pulling: lbank : LRC3S/USDT [538/957]
# Pulling: lbank : LTC/ETH [539/957]
# Pulling: lbank : LTC/USDC [540/957]
# Pulling: lbank : LTC/USDT [541/957]
# Pulling: lbank : LTC3L/USDT [542/957]
# Pulling: lbank : LTC3S/USDT [543/957]
# Pulling: lbank : LTC5L/USDT [544/957]
# Pulling: lbank : LTC5S/USDT [545/957]
# Pulling: lbank : LTNM/USDT [546/957]
# Pulling: lbank : LUFFY/USDT [547/957]
# Pulling: lbank : LUNA/USDT [548/957]
# Pulling: lbank : LUNAT/USDT [549/957]
# Pulling: lbank : LUNC/BUSD [550/957]
# Pulling: lbank : LUNC/USDT [551/957]
# Pulling: lbank : LUNC3L/USDT [552/957]
# Pulling: lbank : LUNC3S/USDT [553/957]
# Pulling: lbank : LXRN/USDT [554/957]
# Pulling: lbank : LYNK/USDT [555/957]
# Pulling: lbank : LYO/USDT [556/957]
# Pulling: lbank : MAGIC/USDT [557/957]
# Pulling: lbank : MAGIC3L/USDT [558/957]
# Pulling: lbank : MAGIC3S/USDT [559/957]
# Pulling: lbank : MANA/USDT [560/957]
# Pulling: lbank : MANA3L/USDT [561/957]
# Pulling: lbank : MANA3S/USDT [562/957]
# Pulling: lbank : MARS/USDT [563/957]
# Pulling: lbank : MASK/USDT [564/957]
# Pulling: lbank : MASK3L/USDT [565/957]
# Pulling: lbank : MASK3S/USDT [566/957]
# Pulling: lbank : MATIC/BUSD [567/957]
# Pulling: lbank : MATIC/USDT [568/957]
# Pulling: lbank : MATIC3L/USDT [569/957]
# Pulling: lbank : MATIC3S/USDT [570/957]
# Pulling: lbank : MAXR/USDT [571/957]
# Pulling: lbank : MBOX/USDT [572/957]
# Pulling: lbank : MC/USDT [573/957]
# Pulling: lbank : MCOIN/USDT [574/957]
# Pulling: lbank : MDX1/USDT [575/957]
# Pulling: lbank : MEER/USDT [576/957]
# Pulling: lbank : MEF/USDT [577/957]
# Pulling: lbank : MELOS/USDT [578/957]
# Pulling: lbank : METADOGE/USDT [579/957]
# Pulling: lbank : METAF/USDT [580/957]
# Pulling: lbank : METIS/USDT [581/957]
# Pulling: lbank : MEVR/USDT [582/957]
# Pulling: lbank : MINTME/USDT [583/957]
# Pulling: lbank : MIST/USDT [584/957]
# Pulling: lbank : MKR/USDT [585/957]
# Pulling: lbank : MKR3L/USDT [586/957]
# Pulling: lbank : MKR3S/USDT [587/957]
# Pulling: lbank : MLNS/USDT [588/957]
# Pulling: lbank : MMAI/USDT [589/957]
# Pulling: lbank : MMF/USDT [590/957]
# Pulling: lbank : MMY/USDT [591/957]
# Pulling: lbank : MNDCC/USDT [592/957]
# Pulling: lbank : MNFT/USDT [593/957]
# Pulling: lbank : MNTL/USDT [594/957]
# Pulling: lbank : MOB/USDT [595/957]
# Pulling: lbank : MON/USDT [596/957]
# Pulling: lbank : MOTG/USDT [597/957]
# Pulling: lbank : MOVR/USDT [598/957]
# Pulling: lbank : MPT/USDT [599/957]
# Pulling: lbank : MR/USDT [600/957]
# Pulling: lbank : MRHB/USDT [601/957]
# Pulling: lbank : MSHD/USDT [602/957]
# Pulling: lbank : MTH/USDT [603/957]
# Pulling: lbank : MTL3L/USDT [604/957]
# Pulling: lbank : MTL3S/USDT [605/957]
# Pulling: lbank : MTRM/USDT [606/957]
# Pulling: lbank : MTVT/USDT [607/957]
# Pulling: lbank : MTW/USDT [608/957]
# Pulling: lbank : MUDI/USDT [609/957]
# Pulling: lbank : MWCC/USDT [610/957]
# Pulling: lbank : MYO/USDT [611/957]
# Pulling: lbank : MZR/USDT [612/957]
# Pulling: lbank : NEAR/USDC [613/957]
# Pulling: lbank : NEAR/USDT [614/957]
# Pulling: lbank : NEAR3L/USDT [615/957]
# Pulling: lbank : NEAR3S/USDT [616/957]
# Pulling: lbank : NEO/USDT [617/957]
# Pulling: lbank : NEO3L/USDT [618/957]
# Pulling: lbank : NEO3S/USDT [619/957]
# Pulling: lbank : NEO5L/USDT [620/957]
# Pulling: lbank : NEO5S/USDT [621/957]
# Pulling: lbank : NEOM/USDT [622/957]
# Pulling: lbank : NFTART/USDT [623/957]
# Pulling: lbank : NFTY/USDT [624/957]
# Pulling: lbank : NGR/USDT [625/957]
# Pulling: lbank : NKN3L/USDT [626/957]
# Pulling: lbank : NKN3S/USDT [627/957]
# Pulling: lbank : NOAH/USDT [628/957]
# Pulling: lbank : NTO/USDT [629/957]
# Pulling: lbank : NUGEN/USDT [630/957]
# Pulling: lbank : NUTSPAY/USDT [631/957]
# Pulling: lbank : NVIR/USDT [632/957]
# Pulling: lbank : OCEAN3L/USDT [633/957]
# Pulling: lbank : OCEAN3S/USDT [634/957]
# Pulling: lbank : OCLI/USDT [635/957]
# Pulling: lbank : ODOGE/USDT [636/957]
# Pulling: lbank : OGN3L/USDT [637/957]
# Pulling: lbank : OGN3S/USDT [638/957]
# Pulling: lbank : OKB/USDT [639/957]
# Pulling: lbank : OKB3L/USDT [640/957]
# Pulling: lbank : OKB3S/USDT [641/957]
# Pulling: lbank : OMAX/USDT [642/957]
# Pulling: lbank : OMG/USDT [643/957]
# Pulling: lbank : OMG3L/USDT [644/957]
# Pulling: lbank : OMG3S/USDT [645/957]
# Pulling: lbank : ONDA/USDT [646/957]
# Pulling: lbank : ONE3L/USDT [647/957]
# Pulling: lbank : ONE3S/USDT [648/957]
# Pulling: lbank : ONT3L/USDT [649/957]
# Pulling: lbank : ONT3S/USDT [650/957]
# Pulling: lbank : OP/USDT [651/957]
# Pulling: lbank : OP3L/USDT [652/957]
# Pulling: lbank : OP3S/USDT [653/957]
# Pulling: lbank : OPTIMUS/USDT [654/957]
# Pulling: lbank : ORDA/USDT [655/957]
# Pulling: lbank : OSMO/USDT [656/957]
# Pulling: lbank : OTWO/USDT [657/957]
# Pulling: lbank : PAE/USDT [658/957]
# Pulling: lbank : PAW/USDT [659/957]
# Pulling: lbank : PAWSWAP/USDT [660/957]
# Pulling: lbank : PAXG/USDT [661/957]
# Pulling: lbank : PC/USDT [662/957]
# Pulling: lbank : PCE/USDT [663/957]
# Pulling: lbank : PEOPLE/USDT [664/957]
# Pulling: lbank : PEOPLE3L/USDT [665/957]
# Pulling: lbank : PEOPLE3S/USDT [666/957]
# Pulling: lbank : PEOPLE5L/USDT [667/957]
# Pulling: lbank : PEOPLE5S/USDT [668/957]
# Pulling: lbank : PEPES/USDT [669/957]
# Pulling: lbank : PERP/USDT [670/957]
# Pulling: lbank : PESA/USDT [671/957]
# Pulling: lbank : PHB/BUSD [672/957]
# Pulling: lbank : PIAS/USDT [673/957]
# Pulling: lbank : PLASTIK/USDT [674/957]
# Pulling: lbank : POKT/USDT [675/957]
# Pulling: lbank : POLO/USDT [676/957]
# Pulling: lbank : POND/USDT [677/957]
# Pulling: lbank : POPCOIN/USDT [678/957]
# Pulling: lbank : POR/USDT [679/957]
# Pulling: lbank : PORTO/USDT [680/957]
# Pulling: lbank : POSI/USDT [681/957]
# Pulling: lbank : POX/USDT [682/957]
# Pulling: lbank : PRI/USDT [683/957]
# Pulling: lbank : PRIME/USDT [684/957]
# Pulling: lbank : PRMX/USDT [685/957]
# Pulling: lbank : PRX/USDT [686/957]
# Pulling: lbank : PSI/USDT [687/957]
# Pulling: lbank : PTOY/USDT [688/957]
# Pulling: lbank : PTX/USDT [689/957]
# Pulling: lbank : PYR/USDT [690/957]
# Pulling: lbank : QI/USDT [691/957]
# Pulling: lbank : QNT/USDT [692/957]
# Pulling: lbank : QRDO/USDT [693/957]
# Pulling: lbank : QTUM/USDT [694/957]
# Pulling: lbank : QTUM3L/USDT [695/957]
# Pulling: lbank : QTUM3S/USDT [696/957]
# Pulling: lbank : QUACK/USDT [697/957]
# Pulling: lbank : QUICK/USDT [698/957]
# Pulling: lbank : R3T/USDT [699/957]
# Pulling: lbank : RACA/USDT [700/957]
# Pulling: lbank : RAD/USDT [701/957]
# Pulling: lbank : RARE/USDT [702/957]
# Pulling: lbank : RBT/USDT [703/957]
# Pulling: lbank : RDNT/USDT [704/957]
# Pulling: lbank : RED/USDT [705/957]
# Pulling: lbank : REEF/USDT [706/957]
# Pulling: lbank : REEF3L/USDT [707/957]
# Pulling: lbank : REEF3S/USDT [708/957]
# Pulling: lbank : REGENT/USDT [709/957]
# Pulling: lbank : REN/USDT [710/957]
# Pulling: lbank : REN3L/USDT [711/957]
# Pulling: lbank : REN3S/USDT [712/957]
# Pulling: lbank : RENEC/USDT [713/957]
# Pulling: lbank : RIA/USDT [714/957]
# Pulling: lbank : RIF/USDT [715/957]
# Pulling: lbank : RLC3L/USDT [716/957]
# Pulling: lbank : RLC3S/USDT [717/957]
# Pulling: lbank : RNDR/USDT [718/957]
# Pulling: lbank : ROG/USDT [719/957]
# Pulling: lbank : ROSE/USDT [720/957]
# Pulling: lbank : ROSE3L/USDT [721/957]
# Pulling: lbank : ROSE3S/USDT [722/957]
# Pulling: lbank : RPL/USDT [723/957]
# Pulling: lbank : RSR3L/USDT [724/957]
# Pulling: lbank : RSR3S/USDT [725/957]
# Pulling: lbank : RSS3/USDT [726/957]
# Pulling: lbank : RUNE3L/USDT [727/957]
# Pulling: lbank : RUNE3S/USDT [728/957]
# Pulling: lbank : RVLT/USDT [729/957]
# Pulling: lbank : RVN/USDT [730/957]
# Pulling: lbank : RVN3L/USDT [731/957]
# Pulling: lbank : RVN3S/USDT [732/957]
# Pulling: lbank : SAITAMA/USDT [733/957]
# Pulling: lbank : SAND/USDC [734/957]
# Pulling: lbank : SAND/USDT [735/957]
# Pulling: lbank : SAND3L/USDT [736/957]
# Pulling: lbank : SAND3S/USDT [737/957]
# Pulling: lbank : SAND5L/USDT [738/957]
# Pulling: lbank : SAND5S/USDT [739/957]
# Pulling: lbank : SANTOS/USDT [740/957]
# Pulling: lbank : SC3L/USDT [741/957]
# Pulling: lbank : SC3S/USDT [742/957]
# Pulling: lbank : SCRT/USDT [743/957]
# Pulling: lbank : SCRT3L/USDT [744/957]
# Pulling: lbank : SCRT3S/USDT [745/957]
# Pulling: lbank : SDT/USDT [746/957]
# Pulling: lbank : SENSO/USDT [747/957]
# Pulling: lbank : SERP/USDT [748/957]
# Pulling: lbank : SFP/USDT [749/957]
# Pulling: lbank : SFP3L/USDT [750/957]
# Pulling: lbank : SFP3S/USDT [751/957]
# Pulling: lbank : SG/USDT [752/957]
# Pulling: lbank : SHIB/BUSD [753/957]
# Pulling: lbank : SHIB/USDT [754/957]
# Pulling: lbank : SHIB3L/USDT [755/957]
# Pulling: lbank : SHIB3S/USDT [756/957]
# Pulling: lbank : SHIB5L/USDT [757/957]
# Pulling: lbank : SHIB5S/USDT [758/957]
# Pulling: lbank : SHIBDOGE/USDT [759/957]
# Pulling: lbank : SHIBELON/USDT [760/957]
# Pulling: lbank : SHIBLITE/USDT [761/957]
# Pulling: lbank : SHIK/USDT [762/957]
# Pulling: lbank : SHINJA(1M)/USDT [763/957]
# Pulling: lbank : SHIRYO/USDT [764/957]
# Pulling: lbank : SHR/USDT [765/957]
# Pulling: lbank : SIDO/USDT [766/957]
# Pulling: lbank : SILK/USDT [767/957]
# Pulling: lbank : SKL3L/USDT [768/957]
# Pulling: lbank : SKL3S/USDT [769/957]
# Pulling: lbank : SLP3L/USDT [770/957]
# Pulling: lbank : SLP3S/USDT [771/957]
# Pulling: lbank : SNX/USDT [772/957]
# Pulling: lbank : SNX3L/USDT [773/957]
# Pulling: lbank : SNX3S/USDT [774/957]
# Pulling: lbank : SOL/USDT [775/957]
# Pulling: lbank : SOL3L/USDT [776/957]
# Pulling: lbank : SOL3S/USDT [777/957]
# Pulling: lbank : SOL5S/USDT [778/957]
# Pulling: lbank : SOS/USDT [779/957]
# Pulling: lbank : SOV/USDT [780/957]
# Pulling: lbank : SPCFIN/USDT [781/957]
# Pulling: lbank : SPELL/USDT [782/957]
# Pulling: lbank : SPELL3L/USDT [783/957]
# Pulling: lbank : SPELL3S/USDT [784/957]
# Pulling: lbank : SPSI/USDT [785/957]
# Pulling: lbank : SQUIDGROW/USDT [786/957]
# Pulling: lbank : SSM/USDT [787/957]
# Pulling: lbank : SSS/USDT [788/957]
# Pulling: lbank : SSV/USDT [789/957]
# Pulling: lbank : SSV3L/USDT [790/957]
# Pulling: lbank : SSV3S/USDT [791/957]
# Pulling: lbank : STAR1/USDT [792/957]
# Pulling: lbank : STARL/USDT [793/957]
# Pulling: lbank : STEP/USDT [794/957]
# Pulling: lbank : STG/USDT [795/957]
# Pulling: lbank : STLE/USDT [796/957]
# Pulling: lbank : STMX3L/USDT [797/957]
# Pulling: lbank : STMX3S/USDT [798/957]
# Pulling: lbank : STO/USDT [799/957]
# Pulling: lbank : STORJ/USDT [800/957]
# Pulling: lbank : STORJ3L/USDT [801/957]
# Pulling: lbank : STORJ3S/USDT [802/957]
# Pulling: lbank : STX/USDT [803/957]
# Pulling: lbank : SUDO/USDT [804/957]
# Pulling: lbank : SUPER/USDT [805/957]
# Pulling: lbank : SUSHI/USDT [806/957]
# Pulling: lbank : SUSHI3L/USDT [807/957]
# Pulling: lbank : SUSHI3S/USDT [808/957]
# Pulling: lbank : SUSHI5L/USDT [809/957]
# Pulling: lbank : SUSHI5S/USDT [810/957]
# Pulling: lbank : SWEAT/USDT [811/957]
# Pulling: lbank : SXP/USDT [812/957]
# Pulling: lbank : SXP3L/USDT [813/957]
# Pulling: lbank : SXP3S/USDT [814/957]
# Pulling: lbank : SYLMYDID/USDT [815/957]
# Pulling: lbank : SYN/USDT [816/957]
# Pulling: lbank : T/USDT [817/957]
# Pulling: lbank : TABOO/USDT [818/957]
# Pulling: lbank : TAMA/USDT [819/957]
# Pulling: lbank : TBP/USDT [820/957]
# Pulling: lbank : TCG2/USDT [821/957]
# Pulling: lbank : THE/USDT [822/957]
# Pulling: lbank : THE9/USDT [823/957]
# Pulling: lbank : THETA3L/USDT [824/957]
# Pulling: lbank : THETA3S/USDT [825/957]
# Pulling: lbank : THX/USDT [826/957]
# Pulling: lbank : TLC/USDT [827/957]
# Pulling: lbank : TLM3L/USDT [828/957]
# Pulling: lbank : TLM3S/USDT [829/957]
# Pulling: lbank : TMC/USDT [830/957]
# Pulling: lbank : TNT/USDT [831/957]
# Pulling: lbank : TOKAMAK/USDT [832/957]
# Pulling: lbank : TOLLS/USDT [833/957]
# Pulling: lbank : TOMO/USDT [834/957]
# Pulling: lbank : TOMO3L/USDT [835/957]
# Pulling: lbank : TOMO3S/USDT [836/957]
# Pulling: lbank : TON/USDT [837/957]
# Pulling: lbank : TOWN/USDT [838/957]
# Pulling: lbank : TPY/USDT [839/957]
# Pulling: lbank : TRA/USDT [840/957]
# Pulling: lbank : TRB3L/USDT [841/957]
# Pulling: lbank : TRB3S/USDT [842/957]
# Pulling: lbank : TREES/USDT [843/957]
# Pulling: lbank : TRG/USDT [844/957]
# Pulling: lbank : TRIX/USDT [845/957]
# Pulling: lbank : TRL/USDT [846/957]
# Pulling: lbank : TRMX/USDT [847/957]
# Pulling: lbank : TRU/USDT [848/957]
# Pulling: lbank : TRX/ETH [849/957]
# Pulling: lbank : TRX/USDC [850/957]
# Pulling: lbank : TRX/USDT [851/957]
# Pulling: lbank : TRX3L/USDT [852/957]
# Pulling: lbank : TRX3S/USDT [853/957]
# Pulling: lbank : TRX5L/USDT [854/957]
# Pulling: lbank : TRX5S/USDT [855/957]
# Pulling: lbank : TUR/USDT [856/957]
# Pulling: lbank : TVK/USDT [857/957]
# Pulling: lbank : TVS/USDT [858/957]
# Pulling: lbank : TWT/USDT [859/957]
# Pulling: lbank : UFO/USDT [860/957]
# Pulling: lbank : UMA/USDT [861/957]
# Pulling: lbank : UNFI3L/USDT [862/957]
# Pulling: lbank : UNFI3S/USDT [863/957]
# Pulling: lbank : UNI/USDT [864/957]
# Pulling: lbank : UNI3L/USDT [865/957]
# Pulling: lbank : UNI3S/USDT [866/957]
# Pulling: lbank : UNI5L/USDT [867/957]
# Pulling: lbank : UNI5S/USDT [868/957]
# Pulling: lbank : UNW/USDT [869/957]
# Pulling: lbank : UPS/USDT [870/957]
# Pulling: lbank : USDC/USDT [871/957]
# Pulling: lbank : USDD/USDT [872/957]
# Pulling: lbank : UTK/USDT [873/957]
# Pulling: lbank : UUSD/USDT [874/957]
# Pulling: lbank : VEGA/USDT [875/957]
# Pulling: lbank : VELO/USDT [876/957]
# Pulling: lbank : VET/USDT [877/957]
# Pulling: lbank : VET3L/USDT [878/957]
# Pulling: lbank : VET3S/USDT [879/957]
# Pulling: lbank : VEX/USDT [880/957]
# Pulling: lbank : VIC/USDT [881/957]
# Pulling: lbank : VICA/USDT [882/957]
# Pulling: lbank : VITA/USDT [883/957]
# Pulling: lbank : VNXAU/USDT [884/957]
# Pulling: lbank : VOB/USDT [885/957]
# Pulling: lbank : VOLT/USDT [886/957]
# Pulling: lbank : VOXEL/USDT [887/957]
# Pulling: lbank : VRT/USDT [888/957]
# Pulling: lbank : VST/USDT [889/957]
# Pulling: lbank : VT/USDT [890/957]
# Pulling: lbank : WAHED/USDT [891/957]
# Pulling: lbank : WAVES/USDT [892/957]
# Pulling: lbank : WAVES3L/USDT [893/957]
# Pulling: lbank : WAVES3S/USDT [894/957]
# Pulling: lbank : WAXE/USDT [895/957]
# Pulling: lbank : WAXP/USDT [896/957]
# Pulling: lbank : WBC/USDT [897/957]
# Pulling: lbank : WBX/USDT [898/957]
# Pulling: lbank : WCA/USDT [899/957]
# Pulling: lbank : WELUPS/USDT [900/957]
# Pulling: lbank : WIN/USDT [901/957]
# Pulling: lbank : WMX/USDT [902/957]
# Pulling: lbank : WOO/USDT [903/957]
# Pulling: lbank : WOOF/USDT [904/957]
# Pulling: lbank : WV/USDT [905/957]
# Pulling: lbank : WWY/USDT [906/957]
# Pulling: lbank : X2Y2/USDT [907/957]
# Pulling: lbank : XCC/USDT [908/957]
# Pulling: lbank : XCH/USDT [909/957]
# Pulling: lbank : XEM3L/USDT [910/957]
# Pulling: lbank : XEM3S/USDT [911/957]
# Pulling: lbank : XLM/USDT [912/957]
# Pulling: lbank : XLM3L/USDT [913/957]
# Pulling: lbank : XLM3S/USDT [914/957]
# Pulling: lbank : XMR3L/USDT [915/957]
# Pulling: lbank : XMR3S/USDT [916/957]
# Pulling: lbank : XMT/USDT [917/957]
# Pulling: lbank : XRD/USDT [918/957]
# Pulling: lbank : XRP/BUSD [919/957]
# Pulling: lbank : XRP/ETH [920/957]
# Pulling: lbank : XRP/USDC [921/957]
# Pulling: lbank : XRP/USDT [922/957]
# Pulling: lbank : XRP3L/USDT [923/957]
# Pulling: lbank : XRP3S/USDT [924/957]
# Pulling: lbank : XRP5L/USDT [925/957]
# Pulling: lbank : XRP5S/USDT [926/957]
# Pulling: lbank : XSPECTAR/USDT [927/957]
# Pulling: lbank : XT/USDT [928/957]
# Pulling: lbank : XTZ/USDT [929/957]
# Pulling: lbank : XTZ3L/USDT [930/957]
# Pulling: lbank : XTZ3S/USDT [931/957]
# Pulling: lbank : XWC2/BTC [932/957]
# Pulling: lbank : XWC2/ETH [933/957]
# Pulling: lbank : YELO/USDT [934/957]
# Pulling: lbank : YEON/USDT [935/957]
# Pulling: lbank : YFI3L/USDT [936/957]
# Pulling: lbank : YFI3S/USDT [937/957]
# Pulling: lbank : YFII/USDT [938/957]
# Pulling: lbank : YFII3L/USDT [939/957]
# Pulling: lbank : YFII3S/USDT [940/957]
# Pulling: lbank : YGG/USDT [941/957]
# Pulling: lbank : ZAMZAM/USDC [942/957]
# Pulling: lbank : ZBC/USDT [943/957]
# Pulling: lbank : ZEC/USDT [944/957]
# Pulling: lbank : ZEC3L/USDT [945/957]
# Pulling: lbank : ZEC3S/USDT [946/957]
# Pulling: lbank : ZEN/USDT [947/957]
# Pulling: lbank : ZEN3L/USDT [948/957]
# Pulling: lbank : ZEN3S/USDT [949/957]
# Pulling: lbank : ZEXI/USDT [950/957]
# Pulling: lbank : ZIK/USDT [951/957]
# Pulling: lbank : ZIL/USDT [952/957]
# Pulling: lbank : ZIL3L/USDT [953/957]
# Pulling: lbank : ZIL3S/USDT [954/957]
# Pulling: lbank : ZINU/USDT [955/957]
# Pulling: lbank : ZRX3L/USDT [956/957]
# Pulling: lbank : ZRX3S/USDT [957/957]
# []
