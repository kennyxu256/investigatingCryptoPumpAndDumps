# %% [markdown]
# <a href="https://colab.research.google.com/github/kennyxu256/investigatingCryptoPumpAndDumps/blob/main/march2023DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I used Google Colab for analysis, so ignore the first code block if you aren't.

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Senior Year/busi 496/dataAnalysis/newData
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Senior Year/busi 496/dataAnalysis/newData

# %%
# !pip install ccxt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ccxt
#   Downloading ccxt-3.0.83-py2.py3-none-any.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 30.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt) (2022.12.7)
# Collecting aiohttp>=3.8
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from ccxt) (2.27.1)
# Collecting aiodns>=1.1.1
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting yarl>=1.7.2
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt) (40.0.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt) (67.7.2)
# Collecting pycares>=4.0.0
#   Downloading pycares-4.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 15.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 12.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.8->ccxt) (23.1.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt) (1.15.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->ccxt) (1.26.15)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.21)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, pycares, aiosignal, aiohttp, aiodns, ccxt
# Successfully installed aiodns-3.0.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 ccxt-3.0.83 frozenlist-1.3.3 multidict-6.0.4 pycares-4.3.0 yarl-1.9.2

# %%
import ccxt
import pandas as pd
import os

# gets symbol name from the csv file
def get_symbol(f_path):
    df = pd.read_csv(f_path, index_col=0, parse_dates=["Timestamp"])
    filename = os.path.basename(f_path)
    symbol_name = filename.split("_")[1].replace("-", "/")
    print("Loading:", symbol_name)

    return symbol_name


# extracts the symbol pairs and stores them in a df per exchange
def extract_symbol_df_from_csvs(folder):
    for subdir, dirs, files in os.walk(folder):
        symbols = []

        exchange_n = subdir.split("/")[-1]

        if 'data' not in exchange_n:
            for file in files:
                if ".csv" in file:
                    symbols.append(get_symbol('../data/' + subdir + '/' + file))
            header = ['Symbol']
            df = pd.DataFrame(symbols, columns=header)
            filename = '{}_symbols.csv'.format(exchange_n)
            df.to_csv(filename)


# analyses all the symbol pairs in subfolders of a given folder
# returns a df indexed by exchange with the number price and volume spikes, and number of pumps
def analyse_folder(folder, vol_thresh, price_thresh, window_size=24, candle_size='1h'):
    row_list = []  # list for each row of the result df

    # -- loop through folders --
    for subdir, dirs, files in os.walk(folder):
        for file in files:
            if ".csv" in file:
                f_path = subdir + '/' + file
                result_row = analyse_symbol(f_path, vol_thresh, price_thresh, window_size, candle_size)
                row_list.append(result_row)

    # -- create result df --
    df = pd.DataFrame(row_list)
    df.set_index('Exchange', inplace=True)
    df.sort_index(inplace=True)

    return df


# Main analysis method for pump and dump detection. Returns final dataframe with number of pump and dumps.

def analyse_symbol(f_path, volume_thresh, price_thresh, window_size, candle_size):
    # -- load the data --
    exchange_name, symbol_name, df = load_csv(f_path)

    # -- find spikes --
    vol_mask, vol_df = find_vol_spikes(df, volume_thresh, window_size)
    num_v_spikes = get_num_rows(vol_df)  # the number of volume spikes found for this symbol pair

    price_mask, price_df = find_price_spikes(df, price_thresh, window_size)
    num_p_spikes = get_num_rows(price_df)

    pd_mask, pd_df = find_price_dumps(df, window_size)

    vd_mask, vd_df = find_volume_dumps(df, window_size)

    # find coinciding price and volume spikes
    vp_combined_mask = (vol_mask) & (price_mask)
    vp_combined_df = df[vp_combined_mask]
    num_vp_combined_rows = get_num_rows(vp_combined_df)

    # coinciding price and volume spikes for alleged P&D (more than 1x per given time removed)
    vp_combined_rm = rm_same_day_pumps(vp_combined_df)
    num_alleged = get_num_rows(vp_combined_rm)

    # find coinciding price and volume spikes with dumps
    final_combined_mask = (vol_mask) & (price_mask) & (pd_mask)
    final_combined = df[final_combined_mask]
    final_combined_rm = rm_same_day_pumps(final_combined)  # remove indicators which occur on the same day
    num_final_combined = get_num_rows(final_combined_rm)

    row_entry = {'Exchange': exchange_name,
                 'Symbol': symbol_name,
                 'Price Spikes': num_p_spikes,
                 'Volume Spikes': num_v_spikes,
                 'Alleged Pump and Dumps': num_alleged,
                 'Pump and Dumps': num_final_combined}

    print(row_entry)

    return row_entry


def get_num_rows(df):
    return df.shape[0]


def rm_same_day_pumps(df):
    # Removes spikes that occur on the same day
    df = df.copy()
    df['Timestamp_DAYS'] = df['Timestamp'].apply(lambda x: x.replace(hour=0, minute=0, second=0))
    df = df.drop_duplicates(subset='Timestamp_DAYS', keep='last')

    return df


# finds volume spikes with a certain threshold and window size
# returns a boolean_mask, dataframe
def find_vol_spikes(df, v_thresh, win_size):
    # -- add rolling average column to df --
    vRA = str(win_size) + 'h Volume RA'
    add_RA(df, win_size, 'Volume', vRA)

    # -- find spikes --
    vol_threshold = v_thresh * df[vRA]  # v_thresh increase in volume
    vol_spike_mask = df["Volume"] > vol_threshold  # where the volume is at least v_thresh greater than the x-hr RA
    df_vol_spike = df[vol_spike_mask]

    return vol_spike_mask, df_vol_spike


# finds price spikes with a certain threshold and window size
# returns a boolean_mask, dataframe
def find_price_spikes(df, p_thresh, win_size):
    # -- add rolling average column to df --
    pRA = str(win_size) + 'h Close Price RA'
    add_RA(df, win_size, 'Close', pRA)

    # -- find spikes --
    p_threshold = p_thresh * df[pRA]  # p_thresh increase in price
    p_spike_mask = df["High"] > p_threshold  # where the high is at least p_thresh greater than the x-hr RA
    df_price_spike = df[p_spike_mask]
    return p_spike_mask, df_price_spike


# finds price dumps with a certain threshold and window size
# returns a boolean_mask, dataframe
def find_price_dumps(df, win_size):
    pRA = str(win_size) + "h Close Price RA"
    pRA_plus = pRA + "+" + str(win_size)

    df[pRA_plus] = df[pRA].shift(-win_size)
    price_dump_mask = df[pRA_plus] <= (df[pRA] + df[pRA].std())
    # if the xhour RA from after the pump was detected is <= the xhour RA (+std dev) from before the pump was detected
    # if the price goes from the high to within a range of what it was before

    df_p_dumps = df[price_dump_mask]
    return price_dump_mask, df_p_dumps


def find_volume_dumps(df, win_size):
    vRA = str(win_size) + "h Volume RA"
    vRA_plus = vRA + "+" + str(win_size)

    df[vRA_plus] = df[vRA].shift(-win_size)
    price_dump_mask = df[vRA_plus] <= (df[vRA] + df[vRA].std())
    # if the xhour RA from after the pump was detected is <= the xhour RA (+std dev) from before the pump was detected
    # if the volume goes from the high to within a range of what it was before

    df_p_dumps = df[price_dump_mask]
    return price_dump_mask, df_p_dumps


# adds a rolling average column with specified window size to a given df and col
def add_RA(df, win_size, col, name):
    df[name] = pd.Series.rolling(df[col], window=win_size, center=False).mean()


# returns a (exchange_name ,symbol_name, dataframe) tuple
def load_csv(f_path, suppress=True):
    df = pd.read_csv(f_path, index_col=0, parse_dates=["Timestamp"])
    filename = os.path.basename(f_path)
    exchange_name = filename.split("_")[0]
    symbol_name = filename.split("_")[1].replace("-", "/")

    if not suppress:
        print("Exchange:", exchange_name, "\nSymbol:", symbol_name)

    return exchange_name, symbol_name, df

# %%
def countTransactions(f_path):
  df = pd.read_csv(f_path, index_col=0, parse_dates=["Timestamp"])
  return len(df.index)

# %%
def countVolume(f_path):
  df = pd.read_csv(f_path, index_col=0, parse_dates=['Timestamp'])
  return df['Volume'].sum()

# %%
def checkForPumps(f_path):
  dictionary = analyse_symbol(f_path=file,
               volume_thresh=4.2,
               price_thresh=1.05,
               window_size=12,
               candle_size='1h')
  return dictionary['Pump and Dumps']

# %%
print(countTransactions(f_path='bittrex/bittrex_1ECO-BTC_[2023-03-10 00.00.00]-TO-[2023-03-29 00.00.00].csv'))
# Out:
# 457

# %%
print(countVolume(f_path='bittrex/bittrex_1ECO-BTC_[2023-03-10 00.00.00]-TO-[2023-03-29 00.00.00].csv'))
# Out:
# 8826.53704126

# %%
exchangeDict = {'bittrex': [], 'kraken': [], 'kucoin': [], 'lbank': []}

# %% [markdown]
# ***DISCLAIMER:***
# the following data analysis is highly specific to my dataset. parameters and file names should be adjusted according to your data

# %%
infoList = []
for file in os.listdir('bittrex'):
    file = 'bittrex/' + file
    infoList.append(analyse_symbol(f_path=file,
               volume_thresh=4.2,
               price_thresh=1.05,
               window_size=12,
               candle_size='1h'))
exchangeDict['bittrex'] = infoList
# Out:
# {'Exchange': 'bittrex', 'Symbol': '1ECO/BTC', 'Price Spikes': 67, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': '1ECO/USDT', 'Price Spikes': 32, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/BTC', 'Price Spikes': 6, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/ETH', 'Price Spikes': 4, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/USD', 'Price Spikes': 12, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/USDT', 'Price Spikes': 20, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': '1PECO/BTC', 'Price Spikes': 176, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': '1PECO/USDT', 'Price Spikes': 61, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': '4ART/BTC', 'Price Spikes': 11, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': '4ART/USDT', 'Price Spikes': 1, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/BTC', 'Price Spikes': 5, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/ETH', 'Price Spikes': 6, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/EUR', 'Price Spikes': 4, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/USD', 'Price Spikes': 16, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/USDT', 'Price Spikes': 6, 'Volume Spikes': 43, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ABBC/BTC', 'Price Spikes': 2, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ABYSS/BTC', 'Price Spikes': 1, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ACH/USD', 'Price Spikes': 47, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ACXT/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/BTC', 'Price Spikes': 3, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/ETH', 'Price Spikes': 6, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/EUR', 'Price Spikes': 6, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/USD', 'Price Spikes': 11, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/USDC', 'Price Spikes': 13, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/USDT', 'Price Spikes': 10, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADK/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADX/BTC', 'Price Spikes': 0, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AGRS/BTC', 'Price Spikes': 30, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'AGRS/USDT', 'Price Spikes': 33, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': 'AGV/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AIN/USDT', 'Price Spikes': 18, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AKN/USDT', 'Price Spikes': 5, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AKRO/BTC', 'Price Spikes': 0, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AKT/BTC', 'Price Spikes': 8, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AKT/USDT', 'Price Spikes': 14, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AKTIO/USDT', 'Price Spikes': 21, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'ALGO/BTC', 'Price Spikes': 11, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ALGO/USD', 'Price Spikes': 14, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ALGO/USDT', 'Price Spikes': 17, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ALTA/USDT', 'Price Spikes': 28, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/BTC', 'Price Spikes': 17, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/ETH', 'Price Spikes': 6, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/USD', 'Price Spikes': 6, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/USDT', 'Price Spikes': 23, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'ANKR/BTC', 'Price Spikes': 4, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ANKR/ETH', 'Price Spikes': 3, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ANKR/USD', 'Price Spikes': 15, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ANT/BTC', 'Price Spikes': 0, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ANT/ETH', 'Price Spikes': 0, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 
 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/USD', 'Price Spikes': 13, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/USDC', 'Price Spikes': 12, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/USDT', 'Price Spikes': 13, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BTCV/BTC', 'Price Spikes': 10, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BTCV/USDT', 'Price Spikes': 29, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'BTD/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTRIPS/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTRST/USD', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTS/BTC', 'Price Spikes': 5, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BTU/BTC', 'Price Spikes': 38, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CAIZ/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CAST/USDT', 'Price Spikes': 0, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CBANK/USDT', 'Price Spikes': 0, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CBC/BTC', 'Price Spikes': 7, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CDEX/USDT', 'Price Spikes': 29, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CEDS/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/BTC', 'Price Spikes': 10, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/ETH', 'Price Spikes': 6, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/USD', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/USDT', 'Price Spikes': 7, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/BTC', 'Price Spikes': 1, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/ETH', 'Price Spikes': 7, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/EUR', 'Price Spikes': 9, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/USD', 'Price Spikes': 23, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/USDT', 'Price Spikes': 9, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'CHNG/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CIND/USDT', 'Price Spikes': 20, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'CIV/USDT', 'Price Spikes': 1, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CKB/BTC', 'Price Spikes': 34, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'CKB/USD', 'Price Spikes': 41, 'Volume Spikes': 47, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'CKB/USDT', 'Price Spikes': 55, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'bittrex', 'Symbol': 'CLI/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CLT/BTC', 'Price Spikes': 0, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CLT/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CLXY/USDT', 'Price Spikes': 0, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CMCX/USDT', 'Price Spikes': 2, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CND/BTC', 'Price Spikes': 37, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CNTM/USDT', 'Price Spikes': 34, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'COMP/BTC', 'Price Spikes': 1, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'COMP/ETH', 'Price Spikes': 0, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}

# %%
infoList = []
for file in os.listdir('kraken'):
    file = 'kraken/' + file
    infoList.append(analyse_symbol(f_path=file,
               volume_thresh=4.2,
               price_thresh=1.05,
               window_size=12,
               candle_size='1h'))
exchangeDict['kraken'] = infoList
# Out:
# {'Exchange': 'kraken', 'Symbol': '1INCH/EUR', 'Price Spikes': 7, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': '1INCH/USD', 'Price Spikes': 8, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 
 'Volume Spikes': 37, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ANT/ETH', 'Price Spikes': 0, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ANT/EUR', 'Price Spikes': 5, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ANT/USD', 'Price Spikes': 5, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'APE/EUR', 'Price Spikes': 13, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'APE/USD', 'Price Spikes': 17, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'APE/USDT', 'Price Spikes': 13, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'API3/EUR', 'Price Spikes': 26, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'API3/USD', 'Price Spikes': 27, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'APT/EUR', 'Price Spikes': 23, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'APT/USD', 'Price Spikes': 25, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ARB/EUR', 'Price Spikes': 13, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ARB/USD', 'Price Spikes': 11, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ARPA/EUR', 'Price Spikes': 28, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ARPA/USD', 'Price Spikes': 43, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'ASTR/EUR', 'Price Spikes': 18, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'ASTR/USD', 'Price Spikes': 23, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'ATLAS/EUR', 'Price Spikes': 15, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ATLAS/USD', 'Price Spikes': 15, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/BTC', 'Price Spikes': 5, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/ETH', 'Price Spikes': 3, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/EUR', 'Price Spikes': 6, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/GBP', 'Price Spikes': 6, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/USD', 'Price Spikes': 6, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/USDT', 'Price Spikes': 8, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'AUD/JPY', 'Price Spikes': 0, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'AUD/USD', 'Price Spikes': 0, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'AUDIO/EUR', 'Price Spikes': 29, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'AUDIO/USD', 'Price Spikes': 24, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'AVAX/EUR', 'Price Spikes': 14, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'AVAX/USD', 'Price Spikes': 16, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'AVAX/USDT', 'Price Spikes': 28, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'AXS/EUR', 'Price Spikes': 20, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'AXS/USD', 'Price Spikes': 22, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BADGER/EUR', 'Price Spikes': 11, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BADGER/USD', 'Price Spikes': 13, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BAL/BTC', 'Price Spikes': 1, 'Volume Spikes': 48, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BAL/EUR', 'Price Spikes': 2, 'Volume Spikes': 46, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BAL/USD', 'Price Spikes': 6, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BAND/EUR', 'Price Spikes': 15, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BAND/USD', 'Price Spikes': 22, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BAT/BTC', 'Price Spikes': 2, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BAT/ETH', 'Price Spikes': 0, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BAT/EUR', 'Price Spikes': 13, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BAT/JPY', 'Price Spikes': 10, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BAT/USD', 'Price Spikes': 14, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BCH/AUD', 'Price Spikes': 1, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/BTC', 'Price Spikes': 0, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/ETH', 'Price Spikes': 0, 'Volume Spikes': 49, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/EUR', 'Price Spikes': 4, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/GBP', 'Price Spikes': 5, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BCH/JPY', 'Price Spikes': 2, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/USD', 'Price Spikes': 4, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/USDT', 'Price Spikes': 3, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BICO/EUR', 'Price Spikes': 17, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'BICO/USD', 'Price Spikes': 19, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'BIT/EUR', 'Price Spikes': 24, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BIT/USD', 'Price Spikes': 2, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BLUR/EUR', 'Price Spikes': 43, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BLUR/USD', 'Price Spikes': 55, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BLZ/EUR', 'Price Spikes': 19, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'BLZ/USD', 'Price Spikes': 24, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'BNC/EUR', 'Price Spikes': 43, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'BNC/USD', 'Price Spikes': 52, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'BNT/BTC', 'Price Spikes': 6, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BNT/EUR', 'Price Spikes': 11, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BNT/USD', 'Price Spikes': 14, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BOBA/EUR', 'Price Spikes': 14, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BOBA/USD', 'Price Spikes': 7, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BOND/EUR', 'Price Spikes': 8, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BOND/USD', 'Price Spikes': 4, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BSX/EUR', 'Price Spikes': 47, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 10, 'Pump and Dumps': 8}
# {'Exchange': 'kraken', 'Symbol': 'BSX/USD', 'Price Spikes': 51, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'BTC/AUD', 'Price Spikes': 11, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/CAD', 'Price Spikes': 14, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/CHF', 'Price Spikes': 13, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/DAI', 'Price Spikes': 17, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BTC/EUR', 'Price Spikes': 11, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/GBP', 'Price Spikes': 12, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/JPY', 'Price Spikes': 9, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/USD', 'Price Spikes': 13, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/USDC', 'Price Spikes': 19, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/USDT', 'Price Spikes': 13, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BTT/EUR', 'Price Spikes': 2, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTT/USD', 'Price Spikes': 2, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'C98/EUR', 'Price Spikes': 8, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'C98/USD', 'Price Spikes': 13, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CELR/EUR', 'Price Spikes': 50, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CELR/USD', 'Price Spikes': 47, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CFG/EUR', 'Price Spikes': 28, 'Volume Spikes': 47, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'CFG/USD', 'Price Spikes': 31, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CHR/EUR', 'Price Spikes': 16, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'CHR/USD', 'Price Spikes': 11, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CHZ/EUR', 'Price Spikes': 0, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'CHZ/USD', 'Price Spikes': 0, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'COMP/BTC', 'Price Spikes': 0, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'COMP/EUR', 'Price Spikes': 12, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'COMP/USD', 'Price Spikes': 12, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'COTI/EUR', 'Price Spikes': 19, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'COTI/USD', 'Price Spikes': 17, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CQT/EUR', 'Price Spikes': 15, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CQT/USD', 'Price Spikes': 14, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/BTC', 'Price Spikes': 1, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/ETH', 'Price Spikes': 1, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/EUR', 'Price Spikes': 17, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/USD', 'Price Spikes': 21, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CSM/EUR', 'Price Spikes': 60, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CSM/USD', 'Price Spikes': 70, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'CTSI/EUR', 'Price Spikes': 12, 'Volume Spikes': 46, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CTSI/USD', 'Price Spikes': 17, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'CVC/EUR', 'Price Spikes': 11, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CVC/USD', 'Price Spikes': 7, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CVX/EUR', 'Price Spikes': 17, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'CVX/USD', 'Price Spikes': 13, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'DAI/EUR', 'Price Spikes': 0, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DAI/USD', 'Price Spikes': 0, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DAI/USDT', 'Price Spikes': 0, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 
 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ETH/USDC', 'Price Spikes': 12, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ETH/USDT', 'Price Spikes': 6, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ETH2.S/ETH', 'Price Spikes': 0, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ETHW/ETH', 'Price Spikes': 2, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ETHW/EUR', 'Price Spikes': 4, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ETHW/USD', 'Price Spikes': 4, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EUL/EUR', 'Price Spikes': 80, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'EUL/USD', 'Price Spikes': 81, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'kraken', 'Symbol': 'EUR/AUD', 'Price Spikes': 0, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EUR/CAD', 'Price Spikes': 0, 'Volume Spikes': 46, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EUR/CHF', 'Price Spikes': 0, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EUR/GBP', 'Price Spikes': 0, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EUR/JPY', 'Price Spikes': 0, 'Volume Spikes': 49, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EUR/USD', 'Price Spikes': 0, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EWT/BTC', 'Price Spikes': 1, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'EWT/EUR', 'Price Spikes': 12, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'EWT/GBP', 'Price Spikes': 12, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'EWT/USD', 'Price Spikes': 8, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'FARM/EUR', 'Price Spikes': 8, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FARM/USD', 'Price Spikes': 3, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FET/EUR', 'Price Spikes': 26, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FET/USD', 'Price Spikes': 32, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'FIDA/EUR', 'Price Spikes': 14, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'FIDA/USD', 'Price Spikes': 19, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'FIL/BTC', 'Price Spikes': 17, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FIL/ETH', 'Price Spikes': 15, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'FIL/EUR', 'Price Spikes': 34, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FIL/GBP', 'Price Spikes': 26, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FIL/USD', 'Price Spikes': 39, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FIS/EUR', 'Price Spikes': 30, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FIS/USD', 'Price Spikes': 25, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FLOW/BTC', 'Price Spikes': 6, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FLOW/ETH', 'Price Spikes': 5, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FLOW/EUR', 'Price Spikes': 16, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FLOW/GBP', 'Price Spikes': 11, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FLOW/USD', 'Price Spikes': 17, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'FLR/EUR', 'Price Spikes': 26, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FLR/USD', 'Price Spikes': 31, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'FORTH/EUR', 'Price Spikes': 10, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'FORTH/USD', 'Price Spikes': 12, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'FTM/EUR', 'Price Spikes': 40, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'FTM/USD', 'Price Spikes': 46, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'FXS/EUR', 'Price Spikes': 22, 'Volume Spikes': 49, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'FXS/USD', 'Price Spikes': 30, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GAL/EUR', 'Price Spikes': 33, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'kraken', 'Symbol': 'GAL/USD', 'Price Spikes': 32, 'Volume Spikes': 43, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'GALA/EUR', 'Price Spikes': 29, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'GALA/USD', 'Price Spikes': 33, 'Volume Spikes': 14, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'GARI/EUR', 'Price Spikes': 18, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'GARI/USD', 'Price Spikes': 8, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'GBP/USD', 'Price Spikes': 0, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'GHST/BTC', 'Price Spikes': 12, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'GHST/EUR', 'Price Spikes': 27, 'Volume Spikes': 43, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GHST/USD', 'Price Spikes': 25, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'GLMR/EUR', 'Price Spikes': 16, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'GLMR/USD', 'Price Spikes': 22, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GMT/EUR', 'Price Spikes': 27, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GMT/USD', 'Price Spikes': 32, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'GMX/EUR', 'Price Spikes': 33, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GMX/USD', 'Price Spikes': 36, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GNO/BTC', 'Price Spikes': 0, 'Volume Spikes': 54, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'GNO/EUR', 'Price Spikes': 2, 'Volume Spikes': 47, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'GNO/USD', 'Price Spikes': 6, 'Volume Spikes': 49, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'GRT/BTC', 'Price Spikes': 17, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'GRT/EUR', 'Price Spikes': 38, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'GRT/GBP', 'Price Spikes': 33, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GRT/USD', 'Price Spikes': 43, 'Volume Spikes': 14, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GST/EUR', 'Price Spikes': 29, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'GST/USD', 'Price Spikes': 30, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'GTC/EUR', 'Price Spikes': 38, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'GTC/USD', 'Price Spikes': 44, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'HDX/EUR', 'Price Spikes': 31, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'HDX/USD', 'Price Spikes': 65, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'kraken', 'Symbol': 'HFT/EUR', 'Price Spikes': 15, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'HFT/USD', 'Price Spikes': 24, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ICP/EUR', 'Price Spikes': 11, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ICP/USD', 'Price Spikes': 15, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ICX/BTC', 'Price Spikes': 1, 'Volume Spikes': 52, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ICX/ETH', 'Price Spikes': 2, 'Volume Spikes': 43, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ICX/EUR', 'Price Spikes': 10, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'ICX/USD', 'Price Spikes': 12, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'IDEX/EUR', 'Price Spikes': 12, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'IDEX/USD', 'Price Spikes': 7, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'IMX/EUR', 'Price Spikes': 46, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'IMX/USD', 'Price Spikes': 62, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'INJ/EUR', 'Price Spikes': 69, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'INJ/USD', 'Price Spikes': 81, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'INTR/EUR', 'Price Spikes': 0, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'INTR/USD', 'Price Spikes': 0, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'JASMY/EUR', 'Price Spikes': 14, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'JASMY/USD', 'Price Spikes': 15, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'JUNO/EUR', 'Price Spikes': 27, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'JUNO/USD', 'Price Spikes': 8, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'KAR/EUR', 'Price Spikes': 12, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'KAR/USD', 'Price Spikes': 6, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'KAVA/BTC', 'Price Spikes': 2, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'KAVA/ETH', 'Price Spikes': 1, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'KAVA/EUR', 'Price Spikes': 20, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'KAVA/USD', 'Price Spikes': 20, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'KEEP/BTC', 'Price Spikes': 22, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'KEEP/EUR', 'Price Spikes': 32, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'KEEP/USD', 'Price Spikes': 27, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'KEY/EUR', 'Price Spikes': 67, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'KEY/USD', 'Price Spikes': 72, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'KILT/EUR', 'Price Spikes': 26, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'KILT/USD', 'Price Spikes': 27, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'KIN/EUR', 'Price Spikes': 31, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'KIN/USD', 'Price Spikes': 41, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 10, 'Pump and Dumps': 8}
# {'Exchange': 'kraken', 'Symbol': 'KINT/EUR', 'Price Spikes': 15, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 1}

# %%
infoList = []
for file in os.listdir('kucoin'):
    file = 'kucoin/' + file
    infoList.append(analyse_symbol(f_path=file,
               volume_thresh=4.2,
               price_thresh=1.05,
               window_size=12,
               candle_size='1h'))
exchangeDict['kucoin'] = infoList
# Out:
# {'Exchange': 'kucoin', 'Symbol': '1EARTH/USDT', 'Price Spikes': 28, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': '1INCH/USDT', 'Price Spikes': 9, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kucoin', 'Symbol': '2CRZ/USDT', 'Price Spikes': 32, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 2}
# {'Exchange': 'kucoin', 'Symbol': 'AAVE/BTC', 'Price Spikes': 0, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'AAVE/KCS', 'Price Spikes': 0, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'AAVE/USDT', 'Price Spikes': 9, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'AAVE3L/USDT', 'Price Spikes': 91, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kucoin', 'Symbol': 'AAVE3S/USDT', 'Price Spikes': 81, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 6}
# {'Exchange': 'kucoin', 'Symbol': 'ABBC/BTC', 'Price Spikes': 1, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ABBC/USDT', 'Price Spikes': 2, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ACA/BTC', 'Price Spikes': 15, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kucoin', 'Symbol': 'ACA/USDT', 'Price Spikes': 15, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kucoin', 'Symbol': 'ACE/USDT', 'Price Spikes': 21, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ACH/USDT', 'Price Spikes': 64, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kucoin', 'Symbol': 'ACOIN/USDT', 'Price Spikes': 50, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kucoin', 'Symbol': 'ACQ/USDC', 'Price Spikes': 27, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kucoin', 'Symbol': 'ACQ/USDT', 'Price Spikes': 24, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kucoin', 'Symbol': 'ACS/USDT', 'Price Spikes': 57, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kucoin', 'Symbol': 'ACT/USDT', 'Price Spikes': 2, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ADA/BTC', 'Price Spikes': 3, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ADA/KCS', 'Price Spikes': 3, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ADA/USDC', 'Price Spikes': 15, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ADA/USDT', 'Price Spikes': 11, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kucoin', 'Symbol': 'ADA3L/USDT', 'Price Spikes': 103, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kucoin', 'Symbol': 'ADA3S/USDT', 'Price Spikes': 74, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}

# %%
infoList = []
for file in os.listdir('lbank'):
    file = 'lbank/' + file
    infoList.append(analyse_symbol(f_path=file,
               volume_thresh=4.2,
               price_thresh=1.05,
               window_size=12,
               candle_size='1h'))
exchangeDict['lbank'] = infoList
# Out:
# {'Exchange': 'lbank', 'Symbol': '1INCH/USDT', 'Price Spikes': 14, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': '1INCH3L/USDT', 'Price Spikes': 86, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol
 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BCH5L/USDT', 'Price Spikes': 100, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 13, 'Pump and Dumps': 13}
# {'Exchange': 'lbank', 'Symbol': 'BCH5S/USDT', 'Price Spikes': 88, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'lbank', 'Symbol': 'BCL/USDT', 'Price Spikes': 64, 'Volume Spikes': 14, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'BEAR/USDT', 'Price Spikes': 75, 'Volume Spikes': 14, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 6}
# {'Exchange': 'lbank', 'Symbol': 'BEL1/USDT', 'Price Spikes': 30, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BEL3L/USDT', 'Price Spikes': 126, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BEL3S/USDT', 'Price Spikes': 116, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BERRY/USDT', 'Price Spikes': 46, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BFIC/USDT', 'Price Spikes': 15, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BFLOKIC/USDT', 'Price Spikes': 21, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'BIBL/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BICO/USDT', 'Price Spikes': 32, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BIO/USDT', 'Price Spikes': 118, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'BIT3L/USDT', 'Price Spikes': 51, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BIT3S/USDT', 'Price Spikes': 20, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BLID/USDT', 'Price Spikes': 26, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'BLOVELY/USDT', 'Price Spikes': 23, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BLUESPARROW/USDT', 'Price Spikes': 113, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BLUR/USDT', 'Price Spikes': 53, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BLZ/USDT', 'Price Spikes': 27, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BLZ3L/USDT', 'Price Spikes': 121, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BLZ3S/USDT', 'Price Spikes': 131, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNB/BUSD', 'Price Spikes': 5, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNB/ETH', 'Price Spikes': 11, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNB/USDT', 'Price Spikes': 3, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNB3L/USDT', 'Price Spikes': 48, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNB3S/USDT', 'Price Spikes': 36, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNT/USDT', 'Price Spikes': 18, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BNX/USDT', 'Price Spikes': 36, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BONE/USDT', 'Price Spikes': 22, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BONK/USDT', 'Price Spikes': 65, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BOTTO/USDT', 'Price Spikes': 35, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BP/USDT', 'Price Spikes': 46, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BRG/USDT', 'Price Spikes': 26, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'BRISE/USDT', 'Price Spikes': 36, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'BSV3L/USDT', 'Price Spikes': 72, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BSV3S/USDT', 'Price Spikes': 51, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BSV5L/USDT', 'Price Spikes': 103, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'BSV5S/USDT', 'Price Spikes': 82, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'lbank', 'Symbol': 'BSW/USDT', 'Price Spikes': 9, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BTC/BUSD', 'Price Spikes': 89, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BTC/USDC', 'Price Spikes': 37, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'BTC/USDT', 'Price Spikes': 13, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BTC3L/USDT', 'Price Spikes': 76, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'BTC3S/USDT', 'Price Spikes': 34, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': '
 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DINGO/USDT', 'Price Spikes': 79, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'DMCC/USDT', 'Price Spikes': 133, 'Volume Spikes': 14, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'DOCT/USDT', 'Price Spikes': 13, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DODO3L/USDT', 'Price Spikes': 160, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DODO3S/USDT', 'Price Spikes': 142, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'DOGE/USDC', 'Price Spikes': 11, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOGE/USDT', 'Price Spikes': 7, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOGE3L/USDT', 'Price Spikes': 84, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOGE3S/USDT', 'Price Spikes': 63, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOGE5L/USDT', 'Price Spikes': 112, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 10, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'DOGECOIN/USDT', 'Price Spikes': 14, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOGECOLA/USDT', 'Price Spikes': 8, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOT/USDC', 'Price Spikes': 6, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOT/USDT', 'Price Spikes': 9, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOT3L/USDT', 'Price Spikes': 98, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOT3S/USDT', 'Price Spikes': 84, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DOT5L/USDT', 'Price Spikes': 123, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 11, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'DOT5S/USDT', 'Price Spikes': 99, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 9, 'Pump and Dumps': 9}
# {'Exchange': 'lbank', 'Symbol': 'DRIVECRYPTO/USDT', 'Price Spikes': 123, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DSP/USDT', 'Price Spikes': 2, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DST/USDT', 'Price Spikes': 3, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DTH/USDT', 'Price Spikes': 93, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'lbank', 'Symbol': 'DTR/USDT', 'Price Spikes': 11, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'DVTC/USDT', 'Price Spikes': 22, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DYDX/USDT', 'Price Spikes': 42, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DYDX3L/USDT', 'Price Spikes': 179, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'DYDX3S/USDT', 'Price Spikes': 141, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'DZOO/USDT', 'Price Spikes': 62, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EBSO/USDT', 'Price Spikes': 2, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EDAT/USDT', 'Price Spikes': 80, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 11, 'Pump and Dumps': 11}
# {'Exchange': 'lbank', 'Symbol': 'EFK/USDT', 'Price Spikes': 1, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EGLD/USDT', 'Price Spikes': 9, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EGLD3L/USDT', 'Price Spikes': 101, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EGLD3S/USDT', 'Price Spikes': 73, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ELC/USDT', 'Price Spikes': 5, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ELYSIAN/USDT', 'Price Spikes': 136, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ENJ3L/USDT', 'Price Spikes': 103, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ENJ3S/USDT', 'Price Spikes': 109, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'ENJ5L/USDT', 'Price Spikes': 107, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'ENJ5S/USDT', 'Price Spikes': 100, 'Volume Spikes': 49, 'Alleged Pump and Dumps': 13, 'Pump and Dumps': 13}
# {'Exchange': 'lbank', 'Symbol': 'ENS/USDC', 'Price Spikes': 18, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ENS/USDT', 'Price Spikes': 19, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ENS3L/USDT', 'Price Spikes': 96, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ENS3S/USDT', 'Price Spikes': 93, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ENT/USDT', 'Price Spikes': 13, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EOS/USDC', 'Price Spikes': 6, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EOS/USDT', 'Price Spikes': 7, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EOS3L/USDT', 'Price Spikes': 104, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EOS3S/USDT', 'Price Spikes': 77, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EOS5L/USDT', 'Price Spikes': 151, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'EOS5S/USDT', 'Price Spikes': 118, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'EPIX/USDT', 'Price Spikes': 94, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EPX/USDT', 'Price Spikes': 6, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ERN/USDT', 'Price Spikes': 5, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ERR/USDT', 'Price Spikes': 7, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ESG/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EST/USDT', 'Price Spikes': 125, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETC/ETH', 'Price Spikes': 8, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETC/USDT', 'Price Spikes': 20, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETC3L/USDT', 'Price Spikes': 84, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETC3S/USDT', 'Price Spikes': 82, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETH/BTC', 'Price Spikes': 2, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETH/BUSD', 'Price Spikes': 44, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'ETH/USDC', 'Price Spikes': 24, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'ETH/USDT', 'Price Spikes': 8, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETH3L/USDT', 'Price Spikes': 74, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETH3S/USDT', 'Price Spikes': 45, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ETH5L/USDT', 'Price Spikes': 134, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'ETH5S/USDT', 'Price Spikes': 77, 'Volume Spikes': 52, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'ETHW/USDT', 'Price Spikes': 6, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EUL/USDT', 'Price Spikes': 77, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'EWC/USDT', 'Price Spikes': 59, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'EXN/USDT', 'Price Spikes': 2, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'EYE/USDT', 'Price Spikes': 57, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FAMEG/USDT', 'Price Spikes': 9, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FAST/USDT', 'Price Spikes': 22, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FCF/USDT', 'Price Spikes': 143, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'FEI/USDT', 'Price Spikes': 146, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'FET/USDT', 'Price Spikes': 34, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FIDA/USDT', 'Price Spikes': 18, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FIEF/USDT', 'Price Spikes': 11, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FIL/USDT', 'Price Spikes': 39, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FIL3S/USDT', 'Price Spikes': 130, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FIL5L/USDT', 'Price Spikes': 150, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 12, 'Pump and Dumps': 11}
# {'Exchange': 'lbank', 'Symbol': 'FIL5S/USDT', 'Price Spikes': 92, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'FIS/USDT', 'Price Spikes': 28, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FITFI/USDT', 'Price Spikes': 27, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FIWA/USDT', 'Price Spikes': 4, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FJT/USDT', 'Price Spikes': 23, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FLAG/USDT', 'Price Spikes': 26, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FLEX/USDT', 'Price Spikes': 18, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'FLM3L/USDT', 'Price Spikes': 118, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FLM3S/USDT', 'Price Spikes': 103, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FLOKI/USDT', 'Price Spikes': 65, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'FLOKICEO/USDT', 'Price Spikes': 175, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 12, 'Pump and Dumps': 12}
# ...
# {'Exchange': 'lbank', 'Symbol': 'TRA/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRB3L/USDT', 'Price Spikes': 105, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRB3S/USDT', 'Price Spikes': 104, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TREES/USDT', 'Price Spikes': 29, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRG/USDT', 'Price Spikes': 17, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRIX/USDT', 'Price Spikes': 60, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'lbank', 'Symbol': 'TRL/USDT', 'Price Spikes': 134, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRMX/USDT', 'Price Spikes': 110, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'TRU/USDT', 'Price Spikes': 47, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX/ETH', 'Price Spikes': 6, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX/USDC', 'Price Spikes': 11, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX/USDT', 'Price Spikes': 7, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX3L/USDT', 'Price Spikes': 54, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'TRX3S/USDT', 'Price Spikes': 38, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX5L/USDT', 'Price Spikes': 81, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'TRX5S/USDT', 'Price Spikes': 63, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'TUR/USDT', 'Price Spikes': 105, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'TVK/USDT', 'Price Spikes': 3, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TVS/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TWT/USDT', 'Price Spikes': 7, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UEDC/USDT', 'Price Spikes': 213, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'lbank', 'Symbol': 'UFO/USDT', 'Price Spikes': 7, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UMA/USDT', 'Price Spikes': 18, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UNFI3L/USDT', 'Price Spikes': 113, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UNFI3S/USDT', 'Price Spikes': 102, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UNI/USDT', 'Price Spikes': 9, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UNI3L/USDT', 'Price Spikes': 74, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UNI3S/USDT', 'Price Spikes': 66, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UNI5L/USDT', 'Price Spikes': 95, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 9, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'UNI5S/USDT', 'Price Spikes': 79, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'UNW/USDT', 'Price Spikes': 63, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'lbank', 'Symbol': 'UPS/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'USDC/USDT', 'Price Spikes': 2, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'USDD/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UTK/USDT', 'Price Spikes': 10, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'UUSD/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VEGA/USDT', 'Price Spikes': 8, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VELO/USDT', 'Price Spikes': 61, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VET/USDT', 'Price Spikes': 13, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VET3L/USDT', 'Price Spikes': 111, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VET3S/USDT', 'Price Spikes': 87, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VEX/USDT', 'Price Spikes': 72, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'VIC/USDT', 'Price Spikes': 47, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'VICA/USDT', 'Price Spikes': 39, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 
 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEC/USDT', 'Price Spikes': 11, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEC3L/USDT', 'Price Spikes': 109, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEC3S/USDT', 'Price Spikes': 88, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEN/USDT', 'Price Spikes': 19, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEN3L/USDT', 'Price Spikes': 115, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEN3S/USDT', 'Price Spikes': 114, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEXI/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIK/USDT', 'Price Spikes': 9, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIL/USDT', 'Price Spikes': 16, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIL3L/USDT', 'Price Spikes': 119, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIL3S/USDT', 'Price Spikes': 87, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZINU/USDT', 'Price Spikes': 141, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'ZRX3L/USDT', 'Price Spikes': 94, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZRX3S/USDT', 'Price Spikes': 88, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}

# %%
exchangeDict
# Out:
# {'bittrex': [{'Exchange': 'bittrex',
#    'Symbol': '1ECO/BTC',
#    'Price Spikes': 67,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': '1ECO/USDT',
#    'Price Spikes': 32,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': '1INCH/BTC',
#    'Price Spikes': 6,
#    'Volume Spikes': 44,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': '1INCH/ETH',
#    'Price Spikes': 4,
#    'Volume Spikes': 25,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': '1INCH/USD',
#    'Price Spikes': 12,
#    'Volume Spikes': 24,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': '1INCH/USDT',
#    'Price Spikes': 20,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': '1PECO/BTC',
#    'Price Spikes': 176,
#    'Volume Spikes': 9,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': '1PECO/USDT',
#    'Price Spikes': 61,
#    'Volume Spikes': 16,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 5},
#   {'Exchange': 'bittrex',
#    'Symbol': '4ART/BTC',
#    'Price Spikes': 11,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': '4ART/USDT',
#    'Price Spikes': 1,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AAVE/BTC',
#    'Price Spikes': 5,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AAVE/ETH',
#    'Price Spikes': 6,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AAVE/EUR',
#    'Price Spikes': 4,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AAVE/USD',
#    'Price Spikes': 16,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AAVE/USDT',
#    'Price Spikes': 6,
#    'Volume Spikes': 43,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ABBC/BTC',
#    'Price Spikes': 2,
#    'Volume Spikes': 16,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ABYSS/BTC',
#    'Price Spikes': 1,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ACH/USD',
#    'Price Spikes': 47,
#    'Volume Spikes': 18,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ACXT/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADA/BTC',
#    'Price Spikes': 3,
#    'Volume Spikes': 16,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADA/ETH',
#    'Price Spikes': 6,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADA/EUR',
#    'Price Spikes': 6,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADA/USD',
#    'Price Spikes': 11,
#    'Volume Spikes': 21,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADA/USDC',
#    'Price Spikes': 13,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADA/USDT',
#    'Price Spikes': 10,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADK/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ADX/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 16,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AGRS/BTC',
#    'Price Spikes': 30,
#    'Volume Spikes': 45,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AGRS/USDT',
#    'Price Spikes': 33,
#    'Volume Spikes': 45,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 5},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AGV/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AIN/USDT',
#    'Price Spikes': 18,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AKN/USDT',
#    'Price Spikes': 5,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AKRO/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AKT/BTC',
#    'Price Spikes': 8,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AKT/USDT',
#    'Price Spikes': 14,
#    'Volume Spikes': 11,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AKTIO/USDT',
#    'Price Spikes': 21,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ALGO/BTC',
#    'Price Spikes': 11,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ALGO/USD',
#    'Price Spikes': 14,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ALGO/USDT',
#    'Price Spikes': 17,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ALTA/USDT',
#    'Price Spikes': 28,
#    'Volume Spikes': 10,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AMP/BTC',
#    'Price Spikes': 17,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 5},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AMP/ETH',
#    'Price Spikes': 6,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AMP/USD',
#    'Price Spikes': 6,
#    'Volume Spikes': 24,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AMP/USDT',
#    'Price Spikes': 23,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANKR/BTC',
#    'Price Spikes': 4,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANKR/ETH',
#    'Price Spikes': 3,
#    'Volume Spikes': 10,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANKR/USD',
#    'Price Spikes': 15,
#    'Volume Spikes': 21,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANT/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 45,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANT/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANT/USD',
#    'Price Spikes': 4,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ANTE/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'APE/USD',
#    'Price Spikes': 19,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'APE/USDT',
#    'Price Spikes': 9,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'API3/USDT',
#    'Price Spikes': 18,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'APM/BTC',
#    'Price Spikes': 16,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'APXP/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AR/BTC',
#    'Price Spikes': 9,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AR/USD',
#    'Price Spikes': 31,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARDR/BTC',
#    'Price Spikes': 3,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARDX/BTC',
#    'Price Spikes': 19,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARDX/ETH',
#    'Price Spikes': 1,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARDX/USDT',
#    'Price Spikes': 15,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARIA20/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARK/BTC',
#    'Price Spikes': 6,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARTIC/USDT',
#    'Price Spikes': 24,
#    'Volume Spikes': 9,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARTII/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 2,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARV/USDT',
#    'Price Spikes': 36,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ARW/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ASM/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ATOM/BTC',
#    'Price Spikes': 4,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ATOM/ETH',
#    'Price Spikes': 2,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ATOM/USD',
#    'Price Spikes': 7,
#    'Volume Spikes': 48,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ATOM/USDT',
#    'Price Spikes': 5,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ATRI/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'ATTR/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AUDT/USDT',
#    'Price Spikes': 18,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AVAX/BTC',
#    'Price Spikes': 9,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AVAX/ETH',
#    'Price Spikes': 11,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AVAX/USD',
#    'Price Spikes': 20,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AVAX/USDT',
#    'Price Spikes': 26,
#    'Volume Spikes': 44,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AVT/ETH',
#    'Price Spikes': 5,
#    'Volume Spikes': 15,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AVT/USDT',
#    'Price Spikes': 7,
#    'Volume Spikes': 16,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AXS/USD',
#    'Price Spikes': 19,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'AXS/USDT',
#    'Price Spikes': 26,
#    'Volume Spikes': 21,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'B2M/USDT',
#    'Price Spikes': 2,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAAS/USDT',
#    'Price Spikes': 11,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BADGER/USD',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAL/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAL/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 11,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAL/EUR',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAL/USD',
#    'Price Spikes': 16,
#    'Volume Spikes': 22,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAL/USDT',
#    'Price Spikes': 15,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAND/BTC',
#    'Price Spikes': 8,
#    'Volume Spikes': 30,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAND/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAND/USDT',
#    'Price Spikes': 16,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAT/BTC',
#    'Price Spikes': 5,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAT/ETH',
#    'Price Spikes': 3,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAT/USD',
#    'Price Spikes': 15,
#    'Volume Spikes': 44,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 5},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAT/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 47,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BAX/USDT',
#    'Price Spikes': 73,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 6},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BBF/USDT',
#    'Price Spikes': 49,
#    'Volume Spikes': 14,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BCH/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BCH/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BCH/EUR',
#    'Price Spikes': 9,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BCH/USD',
#    'Price Spikes': 14,
#    'Volume Spikes': 27,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 5},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BCH/USDT',
#    'Price Spikes': 6,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BEE/USDT',
#    'Price Spikes': 65,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BERRY/USDT',
#    'Price Spikes': 33,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BEST/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 9,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BFC/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BIOT/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BIST/USDT',
#    'Price Spikes': 4,
#    'Volume Spikes': 2,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BITCI/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BKR/USDT',
#    'Price Spikes': 80,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BLK/BTC',
#    'Price Spikes': 30,
#    'Volume Spikes': 26,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BLOCK/BTC',
#    'Price Spikes': 17,
#    'Volume Spikes': 21,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BLOCK/USDT',
#    'Price Spikes': 26,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BMP/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BMP/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BNA/USDT',
#    'Price Spikes': 16,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BNT/BTC',
#    'Price Spikes': 9,
#    'Volume Spikes': 27,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BNT/ETH',
#    'Price Spikes': 9,
#    'Volume Spikes': 15,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BNT/USD',
#    'Price Spikes': 23,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BOA/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BOA/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BOND/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BOND/USDT',
#    'Price Spikes': 4,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BONDLY/USDT',
#    'Price Spikes': 18,
#    'Volume Spikes': 8,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BOSON/BTC',
#    'Price Spikes': 10,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BOSON/USDT',
#    'Price Spikes': 28,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BRZ/USDT',
#    'Price Spikes': 5,
#    'Volume Spikes': 27,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BST/USDT',
#    'Price Spikes': 20,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BSV/BTC',
#    'Price Spikes': 7,
#    'Volume Spikes': 24,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BSV/ETH',
#    'Price Spikes': 4,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BSV/EUR',
#    'Price Spikes': 4,
#    'Volume Spikes': 43,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BSV/USD',
#    'Price Spikes': 15,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BSV/USDT',
#    'Price Spikes': 16,
#    'Volume Spikes': 27,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTBS/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 2,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTC/EUR',
#    'Price Spikes': 12,
#    'Volume Spikes': 22,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTC/USD',
#    'Price Spikes': 13,
#    'Volume Spikes': 11,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTC/USDC',
#    'Price Spikes': 12,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTC/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 12,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTCV/BTC',
#    'Price Spikes': 10,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTCV/USDT',
#    'Price Spikes': 29,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTD/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTRIPS/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTRST/USD',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTS/BTC',
#    'Price Spikes': 5,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'BTU/BTC',
#    'Price Spikes': 38,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CAIZ/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CAST/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CBANK/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 2,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CBC/BTC',
#    'Price Spikes': 7,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CDEX/USDT',
#    'Price Spikes': 29,
#    'Volume Spikes': 9,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CEDS/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CEL/BTC',
#    'Price Spikes': 10,
#    'Volume Spikes': 16,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CEL/ETH',
#    'Price Spikes': 6,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CEL/USD',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CEL/USDT',
#    'Price Spikes': 7,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CELO/BTC',
#    'Price Spikes': 1,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CELO/ETH',
#    'Price Spikes': 7,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CELO/EUR',
#    'Price Spikes': 9,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CELO/USD',
#    'Price Spikes': 23,
#    'Volume Spikes': 24,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CELO/USDT',
#    'Price Spikes': 9,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CHNG/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CIND/USDT',
#    'Price Spikes': 20,
#    'Volume Spikes': 25,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CIV/USDT',
#    'Price Spikes': 1,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CKB/BTC',
#    'Price Spikes': 34,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 3},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CKB/USD',
#    'Price Spikes': 41,
#    'Volume Spikes': 47,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CKB/USDT',
#    'Price Spikes': 55,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 7},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CLI/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CLT/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CLT/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CLXY/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CMCX/USDT',
#    'Price Spikes': 2,
#    'Volume Spikes': 23,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CND/BTC',
#    'Price Spikes': 37,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'CNTM/USDT',
#    'Price Spikes': 34,
#    'Volume Spikes': 20,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'bittrex',
#    'Symbol': 'COMP/BTC',
#    'Price Spikes': 1,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'bittrex',
#    'Symbol': 'COMP/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0}],
#  'kraken': [{'Exchange': 'kraken',
#    'Symbol': '1INCH/EUR',
#    'Price Spikes': 7,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': '1INCH/USD',
#    'Price Spikes': 8,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'AAVE/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'AAVE/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 44,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'AAVE/EUR',
#    'Price Spikes': 9,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'AAVE/GBP',
#    'Price Spikes': 9,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'AAVE/USD',
#    'Price Spikes': 9,
#    'Volume Spikes': 20,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ACA/EUR',
#    'Price Spikes': 27,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'ACA/USD',
#    'Price Spikes': 23,
#    'Volume Spikes': 43,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 5},
#   {'Exchange': 'kraken',
#    'Symbol': 'ACH/EUR',
#    'Price Spikes': 51,
#    'Volume Spikes': 30,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'ACH/USD',
#    'Price Spikes': 64,
#    'Volume Spikes': 10,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/AUD',
#    'Price Spikes': 9,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/BTC',
#    'Price Spikes': 4,
#    'Volume Spikes': 27,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/ETH',
#    'Price Spikes': 3,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/EUR',
#    'Price Spikes': 8,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/GBP',
#    'Price Spikes': 10,
#    'Volume Spikes': 26,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/USD',
#    'Price Spikes': 12,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADA/USDT',
#    'Price Spikes': 11,
#    'Volume Spikes': 25,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADX/EUR',
#    'Price Spikes': 3,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ADX/USD',
#    'Price Spikes': 1,
#    'Volume Spikes': 43,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'AGLD/EUR',
#    'Price Spikes': 19,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'AGLD/USD',
#    'Price Spikes': 19,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 5},
#   {'Exchange': 'kraken',
#    'Symbol': 'AIR/EUR',
#    'Price Spikes': 24,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'AIR/USD',
#    'Price Spikes': 17,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'AKT/EUR',
#    'Price Spikes': 21,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'AKT/USD',
#    'Price Spikes': 7,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALCX/EUR',
#    'Price Spikes': 11,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALCX/USD',
#    'Price Spikes': 9,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALGO/BTC',
#    'Price Spikes': 3,
#    'Volume Spikes': 26,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALGO/ETH',
#    'Price Spikes': 3,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALGO/EUR',
#    'Price Spikes': 15,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALGO/GBP',
#    'Price Spikes': 11,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALGO/USD',
#    'Price Spikes': 14,
#    'Volume Spikes': 15,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALGO/USDT',
#    'Price Spikes': 14,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALICE/EUR',
#    'Price Spikes': 15,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 5},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALICE/USD',
#    'Price Spikes': 16,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALPHA/EUR',
#    'Price Spikes': 11,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ALPHA/USD',
#    'Price Spikes': 12,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANKR/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANKR/EUR',
#    'Price Spikes': 13,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANKR/USD',
#    'Price Spikes': 17,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANT/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANT/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANT/EUR',
#    'Price Spikes': 5,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ANT/USD',
#    'Price Spikes': 5,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'APE/EUR',
#    'Price Spikes': 13,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'APE/USD',
#    'Price Spikes': 17,
#    'Volume Spikes': 18,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'APE/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'API3/EUR',
#    'Price Spikes': 26,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'API3/USD',
#    'Price Spikes': 27,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'APT/EUR',
#    'Price Spikes': 23,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'APT/USD',
#    'Price Spikes': 25,
#    'Volume Spikes': 26,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ARB/EUR',
#    'Price Spikes': 13,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ARB/USD',
#    'Price Spikes': 11,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ARPA/EUR',
#    'Price Spikes': 28,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ARPA/USD',
#    'Price Spikes': 43,
#    'Volume Spikes': 20,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'ASTR/EUR',
#    'Price Spikes': 18,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'ASTR/USD',
#    'Price Spikes': 23,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 5},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATLAS/EUR',
#    'Price Spikes': 15,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATLAS/USD',
#    'Price Spikes': 15,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATOM/BTC',
#    'Price Spikes': 5,
#    'Volume Spikes': 30,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATOM/ETH',
#    'Price Spikes': 3,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATOM/EUR',
#    'Price Spikes': 6,
#    'Volume Spikes': 22,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATOM/GBP',
#    'Price Spikes': 6,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATOM/USD',
#    'Price Spikes': 6,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'ATOM/USDT',
#    'Price Spikes': 8,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'AUD/JPY',
#    'Price Spikes': 0,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'AUD/USD',
#    'Price Spikes': 0,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'AUDIO/EUR',
#    'Price Spikes': 29,
#    'Volume Spikes': 33,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 6},
#   {'Exchange': 'kraken',
#    'Symbol': 'AUDIO/USD',
#    'Price Spikes': 24,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 6},
#   {'Exchange': 'kraken',
#    'Symbol': 'AVAX/EUR',
#    'Price Spikes': 14,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'AVAX/USD',
#    'Price Spikes': 16,
#    'Volume Spikes': 22,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'AVAX/USDT',
#    'Price Spikes': 28,
#    'Volume Spikes': 27,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 6},
#   {'Exchange': 'kraken',
#    'Symbol': 'AXS/EUR',
#    'Price Spikes': 20,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'AXS/USD',
#    'Price Spikes': 22,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'BADGER/EUR',
#    'Price Spikes': 11,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'BADGER/USD',
#    'Price Spikes': 13,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAL/BTC',
#    'Price Spikes': 1,
#    'Volume Spikes': 48,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAL/EUR',
#    'Price Spikes': 2,
#    'Volume Spikes': 46,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAL/USD',
#    'Price Spikes': 6,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAND/EUR',
#    'Price Spikes': 15,
#    'Volume Spikes': 44,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAND/USD',
#    'Price Spikes': 22,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAT/BTC',
#    'Price Spikes': 2,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAT/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAT/EUR',
#    'Price Spikes': 13,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAT/JPY',
#    'Price Spikes': 10,
#    'Volume Spikes': 26,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BAT/USD',
#    'Price Spikes': 14,
#    'Volume Spikes': 30,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/AUD',
#    'Price Spikes': 1,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 49,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/EUR',
#    'Price Spikes': 4,
#    'Volume Spikes': 24,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/GBP',
#    'Price Spikes': 5,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/JPY',
#    'Price Spikes': 2,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/USD',
#    'Price Spikes': 4,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BCH/USDT',
#    'Price Spikes': 3,
#    'Volume Spikes': 31,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BICO/EUR',
#    'Price Spikes': 17,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'BICO/USD',
#    'Price Spikes': 19,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 5},
#   {'Exchange': 'kraken',
#    'Symbol': 'BIT/EUR',
#    'Price Spikes': 24,
#    'Volume Spikes': 28,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BIT/USD',
#    'Price Spikes': 2,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BLUR/EUR',
#    'Price Spikes': 43,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'BLUR/USD',
#    'Price Spikes': 55,
#    'Volume Spikes': 11,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BLZ/EUR',
#    'Price Spikes': 19,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'BLZ/USD',
#    'Price Spikes': 24,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'kraken',
#    'Symbol': 'BNC/EUR',
#    'Price Spikes': 43,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 6},
#   {'Exchange': 'kraken',
#    'Symbol': 'BNC/USD',
#    'Price Spikes': 52,
#    'Volume Spikes': 29,
#    'Alleged Pump and Dumps': 7,
#    'Pump and Dumps': 6},
#   {'Exchange': 'kraken',
#    'Symbol': 'BNT/BTC',
#    'Price Spikes': 6,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BNT/EUR',
#    'Price Spikes': 11,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'BNT/USD',
#    'Price Spikes': 14,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BOBA/EUR',
#    'Price Spikes': 14,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BOBA/USD',
#    'Price Spikes': 7,
#    'Volume Spikes': 41,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BOND/EUR',
#    'Price Spikes': 8,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BOND/USD',
#    'Price Spikes': 4,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BSX/EUR',
#    'Price Spikes': 47,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 10,
#    'Pump and Dumps': 8},
#   {'Exchange': 'kraken',
#    'Symbol': 'BSX/USD',
#    'Price Spikes': 51,
#    'Volume Spikes': 26,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 5},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/AUD',
#    'Price Spikes': 11,
#    'Volume Spikes': 18,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/CAD',
#    'Price Spikes': 14,
#    'Volume Spikes': 13,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/CHF',
#    'Price Spikes': 13,
#    'Volume Spikes': 15,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/DAI',
#    'Price Spikes': 17,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/EUR',
#    'Price Spikes': 11,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/GBP',
#    'Price Spikes': 12,
#    'Volume Spikes': 9,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/JPY',
#    'Price Spikes': 9,
#    'Volume Spikes': 38,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/USD',
#    'Price Spikes': 13,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/USDC',
#    'Price Spikes': 19,
#    'Volume Spikes': 17,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTC/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTT/EUR',
#    'Price Spikes': 2,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'kraken',
#    'Symbol': 'BTT/USD',
#    'Price Spikes': 2,
#    'Volume Spikes': 23,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'C98/EUR',
#    'Price Spikes': 8,
#    'Volume Spikes': 39,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 1},
#   {'Exchange': 'kraken',
#    'Symbol': 'C98/USD',
#    'Price Spikes': 13,
#    'Volume Spikes': 32,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'kraken',
#    'Symbol': 'CELR/EUR',
#    'Price Spikes': 50,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 7},
#   {'Exchange': 'kraken',
#    'Symbol': 'CELR/USD',
#    'Price Spikes': 47,
#    'Volume Spikes': 34,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 7},
#   {'Exchange': 'kraken',
#    'Symbol': 'CFG/EUR',
#    'Price Spikes': 28,
#    'Volume Spikes': 47,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 4},
#   {'Exchange': 'kraken',
#    'Symbol': 'CFG/USD',
#    'Price Spikes': 31,
#    'Volume Spikes': 35,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 7},
#   {'Exchange': 'kraken',
#    'Symbol': 'CHR/EUR',
#    'Price Spikes': 16,
#    'Volume Spikes': 36,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
# ...
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'TRX5L/USDT',
#    'Price Spikes': 81,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 5},
#   {'Exchange': 'lbank',
#    'Symbol': 'TRX5S/USDT',
#    'Price Spikes': 63,
#    'Volume Spikes': 40,
#    'Alleged Pump and Dumps': 5,
#    'Pump and Dumps': 5},
#   {'Exchange': 'lbank',
#    'Symbol': 'TUR/USDT',
#    'Price Spikes': 105,
#    'Volume Spikes': 22,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 8},
#   {'Exchange': 'lbank',
#    'Symbol': 'TVK/USDT',
#    'Price Spikes': 3,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'TVS/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'TWT/USDT',
#    'Price Spikes': 7,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UEDC/USDT',
#    'Price Spikes': 213,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 3},
#   {'Exchange': 'lbank',
#    'Symbol': 'UFO/USDT',
#    'Price Spikes': 7,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UMA/USDT',
#    'Price Spikes': 18,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNFI3L/USDT',
#    'Price Spikes': 113,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNFI3S/USDT',
#    'Price Spikes': 102,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNI/USDT',
#    'Price Spikes': 9,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNI3L/USDT',
#    'Price Spikes': 74,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNI3S/USDT',
#    'Price Spikes': 66,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNI5L/USDT',
#    'Price Spikes': 95,
#    'Volume Spikes': 44,
#    'Alleged Pump and Dumps': 9,
#    'Pump and Dumps': 8},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNI5S/USDT',
#    'Price Spikes': 79,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 8},
#   {'Exchange': 'lbank',
#    'Symbol': 'UNW/USDT',
#    'Price Spikes': 63,
#    'Volume Spikes': 8,
#    'Alleged Pump and Dumps': 4,
#    'Pump and Dumps': 3},
#   {'Exchange': 'lbank',
#    'Symbol': 'UPS/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'USDC/USDT',
#    'Price Spikes': 2,
#    'Volume Spikes': 9,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'USDD/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UTK/USDT',
#    'Price Spikes': 10,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'UUSD/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VEGA/USDT',
#    'Price Spikes': 8,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VELO/USDT',
#    'Price Spikes': 61,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VET/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VET3L/USDT',
#    'Price Spikes': 111,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VET3S/USDT',
#    'Price Spikes': 87,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VEX/USDT',
#    'Price Spikes': 72,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'VIC/USDT',
#    'Price Spikes': 47,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VICA/USDT',
#    'Price Spikes': 39,
#    'Volume Spikes': 2,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VITA/USDT',
#    'Price Spikes': 14,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VNXAU/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VOB/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VOLT/USDT',
#    'Price Spikes': 35,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'VOXEL/USDT',
#    'Price Spikes': 21,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'VST/USDT',
#    'Price Spikes': 36,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'VT/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WAHED/USDT',
#    'Price Spikes': 26,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WAVES/USDT',
#    'Price Spikes': 15,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WAVES3L/USDT',
#    'Price Spikes': 92,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WAVES3S/USDT',
#    'Price Spikes': 93,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WAXE/USDT',
#    'Price Spikes': 17,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WAXP/USDT',
#    'Price Spikes': 11,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WBC/USDT',
#    'Price Spikes': 10,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WBX/USDT',
#    'Price Spikes': 13,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'WCA/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WELUPS/USDT',
#    'Price Spikes': 126,
#    'Volume Spikes': 19,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'WIN/USDT',
#    'Price Spikes': 6,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WMX/USDT',
#    'Price Spikes': 53,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WOO/USDT',
#    'Price Spikes': 24,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WOOF/USDT',
#    'Price Spikes': 56,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WV/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'WWY/USDT',
#    'Price Spikes': 23,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'X2Y2/USDT',
#    'Price Spikes': 58,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XCC/USDT',
#    'Price Spikes': 38,
#    'Volume Spikes': 24,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'lbank',
#    'Symbol': 'XCH/USDT',
#    'Price Spikes': 2,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XEM3L/USDT',
#    'Price Spikes': 118,
#    'Volume Spikes': 10,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'XEM3S/USDT',
#    'Price Spikes': 85,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XLM/USDT',
#    'Price Spikes': 11,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XLM3L/USDT',
#    'Price Spikes': 83,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XLM3S/USDT',
#    'Price Spikes': 58,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XMR3L/USDT',
#    'Price Spikes': 68,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XMR3S/USDT',
#    'Price Spikes': 57,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XMT/USDT',
#    'Price Spikes': 6,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRD/USDT',
#    'Price Spikes': 12,
#    'Volume Spikes': 3,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP/BUSD',
#    'Price Spikes': 17,
#    'Volume Spikes': 6,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP/ETH',
#    'Price Spikes': 15,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP/USDC',
#    'Price Spikes': 26,
#    'Volume Spikes': 11,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP/USDT',
#    'Price Spikes': 17,
#    'Volume Spikes': 7,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP3L/USDT',
#    'Price Spikes': 120,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP3S/USDT',
#    'Price Spikes': 72,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP5L/USDT',
#    'Price Spikes': 143,
#    'Volume Spikes': 45,
#    'Alleged Pump and Dumps': 8,
#    'Pump and Dumps': 6},
#   {'Exchange': 'lbank',
#    'Symbol': 'XRP5S/USDT',
#    'Price Spikes': 95,
#    'Volume Spikes': 37,
#    'Alleged Pump and Dumps': 6,
#    'Pump and Dumps': 6},
#   {'Exchange': 'lbank',
#    'Symbol': 'XSPECTAR/USDT',
#    'Price Spikes': 32,
#    'Volume Spikes': 8,
#    'Alleged Pump and Dumps': 2,
#    'Pump and Dumps': 2},
#   {'Exchange': 'lbank',
#    'Symbol': 'XT/USDT',
#    'Price Spikes': 3,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XTZ/USDT',
#    'Price Spikes': 9,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XTZ3L/USDT',
#    'Price Spikes': 87,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XTZ3S/USDT',
#    'Price Spikes': 87,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XWC2/BTC',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'XWC2/ETH',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YELO/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YEON/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YFI3L/USDT',
#    'Price Spikes': 105,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 1,
#    'Pump and Dumps': 1},
#   {'Exchange': 'lbank',
#    'Symbol': 'YFI3S/USDT',
#    'Price Spikes': 106,
#    'Volume Spikes': 1,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YFII/USDT',
#    'Price Spikes': 3,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YFII3L/USDT',
#    'Price Spikes': 53,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YFII3S/USDT',
#    'Price Spikes': 49,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'YGG/USDT',
#    'Price Spikes': 44,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZAMZAM/USDC',
#    'Price Spikes': 13,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZBC/USDT',
#    'Price Spikes': 19,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEC/USDT',
#    'Price Spikes': 11,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEC3L/USDT',
#    'Price Spikes': 109,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEC3S/USDT',
#    'Price Spikes': 88,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEN/USDT',
#    'Price Spikes': 19,
#    'Volume Spikes': 5,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEN3L/USDT',
#    'Price Spikes': 115,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEN3S/USDT',
#    'Price Spikes': 114,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZEXI/USDT',
#    'Price Spikes': 0,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZIK/USDT',
#    'Price Spikes': 9,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZIL/USDT',
#    'Price Spikes': 16,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZIL3L/USDT',
#    'Price Spikes': 119,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZIL3S/USDT',
#    'Price Spikes': 87,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZINU/USDT',
#    'Price Spikes': 141,
#    'Volume Spikes': 4,
#    'Alleged Pump and Dumps': 3,
#    'Pump and Dumps': 2},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZRX3L/USDT',
#    'Price Spikes': 94,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0},
#   {'Exchange': 'lbank',
#    'Symbol': 'ZRX3S/USDT',
#    'Price Spikes': 88,
#    'Volume Spikes': 0,
#    'Alleged Pump and Dumps': 0,
#    'Pump and Dumps': 0}]}

# %%
allegedPD  = {'bittrex': 0, 'kraken': 0, 'kucoin': 0, 'lbank': 0}
confirmedPD = {'bittrex': 0, 'kraken': 0, 'kucoin': 0, 'lbank': 0}

# %%
for exchange in allegedPD.keys():
  for dictionary in exchangeDict[exchange]:
    allegedPD[exchange] += dictionary['Alleged Pump and Dumps']
    confirmedPD[exchange] += dictionary['Pump and Dumps']

print(allegedPD)
print(confirmedPD)
# Out:
# {'bittrex': 335, 'kraken': 769, 'kucoin': 46, 'lbank': 855}
# {'bittrex': 219, 'kraken': 616, 'kucoin': 35, 'lbank': 753}

# %%
totalCount = {'bittrex': 0, 'kraken': 0, 'kucoin': 0, 'lbank': 0}

# %%
for exchange in totalCount.keys():
  for file in os.listdir(exchange):
    file = exchange + '/' + file
    totalCount[exchange] += countTransactions(f_path = file)

# %%
print(totalCount)
# Out:
# {'bittrex': 81927, 'kraken': 141688, 'kucoin': 11463, 'lbank': 430049}

# %%
percentagePD = {'bittrex': 0, 'kraken': 0, 'kucoin': 0, 'lbank': 0}
for exchange in percentagePD.keys():
  percentagePD[exchange] = (confirmedPD[exchange] / totalCount[exchange])

print(percentagePD)
# Out:
# {'bittrex': 0.002673111428466806, 'kraken': 0.004347580599627351, 'kucoin': 0.0030533019279420743, 'lbank': 0.001750963262325921}

# %%
allPDCount = []
for exchange in exchangeDict:
  for dictionary in exchangeDict[exchange]:
    allPDCount.append((dictionary['Pump and Dumps'], dictionary['Exchange'], dictionary['Symbol']))

# %%
allPDCount.sort(reverse=True)
print(allPDCount[0:49])
# Out:
# [(13, 'lbank', 'ENJ5S/USDT'), (13, 'lbank', 'BCH5L/USDT'), (12, 'lbank', 'FLOKICEO/USDT'), (11, 'lbank', 'SUSHI5L/USDT'), (11, 'lbank', 'SHIB5S/USDT'), (11, 'lbank', 'SAND5S/USDT'), (11, 'lbank', 'LTC5S/USDT'), (11, 'lbank', 'FIL5L/USDT'), (11, 'lbank', 'EDAT/USDT'), (11, 'lbank', '1INCH5L/USDT'), (10, 'lbank', 'SSM/USDT'), (10, 'lbank', 'OTWO/USDT'), (10, 'lbank', 'GXBC/USDT'), (10, 'lbank', 'AXS5S/USDT'), (10, 'lbank', 'AXS5L/USDT'), (10, 'lbank', 'ASC/USDT'), (10, 'lbank', '1INCH5S/USDT'), (9, 'lbank', 'SAND5L/USDT'), (9, 'lbank', 'PEOPLE5L/USDT'), (9, 'lbank', 'NEO5L/USDT'), (9, 'lbank', 'LINK5S/USDT'), (9, 'lbank', 'GLR/USDT'), (9, 'lbank', 'DOT5S/USDT'), (9, 'lbank', 'APT3S/USDT'), (8, 'lbank', 'UNI5S/USDT'), (8, 'lbank', 'UNI5L/USDT'), (8, 'lbank', 'TUR/USDT'), (8, 'lbank', 'SUSHI5S/USDT'), (8, 'lbank', 'SOL5S/USDT'), (8, 'lbank', 'FIL5S/USDT'), (8, 'lbank', 'EOS5S/USDT'), (8, 'lbank', 'ENJ5L/USDT'), (8, 'lbank', 'DOT5L/USDT'), (8, 'lbank', 'DOGE5L/USDT'), (8, 'lbank', 'BTC5L/USDT'), (8, 'lbank', 'APT3L/USDT'), (8, 'kraken', 'KIN/USD'), (8, 'kraken', 'HDX/USD'), (8, 'kraken', 'GAL/EUR'), (8, 'kraken', 'EUL/USD'), (8, 'kraken', 'BSX/EUR'), (7, 'lbank', 'SHIB5L/USDT'), (7, 'lbank', 'NEO5S/USDT'), (7, 'lbank', 'LTC5L/USDT'), (7, 'lbank', 'LINK5L/USDT'), (7, 'lbank', 'GALA5L/USDT'), (7, 'lbank', 'CRV5S/USDT'), (7, 'lbank', 'CREMOA/USDT'), (7, 'lbank', 'BSV5S/USDT')]

# %% [markdown]
# sum up the volumes instead of the observations;
# the question being: does the liquidity of a coin affect P&D?
# - use volume as measure of liquidity
# - does lbank see a lot of pump and dumps? look at P&D / total volume
# - does the ratio of the 13 pump coin look similar?
# - ratio could be higher, which means that there are a high number of pumps relative to volume (meaning low volume wants to be pumped)
# - ratio could be similar/lower, meaning liquidity not driving P&D
# - is the pair illiquid until P&D, and then there's a lot of trading during the pump, and then it falls back down
# - best to visualize these results with a chart

# %%
volumeSum = {'bittrex': 0, 'kraken': 0, 'kucoin': 0, 'lbank': 0}

# %%
for exchange in totalCount.keys():
  for file in os.listdir(exchange):
    file = exchange + '/' + file
    volumeSum[exchange] += countVolume(f_path = file)

# %%
volumeSum
# Out:
# {'bittrex': 1149277835.3330858,
#  'kraken': 11815017656242.49,
#  'kucoin': 19214948563.90778,
#  'lbank': 3.829304143994772e+17}

# %%
volumePercentPD = {'bittrex': 0, 'kraken': 0, 'kucoin': 0, 'lbank': 0}
for exchange in volumePercentPD.keys():
  volumePercentPD[exchange] = (confirmedPD[exchange] / volumeSum[exchange])

print(volumePercentPD)
# Out:
# {'bittrex': 1.9055444494544613e-07, 'kraken': 5.2137035925167247e-11, 'kucoin': 1.8214985006903388e-09, 'lbank': 1.9664147105705274e-15}

# %%
thirteenPumps = 'lbank/lbank_ENJ5S-USDT_[2023-03-10 00.00.00]-TO-[2023-03-29 02.00.00].csv'
vol = countVolume(thirteenPumps)
print(vol)
print(13 / vol)
# Out:
# 2867761.6175610498
# 4.533152239849047e-06

# %%
pumpCoins = []
noPumpCoins = []
for exchange in exchangeDict.keys():
  for file in os.listdir(exchange):
    file = exchange + '/' + file
    if checkForPumps(file) > 0:
      pumpCoins.append(file)
    else:
      noPumpCoins.append(file)
# Out:
# {'Exchange': 'bittrex', 'Symbol': '1ECO/BTC', 'Price Spikes': 67, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': '1ECO/USDT', 'Price Spikes': 32, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/BTC', 'Price Spikes': 6, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/ETH', 'Price Spikes': 4, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/USD', 'Price Spikes': 12, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': '1INCH/USDT', 'Price Spikes': 20, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': '1PECO/BTC', 'Price Spikes': 176, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': '1PECO/USDT', 'Price Spikes': 61, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': '4ART/BTC', 'Price Spikes': 11, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': '4ART/USDT', 'Price Spikes': 1, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/BTC', 'Price Spikes': 5, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/ETH', 'Price Spikes': 6, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/EUR', 'Price Spikes': 4, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/USD', 'Price Spikes': 16, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'AAVE/USDT', 'Price Spikes': 6, 'Volume Spikes': 43, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ABBC/BTC', 'Price Spikes': 2, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ABYSS/BTC', 'Price Spikes': 1, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ACH/USD', 'Price Spikes': 47, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ACXT/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/BTC', 'Price Spikes': 3, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/ETH', 'Price Spikes': 6, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/EUR', 'Price Spikes': 6, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/USD', 'Price Spikes': 11, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/USDC', 'Price Spikes': 13, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADA/USDT', 'Price Spikes': 10, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADK/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ADX/BTC', 'Price Spikes': 0, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AGRS/BTC', 'Price Spikes': 30, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'AGRS/USDT', 'Price Spikes': 33, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': 'AGV/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AIN/USDT', 'Price Spikes': 18, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AKN/USDT', 'Price Spikes': 5, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AKRO/BTC', 'Price Spikes': 0, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AKT/BTC', 'Price Spikes': 8, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AKT/USDT', 'Price Spikes': 14, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AKTIO/USDT', 'Price Spikes': 21, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'ALGO/BTC', 'Price Spikes': 11, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ALGO/USD', 'Price Spikes': 14, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ALGO/USDT', 'Price Spikes': 17, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ALTA/USDT', 'Price Spikes': 28, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/BTC', 'Price Spikes': 17, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/ETH', 'Price Spikes': 6, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/USD', 'Price Spikes': 6, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'AMP/USDT', 'Price Spikes': 23, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'ANKR/BTC', 'Price Spikes': 4, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ANKR/ETH', 'Price Spikes': 3, 'Volume Spikes': 10, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ANKR/USD', 'Price Spikes': 15, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ANT/BTC', 'Price Spikes': 0, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ANT/ETH', 'Price Spikes': 0, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ANT/USD', 'Price Spikes': 4, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ANTE/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'APE/USD', 'Price Spikes': 19, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'APE/USDT', 'Price Spikes': 9, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'API3/USDT', 'Price Spikes': 18, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'APM/BTC', 'Price Spikes': 16, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'APXP/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AR/BTC', 'Price Spikes': 9, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'AR/USD', 'Price Spikes': 31, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'ARDR/BTC', 'Price Spikes': 3, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'ARDX/BTC', 'Price Spikes': 19, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ARDX/ETH', 'Price Spikes': 1, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ARDX/USDT', 'Price Spikes': 15, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ARIA20/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ARK/BTC', 'Price Spikes': 6, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'ARTIC/USDT', 'Price Spikes': 24, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'ARTII/BTC', 'Price Spikes': 0, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ARV/USDT', 'Price Spikes': 36, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ARW/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ASM/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ATOM/BTC', 'Price Spikes': 4, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ATOM/ETH', 'Price Spikes': 2, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ATOM/USD', 'Price Spikes': 7, 'Volume Spikes': 48, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'ATOM/USDT', 'Price Spikes': 5, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'ATRI/USDT', 'Price Spikes': 0, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'ATTR/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AUDT/USDT', 'Price Spikes': 18, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AVAX/BTC', 'Price Spikes': 9, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'AVAX/ETH', 'Price Spikes': 11, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'AVAX/USD', 'Price Spikes': 20, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AVAX/USDT', 'Price Spikes': 26, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AVT/ETH', 'Price Spikes': 5, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AVT/USDT', 'Price Spikes': 7, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'AXS/USD', 'Price Spikes': 19, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'AXS/USDT', 'Price Spikes': 26, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'B2M/USDT', 'Price Spikes': 2, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAAS/USDT', 'Price Spikes': 11, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BADGER/USD', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAL/BTC', 'Price Spikes': 0, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAL/ETH', 'Price Spikes': 0, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAL/EUR', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAL/USD', 'Price Spikes': 16, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAL/USDT', 'Price Spikes': 15, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BAND/BTC', 'Price Spikes': 8, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAND/ETH', 'Price Spikes': 0, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BAND/USDT', 'Price Spikes': 16, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'BAT/BTC', 'Price Spikes': 5, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BAT/ETH', 'Price Spikes': 3, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BAT/USD', 'Price Spikes': 15, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': 'BAT/USDT', 'Price Spikes': 13, 'Volume Spikes': 47, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'BAX/USDT', 'Price Spikes': 73, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 6}
# {'Exchange': 'bittrex', 'Symbol': 'BBF/USDT', 'Price Spikes': 49, 'Volume Spikes': 14, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BCH/BTC', 'Price Spikes': 0, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BCH/ETH', 'Price Spikes': 0, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BCH/EUR', 'Price Spikes': 9, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BCH/USD', 'Price Spikes': 14, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'bittrex', 'Symbol': 'BCH/USDT', 'Price Spikes': 6, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BEE/USDT', 'Price Spikes': 65, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BERRY/USDT', 'Price Spikes': 33, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BEST/USDT', 'Price Spikes': 0, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BFC/BTC', 'Price Spikes': 0, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BIOT/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BIST/USDT', 'Price Spikes': 4, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BITCI/USDT', 'Price Spikes': 13, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BKR/USDT', 'Price Spikes': 80, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BLK/BTC', 'Price Spikes': 30, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BLOCK/BTC', 'Price Spikes': 17, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BLOCK/USDT', 'Price Spikes': 26, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BMP/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BMP/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BNA/USDT', 'Price Spikes': 16, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BNT/BTC', 'Price Spikes': 9, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BNT/ETH', 'Price Spikes': 9, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BNT/USD', 'Price Spikes': 23, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'BOA/BTC', 'Price Spikes': 0, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BOA/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BOND/ETH', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BOND/USDT', 'Price Spikes': 4, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BONDLY/USDT', 'Price Spikes': 18, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BOSON/BTC', 'Price Spikes': 10, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BOSON/USDT', 'Price Spikes': 28, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BRZ/USDT', 'Price Spikes': 5, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BST/USDT', 'Price Spikes': 20, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BSV/BTC', 'Price Spikes': 7, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BSV/ETH', 'Price Spikes': 4, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BSV/EUR', 'Price Spikes': 4, 'Volume Spikes': 43, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BSV/USD', 'Price Spikes': 15, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'BSV/USDT', 'Price Spikes': 16, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'BTBS/USDT', 'Price Spikes': 0, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/EUR', 'Price Spikes': 12, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/USD', 'Price Spikes': 13, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/USDC', 'Price Spikes': 12, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'BTC/USDT', 'Price Spikes': 13, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BTCV/BTC', 'Price Spikes': 10, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'BTCV/USDT', 'Price Spikes': 29, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'BTD/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTRIPS/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTRST/USD', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'BTS/BTC', 'Price Spikes': 5, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'BTU/BTC', 'Price Spikes': 38, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CAIZ/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CAST/USDT', 'Price Spikes': 0, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CBANK/USDT', 'Price Spikes': 0, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CBC/BTC', 'Price Spikes': 7, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CDEX/USDT', 'Price Spikes': 29, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CEDS/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/BTC', 'Price Spikes': 10, 'Volume Spikes': 16, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/ETH', 'Price Spikes': 6, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/USD', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CEL/USDT', 'Price Spikes': 7, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/BTC', 'Price Spikes': 1, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/ETH', 'Price Spikes': 7, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/EUR', 'Price Spikes': 9, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/USD', 'Price Spikes': 23, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CELO/USDT', 'Price Spikes': 9, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'CHNG/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CIND/USDT', 'Price Spikes': 20, 'Volume Spikes': 25, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'bittrex', 'Symbol': 'CIV/USDT', 'Price Spikes': 1, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 'CKB/BTC', 'Price Spikes': 34, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 3}
# {'Exchange': 'bittrex', 'Symbol': 'CKB/USD', 'Price Spikes': 41, 'Volume Spikes': 47, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'bittrex', 'Symbol': 'CKB/USDT', 'Price Spikes': 55, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'bittrex', 'Symbol': 'CLI/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CLT/BTC', 'Price Spikes': 0, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CLT/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CLXY/USDT', 'Price Spikes': 0, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CMCX/USDT', 'Price Spikes': 2, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'bittrex', 'Symbol': 'CND/BTC', 'Price Spikes': 37, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'bittrex', 'Symbol': 
 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'ALICE/USD', 'Price Spikes': 16, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ALPHA/EUR', 'Price Spikes': 11, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ALPHA/USD', 'Price Spikes': 12, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ANKR/BTC', 'Price Spikes': 0, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ANKR/EUR', 'Price Spikes': 13, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'ANKR/USD', 'Price Spikes': 17, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ANT/BTC', 'Price Spikes': 0, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ANT/ETH', 'Price Spikes': 0, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ANT/EUR', 'Price Spikes': 5, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ANT/USD', 'Price Spikes': 5, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'APE/EUR', 'Price Spikes': 13, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'APE/USD', 'Price Spikes': 17, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'APE/USDT', 'Price Spikes': 13, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'API3/EUR', 'Price Spikes': 26, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'API3/USD', 'Price Spikes': 27, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'APT/EUR', 'Price Spikes': 23, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'APT/USD', 'Price Spikes': 25, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ARB/EUR', 'Price Spikes': 13, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ARB/USD', 'Price Spikes': 11, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ARPA/EUR', 'Price Spikes': 28, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ARPA/USD', 'Price Spikes': 43, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'ASTR/EUR', 'Price Spikes': 18, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'ASTR/USD', 'Price Spikes': 23, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'ATLAS/EUR', 'Price Spikes': 15, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ATLAS/USD', 'Price Spikes': 15, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/BTC', 'Price Spikes': 5, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/ETH', 'Price Spikes': 3, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/EUR', 'Price Spikes': 6, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/GBP', 'Price Spikes': 6, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/USD', 'Price Spikes': 6, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'ATOM/USDT', 'Price Spikes': 8, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'AUD/JPY', 'Price Spikes': 0, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'AUD/USD', 'Price Spikes': 0, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'AUDIO/EUR', 'Price Spikes': 29, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'AUDIO/USD', 'Price Spikes': 24, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'AVAX/EUR', 'Price Spikes': 14, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'AVAX/USD', 'Price Spikes': 16, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'AVAX/USDT', 'Price Spikes': 28, 'Volume Spikes': 27, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'AXS/EUR', 'Price Spikes': 20, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'AXS/USD', 'Price Spikes': 22, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BADGER/EUR', 'Price Spikes': 11, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BADGER/USD', 'Price Spikes': 13, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BAL/BTC', 'Price Spikes': 1, 'Volume Spikes': 48, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BAL/EUR', 'Price Spikes': 2, 'Volume Spikes': 46, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BAL/USD', 'Price Spikes': 6, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BAND/EUR', 'Price Spikes': 15, 'Volume Spikes': 44, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BAND/USD', 'Price Spikes': 22, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BAT/BTC', 'Price Spikes': 2, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BAT/ETH', 'Price Spikes': 0, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BAT/EUR', 'Price Spikes': 13, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BAT/JPY', 'Price Spikes': 10, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BAT/USD', 'Price Spikes': 14, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BCH/AUD', 'Price Spikes': 1, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/BTC', 'Price Spikes': 0, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/ETH', 'Price Spikes': 0, 'Volume Spikes': 49, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/EUR', 'Price Spikes': 4, 'Volume Spikes': 24, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/GBP', 'Price Spikes': 5, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BCH/JPY', 'Price Spikes': 2, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/USD', 'Price Spikes': 4, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BCH/USDT', 'Price Spikes': 3, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BICO/EUR', 'Price Spikes': 17, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'BICO/USD', 'Price Spikes': 19, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'BIT/EUR', 'Price Spikes': 24, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BIT/USD', 'Price Spikes': 2, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BLUR/EUR', 'Price Spikes': 43, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BLUR/USD', 'Price Spikes': 55, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BLZ/EUR', 'Price Spikes': 19, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'BLZ/USD', 'Price Spikes': 24, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'BNC/EUR', 'Price Spikes': 43, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'BNC/USD', 'Price Spikes': 52, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 6}
# {'Exchange': 'kraken', 'Symbol': 'BNT/BTC', 'Price Spikes': 6, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BNT/EUR', 'Price Spikes': 11, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'BNT/USD', 'Price Spikes': 14, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BOBA/EUR', 'Price Spikes': 14, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BOBA/USD', 'Price Spikes': 7, 'Volume Spikes': 41, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BOND/EUR', 'Price Spikes': 8, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BOND/USD', 'Price Spikes': 4, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BSX/EUR', 'Price Spikes': 47, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 10, 'Pump and Dumps': 8}
# {'Exchange': 'kraken', 'Symbol': 'BSX/USD', 'Price Spikes': 51, 'Volume Spikes': 26, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'BTC/AUD', 'Price Spikes': 11, 'Volume Spikes': 18, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/CAD', 'Price Spikes': 14, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/CHF', 'Price Spikes': 13, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/DAI', 'Price Spikes': 17, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BTC/EUR', 'Price Spikes': 11, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTC/GBP', 'Price Spikes': 12, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/JPY', 'Price Spikes': 9, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/USD', 'Price Spikes': 13, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/USDC', 'Price Spikes': 19, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'BTC/USDT', 'Price Spikes': 13, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'BTT/EUR', 'Price Spikes': 2, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'BTT/USD', 'Price Spikes': 2, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'C98/EUR', 'Price Spikes': 8, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'C98/USD', 'Price Spikes': 13, 'Volume Spikes': 32, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CELR/EUR', 'Price Spikes': 50, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CELR/USD', 'Price Spikes': 47, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CFG/EUR', 'Price Spikes': 28, 'Volume Spikes': 47, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'CFG/USD', 'Price Spikes': 31, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CHR/EUR', 'Price Spikes': 16, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'CHR/USD', 'Price Spikes': 11, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CHZ/EUR', 'Price Spikes': 0, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'CHZ/USD', 'Price Spikes': 0, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'COMP/BTC', 'Price Spikes': 0, 'Volume Spikes': 36, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'COMP/EUR', 'Price Spikes': 12, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'COMP/USD', 'Price Spikes': 12, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'COTI/EUR', 'Price Spikes': 19, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'COTI/USD', 'Price Spikes': 17, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CQT/EUR', 'Price Spikes': 15, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'CQT/USD', 'Price Spikes': 14, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/BTC', 'Price Spikes': 1, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/ETH', 'Price Spikes': 1, 'Volume Spikes': 42, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/EUR', 'Price Spikes': 17, 'Volume Spikes': 33, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CRV/USD', 'Price Spikes': 21, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CSM/EUR', 'Price Spikes': 60, 'Volume Spikes': 38, 'Alleged Pump and Dumps': 7, 'Pump and Dumps': 7}
# {'Exchange': 'kraken', 'Symbol': 'CSM/USD', 'Price Spikes': 70, 'Volume Spikes': 34, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'CTSI/EUR', 'Price Spikes': 12, 'Volume Spikes': 46, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CTSI/USD', 'Price Spikes': 17, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'kraken', 'Symbol': 'CVC/EUR', 'Price Spikes': 11, 'Volume Spikes': 23, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CVC/USD', 'Price Spikes': 7, 'Volume Spikes': 39, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'CVX/EUR', 'Price Spikes': 17, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'CVX/USD', 'Price Spikes': 13, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'DAI/EUR', 'Price Spikes': 0, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DAI/USD', 'Price Spikes': 0, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DAI/USDT', 'Price Spikes': 0, 'Volume Spikes': 17, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DASH/BTC', 'Price Spikes': 9, 'Volume Spikes': 31, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'DASH/EUR', 'Price Spikes': 25, 'Volume Spikes': 20, 'Alleged Pump and Dumps': 4, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'DASH/USD', 'Price Spikes': 28, 'Volume Spikes': 21, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'DENT/EUR', 'Price Spikes': 14, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'kraken', 'Symbol': 'DENT/USD', 'Price Spikes': 23, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 4}
# {'Exchange': 'kraken', 'Symbol': 'DOGE/BTC', 'Price Spikes': 1, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DOGE/EUR', 'Price Spikes': 6, 'Volume Spikes': 13, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'DOGE/USD', 'Price Spikes': 7, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DOGE/USDT', 'Price Spikes': 6, 'Volume Spikes': 35, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DOT/BTC', 'Price Spikes': 1, 'Volume Spikes': 19, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'DOT/ETH', 'Price Spikes': 0, 'Volume Spikes': 28, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DOT/EUR', 'Price Spikes': 5, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'kraken', 'Symbol': 'DOT/GBP', 'Price Spikes': 6, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'DOT/JPY', 'Price Spikes': 3, 'Volume Spikes': 29, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'kraken', 'Symbol': 'DOT/USD', 'Price Spikes': 4, 'Volume Spikes': 12, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'kraken', 'Symbol': 'DOT/USDT', 'Price Spikes': 7, 'Volume Spikes': 30, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# ...
# {'Exchange': 'lbank', 'Symbol': 'TRA/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRB3L/USDT', 'Price Spikes': 105, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRB3S/USDT', 'Price Spikes': 104, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TREES/USDT', 'Price Spikes': 29, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRG/USDT', 'Price Spikes': 17, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRIX/USDT', 'Price Spikes': 60, 'Volume Spikes': 15, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 3}
# {'Exchange': 'lbank', 'Symbol': 'TRL/USDT', 'Price Spikes': 134, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRMX/USDT', 'Price Spikes': 110, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'TRU/USDT', 'Price Spikes': 47, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX/ETH', 'Price Spikes': 6, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX/USDC', 'Price Spikes': 11, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX/USDT', 'Price Spikes': 7, 'Volume Spikes': 9, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX3L/USDT', 'Price Spikes': 54, 'Volume Spikes': 2, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'TRX3S/USDT', 'Price Spikes': 38, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TRX5L/USDT', 'Price Spikes': 81, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'TRX5S/USDT', 'Price Spikes': 63, 'Volume Spikes': 40, 'Alleged Pump and Dumps': 5, 'Pump and Dumps': 5}
# {'Exchange': 'lbank', 'Symbol': 'TUR/USDT', 'Price Spikes': 105, 'Volume Spikes': 22, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 8}
# {'Exchange': 'lbank', 'Symbol': 'TVK/USDT', 'Price Spikes': 3, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'TVS/USDT', 'Price Spikes': 0, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 
 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XMR3S/USDT', 'Price Spikes': 57, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XMT/USDT', 'Price Spikes': 6, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XRD/USDT', 'Price Spikes': 12, 'Volume Spikes': 3, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XRP/BUSD', 'Price Spikes': 17, 'Volume Spikes': 6, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XRP/ETH', 'Price Spikes': 15, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XRP/USDC', 'Price Spikes': 26, 'Volume Spikes': 11, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'XRP/USDT', 'Price Spikes': 17, 'Volume Spikes': 7, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XRP3L/USDT', 'Price Spikes': 120, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XRP3S/USDT', 'Price Spikes': 72, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'XRP5L/USDT', 'Price Spikes': 143, 'Volume Spikes': 45, 'Alleged Pump and Dumps': 8, 'Pump and Dumps': 6}
# {'Exchange': 'lbank', 'Symbol': 'XRP5S/USDT', 'Price Spikes': 95, 'Volume Spikes': 37, 'Alleged Pump and Dumps': 6, 'Pump and Dumps': 6}
# {'Exchange': 'lbank', 'Symbol': 'XSPECTAR/USDT', 'Price Spikes': 32, 'Volume Spikes': 8, 'Alleged Pump and Dumps': 2, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'XT/USDT', 'Price Spikes': 3, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XTZ/USDT', 'Price Spikes': 9, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XTZ3L/USDT', 'Price Spikes': 87, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XTZ3S/USDT', 'Price Spikes': 87, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XWC2/BTC', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'XWC2/ETH', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YELO/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YEON/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YFI3L/USDT', 'Price Spikes': 105, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 1, 'Pump and Dumps': 1}
# {'Exchange': 'lbank', 'Symbol': 'YFI3S/USDT', 'Price Spikes': 106, 'Volume Spikes': 1, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YFII/USDT', 'Price Spikes': 3, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YFII3L/USDT', 'Price Spikes': 53, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YFII3S/USDT', 'Price Spikes': 49, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'YGG/USDT', 'Price Spikes': 44, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZAMZAM/USDC', 'Price Spikes': 13, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZBC/USDT', 'Price Spikes': 19, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEC/USDT', 'Price Spikes': 11, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEC3L/USDT', 'Price Spikes': 109, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEC3S/USDT', 'Price Spikes': 88, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEN/USDT', 'Price Spikes': 19, 'Volume Spikes': 5, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEN3L/USDT', 'Price Spikes': 115, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEN3S/USDT', 'Price Spikes': 114, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZEXI/USDT', 'Price Spikes': 0, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIK/USDT', 'Price Spikes': 9, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIL/USDT', 'Price Spikes': 16, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIL3L/USDT', 'Price Spikes': 119, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZIL3S/USDT', 'Price Spikes': 87, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZINU/USDT', 'Price Spikes': 141, 'Volume Spikes': 4, 'Alleged Pump and Dumps': 3, 'Pump and Dumps': 2}
# {'Exchange': 'lbank', 'Symbol': 'ZRX3L/USDT', 'Price Spikes': 94, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}
# {'Exchange': 'lbank', 'Symbol': 'ZRX3S/USDT', 'Price Spikes': 88, 'Volume Spikes': 0, 'Alleged Pump and Dumps': 0, 'Pump and Dumps': 0}

# %%
pumpVolumes = 0
noPumpVolumes = 0

# %%
for file in pumpCoins:
  pumpVolumes += countVolume(f_path = file)

# %%
for file in noPumpCoins:
  noPumpVolumes += countVolume(f_path = file)

# %%
pumpVolumes
# Out:
# 3.64752431303624e+16

# %%
noPumpVolumes
# Out:
# 3.464670066509974e+17
